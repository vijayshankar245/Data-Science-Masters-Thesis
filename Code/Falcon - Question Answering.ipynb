# %% [markdown]
# This Notebook is the implementation of fine-tuning Falcon LLM on FinQA Dataset for Question-answering task. Evaluation was performed on test dataset and results have been reported

# %% [markdown]
# ### Intall Required Libraries and Packages

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# !pip install huggingface_hub
# !pip install -q datasets

import numpy as np
import re
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
from datasets import load_dataset
import pandas as pd
import random
from datasets import Dataset
from datasets import load_dataset
import pandas as pd
import random
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 98.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 53.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.11.17)

# %% [markdown]
# ### Login into Hugging Face Hub

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Load the data

# %% [markdown]
# - Train and Test data has been loaded
# - FINQA has separate Split for train and test data and hence same has been loaded from hugging face hub
# - Data has been converted into a format which can be used to fine tune the LLMs

# %%
pd.set_option('display.max_colwidth', -1)
dataset = load_dataset("dreamerdeo/finqa",split="train") ### Load train data from hugging face hub

dataset_pd = dataset.to_pandas() ### convert to pandas

def table_format(x_input): ### format the tabular data in the financial report in pipe delimited format
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x): ### Convert the list of sentences into a single paragraph of sentences 
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

##apply the functions
dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)


### Instructions to be overlaid to the train dataset
instructions = [
    "Financial data and expert analysis has been provided as context, use the provided context to answer the question.",
    "Please provide the required answer to this expert-authored finance question based on the context given.",
    "A deep financial question based on a financial report has been given along with required context, could you help answer the financial question.",
    "Analysis based on financial documents has been given as context, please answer the question using the context.",
    "Financial report data and analysis has been given as context , please respond to the question using the context given."
]

## Add the instructions
ins_list = []
for ins in range(6251):
  ins = random.choice(instructions)
  ins_list.append(ins)


dataset_pd['instructions'] = ins_list

### Finally combine all the formatted columns together to form the final prompt
ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = f'###Instruction:'  + dataset_pd['instructions'] + ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question'] +  f'\n\n###Answer:' +  dataset_pd['answer']

from datasets import Dataset
train_df = Dataset.from_pandas(dataset_pd)
dataset_dct = train_df.train_test_split(test_size=0.25) ### Create validation dataset from train dataset

### Get the Train and Test Dataset from Hugging Face Dataset Dict object
df_train = dataset_dct["train"]
df_eval = dataset_dct["test"]
# Out:
# <ipython-input-4-222c4df8f7fc>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# Downloading builder script:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/515 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data: 0.00B [00:00, ?B/s]
# /root/.cache/huggingface/datasets/downloads/extracted/ca045c27488b49db24426c67e0b35e06b0188746c40ffaf8d01a7b51e52924dc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Fine-Tuning Framework parameters

# %%
# The model that you want to train from the Hugging Face hub
model_name = "tiiuae/falcon-7b" ### this is falcon model



# Fine-tuned model name
new_model = "falcon-2-7b-finqa-rank-64-vj" ### This will be name of fine-tuned model

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64 ### RANK PARAMETER

# Alpha parameter for LoRA scaling
lora_alpha = 128

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = True

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps 
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = 2000

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)


# Load base model - Falcon
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
# Out:
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform the Fine-Tuning

# %%
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load  tokenizer for Falcon
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["query_key_value","dense","dense_h_to_4h","dense_4h_to_h"]
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard",
    evaluation_strategy="epoch"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=df_train,
    eval_dataset=df_eval,
    peft_config=peft_config,
    dataset_text_field="final_instruction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/4688 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1563 [00:00<?, ? examples/s]
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='1172' max='1172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1172/1172 56:37, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.785100</td>
#       <td>0.933010</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# The model that you want to train from the Hugging Face hub
model_name = "tiiuae/falcon-7b"

# Fine-tuned model name
new_model = "falcon-2-7b-finqa-rank-64-vj"


# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Push the fine-tuned model to Hugging Face hub and save it

# %%
# !huggingface-cli login

model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.89G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/vijayshankar245/falcon-2-7b-finqa-rank-64-vj/commit/d0cad86f66453cd9b5e83b5e0191505c190e85ac', commit_message='Upload tokenizer', commit_description='', oid='d0cad86f66453cd9b5e83b5e0191505c190e85ac', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# - Apply the necessary formatting on test data (Same steps which were followed for train dataset)

# %%
dataset = load_dataset("dreamerdeo/finqa",split="test")

dataset_pd = dataset.to_pandas()

def table_format(x_input):
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x):
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)





ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question']

from datasets import Dataset
test_df = Dataset.from_pandas(dataset_pd)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")

# %% [markdown]
# ### Load the fine-tuned model for evaluation

# %%
# Ignore warnings
logging.set_verbosity(logging.CRITICAL)
model = "vijayshankar245/falcon-2-7b-finqa-rank-64-vj"
tokenizer = AutoTokenizer.from_pretrained(model, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Run text generation pipeline with our next model

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer,return_full_text=False,temperature=0.1,top_p =0.9,max_new_tokens = 15)
# Out:
# tokenizer_config.json:   0%|          | 0.00/248 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.89G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/113 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform the evaluation and extract the results

# %%
import time
start_time = time.time()
from transformers.pipelines.pt_utils import KeyDataset
output_list = []
j=0
for i in pipe(KeyDataset(test_df, "final_instruction")):
  j=j+1
  print(i[0]['generated_text'])
  output_list.append(i[0]['generated_text'])
  print(j)
  df = pd.DataFrame({'output': output_list})
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ###Answer:7.6%\\n
#
# ###:\\n
# 225
#
#
# ###Answer:19.0
#
# ####question:what was the change
# 226
#
#
# ###Answer:56%\\n\\n\\n\\n
#
#
# 227
#
#
# ###Answer:1.38 billion
#
# ####question:what is the
# 228
#
#
# ###Answer:70.1%\\n\\n
#
# ####question
# 229
#
#
# ###Answer:0.5% ( 0.5
# 230
#
#
# ###Answer:14.5%\\n
#
# ####question:what
# 231
#
#
# ###Answer:33.3%\\n\\n
#
# ####question
# 232
#
#
# ###Answer:173.1 million
#
# ###Answer:173.1
# 233
#
#
# ###Answer:19%\\n
#
# ###:\\n
#
# ####
# 234
#
#
# ###Answer:1070.7
#
# ####question:what is the
# 235
# ?
#
# ###Answer:19.8
#
# ####question:what was the
# 236
#
#
# ###Answer:5.6%\\n\\n
#
# ####question
# 237
#
#
# ###Answer:19%\\n
#
# ###:\\n
#
# ####
# 238
#
#
# ###Answer:6700.0 million
#
# ###what is the growth
# 239
#
#
# ###Answer:19.3 and 17.6 million dollars respectively
# 240
# , in thousands?
#
# ###Answer:1.1 million
#
# ###
# 241
#
#
# ###Answer:0.9%\\n
#
# ###:\\n
# 242
#
#
# ###Answer:7.3%\\n\\n\\n
#
#
# 243
# ?
#
# ###Answer:4810.5
#
# ####question:what was
# 244
#
#
# ###Answer:20.7%\\n\\n\\n\\
# 245
#
#
# ###Answer:1.8% ( 1.8
# 246
#
#
# ###Answer:13.5%\\n
#
# ###:\\n
# 247
#
#
# ###Answer:5800.0
#
# ###Answer:5800.
# 248
#
#
# ###Answer:22.5% ( 22.5
# 249
#
#
# ###Answer:37.3%\\n
#
# ####question:what
# 250
#
#
# ###Answer:4.5% ( 4.5
# 251
#  options warrants and rights
#
# ###Answer:7.1:1
#
# ####
# 252
#
#
# ###Answer:11.5%\\n\\n
#
# ###:
# 253
#
#
# ###Answer:0.8% ( 0.8
# 254
#
#
# ###Answer:10.8%\\n\\n
#
# ####question
# 255
#  in other countries?
#
# ###Answer:92.5%:92.
# 256
#
#
# ###Answer:22.8%\\n
#
# ####question:what
# 257
#
#
# ###Answer:52%\\n
#
# ###:\\n
#
# ####
# 258
#
#
# ###Answer:10.2 million shares at a cost of $
# 259
#
#
# ###Answer:1.2
#
# ####question:what was the percentage
# 260
#
#
# ###Answer:1.5%\\n
#
# ###question:what
# 261
#
#
# ###Answer:13.5%\\n
#
# ####question:what
# 262
#
#
# ###Answer:11.2 million
#
# ###question:what is the
# 263
#
#
# ###Answer:2.5%\\n
#
# ###Answer:2
# 264
#
#
# ###Answer:674.0 million for 2018,
# 265
#
#
# ###Answer:14.5%\\n\\n
#
# ###:
# 266
#
#
# ###Answer:203.3
#
# ####question:what was the percentage
# 267
#
#
# ###Answer:102.5 million dollars
#
# ###:what is the
# 268
#
#
# ###Answer:4.50% ( 4.50
# 269
#
#
# ###Answer:10.5%\\n\\n
#
# ####question
# 270
#
#
# ###Answer:1.6:1.0
#
# ####question:
# 271
#
#
# ###Answer:5.5%\\n\\n\\n
#
#
# 272
# ?
#
# ###Answer:10.7%\\n
#
# ####question:
# 273
#
#
# ###Answer:107.62%\\n\\n\\n
#
#
# 274
#
#
# ###Answer:0.5%\\n\\n\\n\\
# 275
#
#
# ###Answer:0.5%\\n
#
# ####question:what
# 276
#
#
# ###Answer:89.5
#
# ####question:what was the percentage
# 277
#
#
# ###Answer:50%\\n
#
# ####question:what was the
# 278
#
#
# ###Answer:19.5%\\n
#
# ###:\\n
# 279
#
#
# ###Answer:14.5%\\n\\n
#
# ####question
# 280
#
#
# ###Answer:yes, by 1.9 million shares.
#
#
# 281
#
#
# ###Answer:105.9 million dollars
#
# ####question:what is
# 282
#
#
# ###Answer:1.1% ( 1.1
# 283
#
#
# ###Answer:5.3
#
# ####question:what is the net
# 284
#
#
# ###Answer:16.5%\\n
#
# ####question:what
# 285
#
#
# ###Answer:28.6%\\n
#
# ####question:what
# 286
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 287
#
#
# ###Answer:64001 shares and 289581 shares to employees at
# 288
#
#
# ###Answer:1.1% ( 1.1
# 289
#
#
# ###Answer:8.5%\\n\\n
#
# ###:
# 290
#
#
# ###Answer:6.5% ( 6.5
# 291
#
#
# ###Answer:49.5%\\n\\n
#
# ####question
# 292
#
#
# ###Answer:0.1% ( 0.1
# 293
#
#
# ###Answer:41.5%\\n\\n
#
# ####question
# 294
#
#
# ###Answer:2.5%\\n
#
# ###:\\n
# 295
#
#
# ###Answer:3.3%\\n\\n\\n
#
#
# 296
#
#
# ###Answer:1.2 million
#
# ####question:what was the
# 297
#
#
# ###Answer:33.3%\\n
#
# ####question:what
# 298
#  in millions?
#
# ###Answer:61.3
#
# ####question:what
# 299
#
#
# ###Answer:5.6% ( 5.6
# 300
#
#
# ###Answer:35.5%\\n
#
# ####question:what
# 301
#
#
# ###Answer:4.8
#
# ####question:what is the percentage
# 302
#
#
# ###Answer:1.7
#
# ####question:what was the percentage
# 303
#
#
# ###Answer:3.6% ( 3.6
# 304
#
#
# ###Answer:7.5%\\n\\n
#
# ###:
# 305
#
#
# ###Answer:12.2%\\n\\n
#
# ###:
# 306
#
#
# ###Answer:1.2\\n
#
# ####question:what was
# 307
#
#
# ###Answer:7.5%\\n
#
# ####question:what
# 308
#
#
# ###Answer:8.3%\\n
#
# ####question:what
# 309
#
#
# ###Answer:2.3:1
#
# ####question:what is
# 310
# ?
#
# ###Answer:1.1% ( 1.1
# 311
#
#
# ###Answer:22%\\n
#
# ###Answer:22%\\
# 312
#
#
# ###Answer:-36.3%\\n\\n\\n\\
# 313
#
#
# ###Answer:12.5% ( 12.5
# 314
#
#
# ###Answer:3.0% ( 3.0
# 315
#
#
# ###Answer:760.0
#
# ####question:what is the percentage
# 316
#
#
# ###Answer:76.33%\\n\\n
#
# ###question
# 317
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 318
#
#
# ###Answer:2.8% ( 2.8
# 319
#
#
# ###Answer:84%\\n\\n
#
# ###:what was
# 320
#
#
# ###Answer:5.6%
#
# ###:
#
# ####question:
# 321
#
#
# ###Answer:39.5%\\n
#
# ###:\\n
# 322
#
#
# ###Answer:yes, it is 5 years for purchased technology and
# 323
#
#
# ###Answer:1.2%
#
# ###Answer:1.2
# 324
#
#
# ###Answer:0.1% ( 0.1
# 325
#
#
# ###Answer:318063.5
#
# ####question:what is the
# 326
# ?
#
# ###Answer:2.3:1
#
# ####question:what
# 327
#
#
# ###Answer:1.4:1.0
#
# ####question:
# 328
#
#
# ###Answer:0.5% ( 0.5
# 329
#
#
# ###Answer:62.5%\\n
#
# ###Answer:62
# 330
#
#
# ###Answer:-1000.0
#
# ####question:what is the
# 331
# ?
#
# ###Answer:6.3%\\n\\n\\n
# 332
#
#
# ###Answer:1328.5
#
# ####question:what was the
# 333
#
#
# ###Answer:5000000
#
# ####question:what is the average
# 334
#
#
# ###Answer:-8.1
#
# ####question:what was the change
# 335
#
#
# ###Answer:8.25%\\n\\n\\n\\
# 336
#
#
# ###Answer:148.92%\\n
#
# ####question:what
# 337
#
#
# ###Answer:6.7%\\n\\n\\n\\
# 338
#  to the total trade and other accounts receivable
#
# ###Answer:2.
# 339
#  from 2013 to 2014
#
# ###Answer:7.7
# 340
#
#
# ###Answer:3.5%\\n\\n
#
# ###:
# 341
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 342
#
#
# ###Answer:5.7% ( 5.7
# 343
#
#
# ###Answer:13.6% and 20.4%\\
# 344
#
#
# ###Answer:1.1%\\n\\n
#
# ####question
# 345
# .
#
# ###Answer:1.05:1.00
#
# ####
# 346
#
#
# ###Answer:44.3\\n\\n\\n\\n
# 347
#
#
# ###Answer:1663120.5
#
# ####question:what was
# 348
#
#
# ###Answer:601.1
#
# ####question:what was the percentage
# 349
#
#
# ###Answer:10.5% ( 10.5
# 350
#
#
# ###Answer:1.2 million shares
#
# ###Answer:1.
# 351
#
#
# ###Answer:83%\\n
#
# ####question:what portion of
# 352
#
#
# ###Answer:2.1%\\n
#
# ####question:what
# 353
#
#
# ###Answer:173.7
#
# ####question:what was the percentage
# 354
#
#
# ###Answer:311.81%\\n\\n
#
# ###Answer
# 355
#
#
# ###Answer:7.5%\\n\\n\\n
#
#
# 356
#
#
# ###Answer:16.7%\\n\\n2016 gross
# 357
#
#
# ###Answer:13.5%\\n\\n
#
# ###:
# 358
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 359
#
#
# ###Answer:-1.1% ( 1.1
# 360
#
#
# ###Answer:10.7%\\n
#
# ####question:what
# 361
#
#
# ###Answer:2.6 billion
#
# ###Answer:2.6
# 362
#
#
# ###Answer:0.4%\\n\\n\\n
#
#
# 363
#
#
# ###Answer:22%\\n
#
# ####question:what portion of
# 364
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 365
#
#
# ###Answer:-2.7% ( 2.7
# 366
#
#
# ###Answer:38.94 and 37.07
#
# ####question
# 367
#
#
# ###Answer:42.50
#
# ####question:what was the percentage
# 368
#
#
# ###Answer:2000.0
#
# ####question:what was the
# 369
#
#
# ###Answer:2000000.00% ( 200000
# 370
#  contractual obligations
#
# ###Answer:57.5%\\n
#
# ####question
# 371
#
#
# ###Answer:4% ( 4 % )
#
#
# 372
#
#
# ###Answer:1.5% ( 1.5
# 373
#
#
# ###Answer:-5.8% ( 5.8
# 374
#
#
# ###Answer:1.2 billion
#
# ###Answer:1.2
# 375
#
#
# ###Answer:114.36%\\n
#
# ####question:what
# 376
# ?
#
# ###Answer:3.6% ( 3.6
# 377
#
#
# ###Answer:5.8%\\n\\n\\n\\
# 378
#
#
# ###Answer:23%\\n
#
# ####question:what was the
# 379
#
#
# ###Answer:32.73 billion
#
# ###what is the percentage change
# 380
#
#
# ###Answer:84.6%\\n\\n
#
# ####question
# 381
#
#
# ###Answer:2.5%\\n\\n
#
# ####question
# 382
#
#
# ###Answer:18.7%\\n\\n\\n\\
# 383
#
#
# ###Answer:57.5%\\n
#
# ####question:what
# 384
#  in 2008
#
# ###Answer:1.5:1.0
# 385
#  in billions?
#
# ###Answer:-19.3 billion\\n\\n
# 386
#
#
# ###Answer:1.2 million shares and 1.3 million
# 387
#
#
# ###Answer:13.5%\\n
#
# ###Answer:13
# 388
#
#
# ###Answer:1040.0
#
# ####question:what is the
# 389
#
#
# ###Answer:7.5%\\n\\n\\n
#
#
# 390
#
#
# ###Answer:2.5%\\n\\n\\n\\
# 391
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 392
#
#
# ###Answer:2.7
#
# ####question:considering the average
# 393
#
#
# ###Answer:1.2 billion
#
# ####question:what was the
# 394
#
#
# ###Answer:18178 and 24296 for 2013 and
# 396
#
#
# ###Answer:52.5%\\n
#
# ####question:what
# 397
#
#
# ###Answer:45%\\n
#
# ###:\\n\\n
# 398
#
#
# ###Answer:2.8
#
# ####question:what was the change
# 399
#
#
# ###Answer:25.0%\\n
#
# ###:\\n
# 400
#
#
# ###Answer:3.0% ( 3.0
# 401
#
#
# ###Answer:7.7
#
# ####question:what is the percentage
# 402
#
#
# ###Answer:63%\\n
#
# ###:\\n
#
# ####
# 403
#
#
# ###Answer:1.8, 1.9 and
# 404
#
#
# ###Answer:27.5%\\n\\n
#
# ###question
# 405
#
#
# ###Answer:558.5 million
#
# ####question:what is the
# 406
#
#
# ###Answer:0.6%\\n
#
# ####question:what
# 407
#
#
# ###Answer:1.2
#
# ####question:what was the change
# 408
#  that was repurchased and retired to the percent of the outstanding shares of
# 409
#
#
# ###Answer:23%\\n\\n
#
# ####question:what
# 410
#  and the assets acquired?
#
# ###Answer:118.0 million
#
# ####
# 411
#
#
# ###Answer:14.3%\\n
#
# ###:\\n
# 412
#
#
# ###Answer:61.1
#
# ###:what was the change in
# 413
#
#
# ###Answer:3.2%\\n\\n\\n
#
#
# 414
#
#
# ###Answer:1.3 years
#
# ###:what is the percentage
# 415
#
#
# ###Answer:-1180.1 million dollars
#
# ###Answer:284
# 416
#
#
# ###Answer:33.3%\\n
#
# ###:\\n
# 417
#
#
# ###Answer:37.5%\\n
#
# ###:\\n
# 418
#
#
# ###Answer:1.1%\\n
#
# ###:what was
# 419
#
#
# ###Answer:-1.5% ( 1.5
# 420
#
#
# ###Answer:31.7%\\n\\n\\n
#
#
# 421
#
#
# ###Answer:13.00$
#
# ###question:what was the
# 422
#
#
# ###Answer:57%\\n
#
# ####question:what is the
# 423
#
#
# ###Answer:9.5 million
#
# ####question:what is the
# 424
#
#
# ###Answer:2380.5
#
# ###:what was the percentage
# 425
#
#
# ###Answer:6.7%\\n
#
# ####question:what
# 426
#
#
# ###Answer:yes
#
# ####question:what was the percentage cumulative total
# 427
#
#
# ###Answer:7.5% ( 7.5
# 428
#
#
# ###Answer:1837.5
#
# ###:what was the percentage
# 429
#
#
# ###Answer:5.7% ( 5.7
# 430
#  at the end of the year
#
# ###Answer:5.7%\\
# 431
#
#
# ###Answer:10.6%\\n\\n
#
# ####question
# 432
#
#
# ###Answer:0.5%\\n
#
# ###:\\n
# 433
#
#
# ###Answer:7.5%\\n
#
# ###:\\n
# 434
#
#
# ###Answer:1.2% ( 1.2
# 435
#
#
# ###Answer:19.5%\\n
#
# ###question:what
# 436
#
#
# ###Answer:13.5$
#
# ###Answer:13.5
# 437
#
#
# ###Answer:78.8%\\n
#
# ####question:what
# 438
#
#
# ###Answer:3.5 million
#
# ####question:what was the
# 439
#
#
# ###Answer:14000
#
# ####question:what is the approximate total
# 440
#
#
# ###Answer:8.9%\\n
#
# ####question:what
# 441
#
#
# ###Answer:1.6% ( 1.6
# 442
#
#
# ###Answer:8.6
#
# ###what is the growth rate in
# 443
#
#
# ###Answer:1.2 billion
#
# ####question:what is the
# 444
#
#
# ###Answer:83.5 and 91.3
#
# ####question
# 445
#
#
# ###Answer:27.5%\\n
#
# ####question:what
# 446
#
#
# ###Answer:5.0%\\n\\n\\n
#
#
# 447
#
#
# ###Answer:0.6% ( 0.6
# 448
#
#
# ###Answer:1.2 million shares
#
# ####question:what is
# 449
#
#
# ###Answer:$ 180993.5
#
# ###Answer:180
# 450
#
#
# ###Answer:0.25% ( 0.25
# 451
#
#
# ###Answer:15.5% ( 15.5
# 452
#
#
# ###Answer:9.1% ( 9.1
# 453
#
#
# ###Answer:10% ( 10 % )
# 454
#
#
# ###Answer:1.2 billion
#
# ###Answer:1.2
# 455
#
#
# ###Answer:9.6% ( 9.6
# 456
#
#
# ###Answer:5.87 and 5.87 billion dollars respectively
# 457
#
#
# ###Answer:13.5% ( 13.5
# 458
#
#
# ###Answer:18.5%\\n
#
# ####question:what
# 459
#
#
# ###Answer:2.5%\\n\\n\\n\\
# 460
#
#
# ###Answer:70.6% ( 70.6
# 461
#
#
# ###Answer:1020.7% ( 1020.
# 462
#
#
# ###Answer:12.5% ( 12.5
# 463
# ?
#
# ###Answer:7.5%\\n\\n\\n
# 464
#
#
# ###Answer:0.5% ( 0.5
# 465
#
#
# ###Answer:-68.8% ( 68.8
# 466
# ?
#
# ###Answer:0.7% ( 0.7
# 467
#
#
# ###Answer:1.2 million dollars
#
# ####question:what is
# 468
#
#
# ###Answer:1.2%\\n
#
# ####question:what
# 469
#
#
# ###Answer:314.36%\\n
#
# ###Answer:314
# 470
#
#
# ###Answer:3802 and 5190 respectively.
#
# ####question
# 471
#
#
# ###Answer:13.2%\\n
#
# ####question:what
# 472
#
#
# ###Answer:75.5% ( 75.5
# 473
#
#
# ###Answer:47.3
#
# ####question:what is the estimated
# 474
#
#
# ###Answer:9.1% ( 9.1
# 475
#
#
# ###Answer:5.97
#
# ####question:what is the growth
# 476
#
#
# ###Answer:10.5%\\n\\n
#
# ###:
# 477
#
#
# ###Answer:47.5 and 47.3
#
# ####question
# 478
#
#
# ###Answer:44.7 billion\\n
#
# ###Answer:44
# 479
# ?
#
# ###Answer:1.1% ( 1.1
# 480
#
#
# ###Answer:-1.2% ( 1.2
# 481
#
#
# ###Answer:37.3%\\n
#
# ####question:what
# 482
#
#
# ###Answer:180.7%\\n\\n\\n\\
# 483
#
#
# ###Answer:0.5% ( 0.5
# 484
#
#
# ###Answer:1.3
#
# ####question:what was the percentage
# 485
# ?
#
# ###Answer:33% ( 33 % )
# 486
#
#
# ###Answer:91.5%\\n\\n
#
# ####question
# 487
#
#
# ###Answer:3900000\\n
#
# ###Answer:390000
# 488
#
#
# ###Answer:897.3
#
# ####question:what was the percentage
# 489
#
#
# ###Answer:57%\\n
#
# ####question:what percentage of
# 490
#
#
# ###Answer:2.1% ( 2.1
# 491
#
#
# ###Answer:5.3% ( 5.3
# 492
#
#
# ###Answer:33.33%\\n
#
# ####question:what
# 493
#  in millions?
#
# ###Answer:67.3
#
# ####question:what
# 494
#
#
# ###Answer:9.5% ( 9.5
# 495
#
#
# ###Answer:23.5%\\n\\n\\n
#
#
# 496
#
#
# ###Answer:7.1%\\n
#
# ###:\\n
# 497
#
#
# ###Answer:7.7%\\n
#
# ###:\\n
# 498
#
#
# ###Answer:27885
#
# ####question:what was the percentage change
# 499
#
#
# ###Answer:22176 and 27885
#
# ####question:what
# 500
#
#
# ###Answer:15.5
#
# ####question:what was the percentage
# 501
#
#
# ###Answer:36%\\n
#
# ###question:what percentage of
# 502
#
#
# ###Answer:0.7% and 0.5% respectively
# 503
#
#
# ###Answer:0.1%\\n
#
# ####question:what
# 504
#
#
# ###Answer:0.6:1.0
#
# ###:what
# 505
#
#
# ###Answer:25%\\n
#
# ####question:what percentage of
# 506
#
#
# ###Answer:133.65%\\n
#
# ####question:what
# 507
#
#
# ###Answer:1029.6 million
#
# ####question:what was
# 508
#
#
# ###Answer:2.5%\\n
#
# ####question:what
# 509
#
#
# ###Answer:3.9% ( 3.9
# 510
#
#
# ###Answer:-7.8 billion
#
# ####question:what was the
# 511
#
#
# ###Answer:yes
#
# ####question:what was the percentage cumulative total
# 512
# ?
#
# ###Answer:0.82:1.00
#
# ####question
# 513
#
#
# ###Answer:3.1%\\n
#
# ###Answer:3
# 514
#
#
# ###Answer:1589.5 million dollars
#
# ###:what is
# 515
#
#
# ###Answer:0.1% ( 0.1
# 516
#  as the continued credit crisis impacted the availability of observable inputs for the underlying securities
# 517
#
#
# ###Answer:2.5 years
#
# ###:what was the percentage
# 518
#
#
# ###Answer:-32.3% ( 32.3
# 519
#  or sub-lease
#
# ###Answer:33.3%\\n
#
#
# 520
#
#
# ###Answer:2.5:1.0
#
# ####question:
# 521
#
#
# ###Answer:7.3% ( 7.3
# 522
#
#
# ###Answer:9.5%\\n
#
# ####question:what
# 523
#
#
# ###Answer:5.5%\\n\\n\\n
#
#
# 524
#
#
# ###Answer:23%\\n\\n\\n
#
# ####question
# 525
#
#
# ###Answer:1.5% ( 1.5
# 526
#
#
# ###Answer:78.8%\\n
#
# ####question:what
# 527
#
#
# ###Answer:$ 373.67
#
# ####question:what is
# 528
# ?
#
# ###Answer:0.2 - 0.3
# 529
#
#
# ###Answer:61.5%\\n
#
# ###:\\n
# 530
#
#
# ###Answer:7.8% ( 7.8
# 531
#
#
# ###Answer:1%\\n
#
# ####question:what was the
# 532
#
#
# ###Answer:14.7%\\n
#
# ####question:what
# 533
#
#
# ###Answer:1.6 million
#
# ####question:what is the
# 534
#  in millions
#
# ###Answer:14.2 million
#
# ####question:what
# 535
#
#
# ###Answer:1024000000.00
#
# ####question:what
# 536
#
#
# ###Answer:2.3% ( 2.3
# 537
#
#
# ###Answer:11.5%\\n\\nfor future lease
# 538
#
#
# ###Answer:148.92%\\n\\n
#
# ####question
# 539
#
#
# ###Answer:31.7%\\n\\n\\n
#
#
# 540
#
#
# ###Answer:3.5% ( 3.5
# 541
# ?
#
# ###Answer:1.1:1.0
#
# ####question
# 542
#
#
# ###Answer:14.5%\\n
#
# ####question:what
# 543
#
#
# ###Answer:16.7% ( 16.7
# 544
#
#
# ###Answer:65.5%\\n
#
# ####question:what
# 545
#
#
# ###Answer:16000
#
# ####question:what is the total number
# 546
#
#
# ###Answer:1.1% ( 1.1
# 547
#
#
# ###Answer:15.6%\\n
#
# ###:what percentage
# 548
# ?
#
# ###Answer:0.5% ( 0.5
# 549
#
#
# ###Answer:-3.8% ( 3.8
# 550
#
#
# ###Answer:27.3%\\n\\n\\n\\
# 551
#
#
# ###Answer:1.7%\\n\\n
#
# ####question
# 552
#
#
# ###Answer:1.7
#
# ####question:what was the ratio
# 553
#
#
# ###Answer:3.87% ( 3.87
# 554
#
#
# ###Answer:1.3:1.0
#
# ####question:
# 555
#
#
# ###Answer:6.79%\\n
#
# ####question:what
# 556
#
#
# ###Answer:13.5$
#
# ####question:what is the
# 557
#
#
# ###Answer:1.1% ( 1.1
# 558
# ?
#
# ###Answer:5000000
#
# ####question:what is the
# 559
#
#
# ###Answer:1.1%\\n
#
# ####question:what
# 560
#
#
# ###Answer:32.5%\\n
#
# ####question:what
# 561
#
#
# ###Answer:0.7% ( 0.7
# 562
#
#
# ###Answer:32.9% ( 32.9
# 563
#
#
# ###Answer:49.5%\\n
#
# ####question:what
# 564
#
#
# ###Answer:3.6%\\n
#
# ####question:what
# 565
#
#
# ###Answer:31.3% ( 31.3
# 566
#
#
# ###Answer:0.1%\\n
#
# ###:\\n
# 567
#
#
# ###Answer:12.5%\\n\\n
#
# ###:
# 568
#
#
# ###Answer:yes it is, by 1 year.
#
#
# 569
#  for the year 2005
#
# ###Answer:1.1%\\
# 570
#  obligations that was due in 2013
#
# ###Answer:8.9
# 571
#
#
# ###Answer:3.2
#
# ####question:what was the percentage
# 572
# ?
#
# ###Answer:2.3\\n\\n\\n
#
#
# 573
#
#
# ###Answer:16.7%\\n\\n
#
# ####question
# 574
#
#
# ###Answer:6.5
#
# ###:what was the average value
# 575
#
#
# ###Answer:3.5%\\n
#
# ####question:what
# 576
#
#
# ###Answer:1.2 million dollars
#
# ####question:what is
# 577
#
#
# ###Answer:2.2:1.0
#
# ####question:
# 578
#
#
# ###Answer:14.5%\\n\\n
#
# ####question
# 579
#  in 2017?
#
# ###Answer:35.6% (
# 580
#
#
# ###Answer:7.5%\\n\\n\\n\\
# 581
#
#
# ###Answer:1.1%\\n
#
# ###:what was
# 582
#
#
# ###Answer:13.5%\\n
#
# ####question:what
# 583
#
#
# ###Answer:1.1 million
#
# ####question:what is the
# 584
#
#
# ###Answer:2.5%\\n
#
# ####question:what
# 585
#
#
# ###Answer:7.1
#
# ####question:what is the net
# 586
#
#
# ###Answer:-1.8% ( 1.8
# 587
#
#
# ###Answer:7.9%\\n
#
# ###:what is
# 588
#
#
# ###Answer:2129.7\\n250.0\\n
# 589
#
#
# ###Answer:184.5
#
# ####question:what was the ratio
# 590
#
#
# ###Answer:1.6%\\n
#
# ###:\\n
# 591
# ?
#
# ###Answer:2.5:1.0
#
# ####question
# 592
#
#
# ###Answer:7.5%\\n\\n\\n\\
# 593
#
#
# ###Answer:0.6:1.0
#
# ####question:
# 594
# , in millions?
#
# ###Answer:102.5
#
# ####question
# 595
#
#
# ###Answer:6.9
#
# ####question:what was the percentage
# 596
#
#
# ###Answer:383.3
#
# ####question:what was the percentage
# 597
#
#
# ###Answer:-9% ( 9 % )\\
# 598
#
#
# ###Answer:19.4%\\n\\n
#
# ####question
# 599
#
#
# ###Answer:88.8%\\n
#
# ####question:what
# 600
#
#
# ###Answer:14.3%\\n\\n\\n\\
# 601
#
#
# ###Answer:1.2 million dollars
#
# ####question:what is
# 602
#
#
# ###Answer:153.6 and $ 153.6
#
#
# 603
#
#
# ###Answer:1.7:1.0
#
# ####question:
# 604
#
#
# ###Answer:1200000.0
#
# ####question:what is
# 605
#
#
# ###Answer:18.9%\\n\\n\\n
#
#
# 606
#
#
# ###Answer:25.5%\\n
#
# ####question:what
# 607
#  that remained unissued
#
# ###Answer:19.5%\\n
#
#
# 608
#
#
# ###Answer:41.5%\\n
#
# ####question:what
# 609
#
#
# ###Answer:0.1
#
# ####question:what was the net
# 610
#
#
# ###Answer:4.5 billion
#
# ####question:what was the
# 611
#
#
# ###Answer:35%\\n\\n
#
# ###:what percentage
# 612
#
#
# ###Answer:$ 6001.5 million
#
# ####question:
# 613
# ?
#
# ###Answer:14.3%\\n\\n\\n
# 614
#
#
# ###Answer:52%\\n
#
# ###:\\n
#
# ####
# 615
#
#
# ###Answer:32.5
#
# ####question:what is the average
# 616
#
#
# ###Answer:19.5%\\n\\n\\n
#
#
# 617
#
#
# ###Answer:0.44%\\n\\n\\n\\
# 618
#
#
# ###Answer:104.3%\\n
#
# ####question:what
# 619
#
#
# ###Answer:7670.3
#
# ####question:what was the
# 620
#
#
# ###Answer:6.5%\\n\\n\\n
#
#
# 621
#
#
# ###Answer:21.46%\\n\\n
#
# ###question
# 622
#
#
# ###Answer:7.5%\\n\\n\\n\\
# 623
#
#
# ###Answer:1.2
#
# ####question:what was the percentage
# 624
#
#
# ###Answer:6.7%\\n\\n\\n
#
#
# 625
#
#
# ###Answer:yes, it was 76% in 201
# 626
#
#
# ###Answer:yes, by $ 4096.
#
# ###
# 627
# ?
#
# ###Answer:14% ( 14 % )
# 628
#
#
# ###Answer:yes
#
# ####question:what is the percentage change in
# 629
#
#
# ###Answer:1.1 billion
#
# ####question:what was the
# 630
#
#
# ###Answer:7.5% ( 7.5
# 631
#
#
# ###Answer:7.3% ( 7.3
# 632
#
#
# ###Answer:8.3% ( 8.3
# 633
#
#
# ###Answer:66.7%\\n
#
# ####question:what
# 634
#  in net revenue from 2014 to 2015
#
# ###Answer:
# 635
#
#
# ###Answer:7.5% ( 7.5
# 636
#  of the stock options
#
# ###Answer:1.5:1.0
# 637
#
#
# ###Answer:538.0
#
# ####question:what is the total
# 638
#
#
# ###Answer:10.8%\\n\\n
#
# ####question
# 639
#
#
# ###Answer:1.3% ( 1.3
# 640
#
#
# ###Answer:49.5%\\n\\n
#
# ###:
# 641
# ?
#
# ###Answer:14.3% ( 14.3
# 642
# ?
#
# ###Answer:19.9%\\n
#
# ####question:
# 643
#
#
# ###Answer:3.4% ( 3.4
# 644
#
#
# ###Answer:24.6%\\n\\nwhat is the
# 645
# ?
#
# ###Answer:1.1% ( 1.1
# 646
#
#
# ###Answer:1.2 billion
#
# ####question:what was the
# 647
#
#
# ###Answer:65.9%\\n\\n
#
# ####question
# 648
#
#
# ###Answer:nope.
#
# ###correct:no. the change
# 649
#
#
# ###Answer:61.5%\\n\\n
#
# ###:
# 650
#
#
# ###Answer:1.1% ( 1.1
# 651
#
#
# ###Answer:88.5%\\n\\n
#
# ###:
# 652
#
#
# ###Answer:1.8 billion dollars
#
# ###: what is the
# 653
#
#
# ###Answer:2.8%\\n
#
# ####question:what
# 654
#
#
# ###Answer:4%\\n
#
# ###:\\n\\n
# 655
#
#
# ###Answer:2.2% ( 2.2
# 656
#
#
# ###Answer:14.5%\\n\\n\\n
#
#
# 657
# ?
#
# ###Answer:3.5
#
# ####question:what was the
# 658
#
#
# ###Answer:108.4%\\n
#
# ###question:what
# 659
#
#
# ###Answer:13.5%\\n\\n
#
# ###:
# 660
#
#
# ###Answer:1.1 million
#
# ###:what is the percentage
# 661
#
#
# ###Answer:6.7%\\n\\n\\n
#
#
# 662
#
#
# ###Answer:2.5% ( 2.5
# 663
#
#
# ###Answer:-12.7
#
# ####question:what was the change
# 664
#
#
# ###Answer:33% ( 33 % )
#
#
# 665
#
#
# ###Answer:5.3% ( 5.3
# 666
#
#
# ###Answer:6.73%\\n\\n\\n
#
#
# 667
#
#
# ###Answer:1180.5\\n
#
# ####question:what
# 668
#
#
# ###Answer:91.7%\\n\\n
#
# ####question
# 669
#
#
# ###Answer:1.2%\\n\\n
#
# ###:
# 670
#
#
# ###Answer:0.5% ( 0.5
# 671
# ?
#
# ###Answer:66.7%\\n\\n
#
# ####
# 672
#
#
# ###Answer:2229188.8
#
# ####question:what was
# 673
#
#
# ###Answer:102.45%\\n\\n\\n\\
# 674
#
#
# ###Answer:21%\\n\\n\\n
#
# ###:
# 675
#
#
# ###Answer:57.5%\\n\\n
#
# ####question
# 676
#
#
# ###Answer:0.7%\\n
#
# ####question:what
# 677
# ?
#
# ###Answer:6.7%\\n
#
# ####question:
# 678
#
#
# ###Answer:23.5%\\n
#
# ####question:what
# 679
#
#
# ###Answer:-2.9
#
# ####question:what was the change
# 680
#
#
# ###Answer:61.5%\\n
#
# ###:\\n
# 681
#
#
# ###Answer:295.6
#
# ####question:what is the net
# 682
#
#
# ###Answer:7.5%\\n
#
# ####question:what
# 683
#  on the sale of approximately 4.9 million mastercard class b shares
# 684
#
#
# ###Answer:2000000.5
#
# ####question:what is
# 685
#  shares
#
# ###Answer:3.9%\\n
#
# ####question:
# 686
#
#
# ###Answer:599.2
#
# ####question:what was the percentage
# 687
#
#
# ###Answer:47800.0
#
# ###:what is the percentage
# 688
#
#
# ###Answer:7.5% ( 7.5
# 689
#
#
# ###Answer:46961.0
#
# ####question:what was the
# 690
#
#
# ###Answer:27.9%\\n
#
# ####question:what
# 691
#
#
# ###Answer:58%\\n\\n
#
# ###:\\n
# 692
# ?
#
# ###Answer:7.5%\\n\\n\\n
# 693
# ?
#
# ###Answer:10.9%\\n\\n
#
# ####
# 694
#
#
# ###Answer:5.5%\\n
#
# ####question:what
# 695
#
#
# ###Answer:24%\\n
#
# ####question:what was the
# 696
# ?
#
# ###Answer:5.6%\\n\\n\\n
# 697
#
#
# ###Answer:2.5% ( 2.5
# 698
#
#
# ###Answer:1.1% ( 1.1
# 699
#
#
# ###Answer:5.6%\\n
#
# ####question:what
# 700
#
#
# ###Answer:1.1:1.0
#
# ####question:
# 701
#
#
# ###Answer:107.5
#
# ####question:what is the percentage
# 702
#
#
# ###Answer:11%\\n
#
# ####question:what was the
# 703
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 704
#
#
# ###Answer:15.6%\\n
#
# ####question:what
# 705
#
#
# ###Answer:8.3%\\n\\n\\n\\
# 706
#
#
# ###Answer:4.5 million shares
#
# ###Answer:4.
# 707
#
#
# ###Answer:0.8%\\n
#
# ####question:what
# 708
#
#
# ###Answer:32.5
#
# ####question:what was the percentage
# 709
#
#
# ###Answer:10.5%\\n\\n\\n\\
# 710
#
#
# ###Answer:92.5% ( 92.5
# 711
#
#
# ###Answer:1.8:1
#
# ####question:what was
# 712
#
#
# ###Answer:44.72\\n52.25\\n39
# 713
# ?
#
# ###Answer:218.3
#
# ####question:what was the
# 714
# ?
#
# ###Answer:1.1 billion
#
# ####question:what was
# 715
#
#
# ###Answer:2.1 million shares per registered holder as of feb
# 716
#
#
# ###Answer:31.5% ( 31.5
# 717
#
#
# ###Answer:65.5%\\n
#
# ####question:what
# 718
# , for the next five years and thereafter
#
# ###Answer:13.
# 719
#
#
# ###Answer:37.5%\\n
#
# ###:\\n
# 720
#
#
# ###Answer:51.5%\\n
#
# ###:\\n
# 721
#
#
# ###Answer:1.1%\\n\\n
#
# ###:
# 722
#
#
# ###Answer:11.1%\\n
#
# ####question:what
# 723
# ?
#
# ###Answer:1.5:1.0
#
# ####question
# 724
#
#
# ###Answer:153258.
#
# ###question:what is the total
# 725
#  shares?
#
# ###Answer:42.96$
#
# ####question:what
# 726
#
#
# ###Answer:12.5%\\n
#
# ####question:what
# 727
#
#
# ###Answer:5.6%\\n
#
# ####question:what
# 728
#
#
# ###Answer:5.0%\\n\\n
#
# ####question
# 729
#
#
# ###Answer:1.2 billion
#
# ####question:what was the
# 730
#
#
# ###Answer:129.0 million
#
# ####question:what was the
# 731
#
#
# ###Answer:9.7%\\n
#
# ###:what was
# 732
# ?
#
# ###Answer:0.6%\\n
#
# ####question:
# 733
#
#
# ###Answer:2061.0
#
# ####question:what is the
# 734
# , 2015 to 10 balance at december 31,
# 735
#
#
# ###Answer:28.6
#
# ####question:what was the percentage
# 736
#
#
# ###Answer:1.2 million shares of common stock.
#
# ####
# 737
#
#
# ###Answer:0.7 billion dollars
#
# ####question:what was
# 738
#
#
# ###Answer:227.5
#
# ###:what is the percentage change
# 739
#
#
# ###Answer:5.3%\\n
#
# ####question:what
# 740
#
#
# ###Answer:1.2 billion
#
# ####question:what is the
# 741
# ?
#
# ###Answer:98.6%\\n
#
# ####question:
# 742
#
#
# ###Answer:57%\\n\\n\\n\\n\\
# 743
#
#
# ###Answer:33.1%\\n\\nfor the year
# 744
#  to 2011
#
# ###Answer:16.7%\\n
#
#
# 745
#
#
# ###Answer:1.5 million
#
# ###Answer:1.5
# 746
#
#
# ###Answer:10.0
#
# ####question:what is the difference
# 747
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 748
#
#
# ###Answer:75.1%\\n
#
# ###:what was
# 749
#
#
# ###Answer:8.5%\\n
#
# ####question:what
# 750
#
#
# ###Answer:yes, by $ 1.4 million.
# 751
#
#
# ###Answer:27.3%\\n\\n\\n\\
# 752
#
#
# ###Answer:95.5%\\n\\n
#
# ###:
# 753
#
#
# ###Answer:0.1%\\n
#
# ###question:what
# 754
#
#
# ###Answer:11.8%\\n
#
# ###:\\n
# 755
#
#
# ###Answer:3.6%\\n\\n\\n\\
# 756
#
#
# ###Answer:32.5% ( 32.5
# 757
#
#
# ###Answer:1.2
#
# ####question:what is the total
# 758
# ?
#
# ###Answer:3.6% ( 3.6
# 759
# ?
#
# ###Answer:35.7% ( 35.7
# 760
#
#
# ###Answer:12.5 million and $ 38.5
# 761
#
#
# ###Answer:1.2 million\\n
#
# ###question:what
# 762
#
#
# ###Answer:9.0 million of unfavorable foreign currency impact during
# 763
#
#
# ###Answer:3799.5
#
# ####question:what was the
# 764
#
#
# ###Answer:1180.5\\n
#
# ####question:what
# 765
#
#
# ###Answer:23.9%\\n
#
# ####question:what
# 766
#
#
# ###Answer:5.5%\\n\\n\\n
#
#
# 767
#
#
# ###Answer:1.1% ( 1.1
# 768
#
#
# ###Answer:6.5%\\n\\n
#
# ###:
# 769
#
#
# ###Answer:11.1%\\n
#
# ####question:what
# 770
#
#
# ###Answer:14.3%\\n
#
# ####question:what
# 771
#
#
# ###Answer:8.5%\\n\\n
#
# ###:
# 772
#
#
# ###Answer:1000000.00
#
# ####question:what was
# 773
#
#
# ###Answer:65.7%\\n
#
# ###:\\n
# 774
#
#
# ###Answer:1.1%\\n
#
# ####question:what
# 775
#
#
# ###Answer:5.6%\\n\\n\\n
#
#
# 776
#
#
# ###Answer:5.6%\\n\\n\\n
#
#
# 777
#
#
# ###Answer:0.25% ( 0.25
# 778
#
#
# ###Answer: $ 2.5 billion
#
# ####question:
# 779
#
#
# ###Answer:8.9%\\n
#
# ###:\\n
# 780
#
#
# ###Answer:1.5 billion dollars
#
# ###:what was the
# 781
#
#
# ###Answer:0.1%\\n
#
# ###:what is
# 782
#
#
# ###Answer:49.5%\\n\\n
#
# ####question
# 783
#
#
# ###Answer:1.1%\\n
#
# ####question:what
# 784
#
#
# ###Answer:-$ ( 12389 )
#
# ####question
# 785
#
#
# ###Answer:2.2
#
# ###:what was the percentage change
# 786
#
#
# ###Answer:10.5%\\n\\n
#
# ###Answer
# 787
#
#
# ###Answer:7.1
#
# ####question:what is the percentage
# 788
#
#
# ###Answer:12.5%\\n
#
# ####question:what
# 789
#
#
# ###Answer:28% ( 28 % ) in
# 790
#
#
# ###Answer:1.1% ( 1.1
# 791
# ?
#
# ###Answer:153.5%\\n
#
# ###Answer:
# 792
#
#
# ###Answer:1.2 million
#
# ####question:what is the
# 793
#
#
# ###Answer:11.3%\\n\\n\\n
#
#
# 794
#
#
# ###Answer:2.5%\\n\\n
#
# ###:
# 795
#
#
# ###Answer:0.3% ( 0.3
# 796
#
#
# ###Answer:0.3:1.0
#
# ####question:
# 797
#
#
# ###Answer:33.7\\n
#
# ###Answer:33.
# 798
#
#
# ###Answer:5.7%\\n
#
# ####question:what
# 799
#
#
# ###Answer:2.1%\\n
#
# ####question:what
# 800
#
#
# ###Answer:8304.5
#
# ####question:what was the
# 801
# ?
#
# ###Answer:9.4 million
#
# ###:what was the
# 802
#
#
# ###Answer:5.6%\\n
#
# ####question:what
# 803
#
#
# ###Answer:1000000000.0
#
# ####question:what
# 804
# ?
#
# ###Answer:2.1:1.0
#
# ####question
# 805
# ?
#
# ###Answer:1.2 billion dollars
#
# ####question:what
# 806
#
#
# ###Answer:2014.5 million
#
# ####question:what is
# 807
#
#
# ###Answer:0.1% ( 0.1
# 808
#
#
# ###Answer:72.5%\\n\\n
#
# ###question
# 809
#
#
# ###Answer:3.5%\\n
#
# ###:what is
# 810
#
#
# ###Answer:3772.5\\n\\n
#
# ###Answer
# 811
#
#
# ###Answer:1.5
#
# ####question:what is the total
# 812
#
#
# ###Answer:43.81% ( 43.81
# 813
#
#
# ###Answer:52%\\n
#
# ###:\\n\\n
# 814
#
#
# ###Answer:56%\\n\\n
#
# ####question:what
# 815
#
#
# ###Answer:1.1%\\n
#
# ###Answer:1
# 816
#
#
# ###Answer:0.85% ( 0.85
# 817
# \\n\\n\\n\\n\\n\\n\\n\\
# 818
#
#
# ###Answer:114% ( 114 % )
#
#
# 819
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 820
#
#
# ###Answer:1.5 million
#
# ####question:what is the
# 821
#
#
# ###Answer:3.8
#
# ####question:what is the percentage
# 822
#
#
# ###Answer:67.92%\\n
#
# ####question:what
# 823
#
#
# ###Answer:52.6%\\n
#
# ####question:what
# 824
#
#
# ###Answer:19251.0\\n
#
# ####question:what
# 825
#
#
# ###Answer:3.5%\\n
#
# ###question:what
# 826
#
#
# ###Answer:92.49%\\n
#
# ####question:what
# 827
#
#
# ###Answer:7.5% ( 7.5
# 828
#
#
# ###Answer:2.5%\\n\\n\\n
#
#
# 829
#
#
# ###Answer:5.6%\\n\\n\\n
#
#
# 830
#
#
# ###Answer:2.6:1.0
#
# ####question:
# 831
#
#
# ###Answer:45%\\n
#
# ###:\\n\\n
# 832
#
#
# ###Answer:7.5%\\n
#
# ###:\\n
# 833
#
#
# ###Answer:311.81$
#
# ####question:what is the
# 834
#
#
# ###Answer:3.1
#
# ####question:what is the total
# 835
#
#
# ###Answer:102.6
#
# ####question:what is the percentage
# 836
# ?
#
# ###Answer:63.5%\\n\\n
#
# ####
# 837
#
#
# ###Answer:61.27 2013 $ 63.
# 838
#
#
# ###Answer:15.5%\\n\\n
#
# ###:
# 839
#
#
# ###Answer:67.5%\\n
#
# ####question:what
# 840
#
#
# ###Answer:20.5%\\n
#
# ####question:what
# 841
#
#
# ###Answer:52%\\n\\n\\n
#
# ####question
# 842
#
#
# ###Answer:114% ( 114 % )
#
#
# 843
#
#
# ###Answer:7.5
#
# ####question:what is the annual
# 844
#
#
# ###Answer:20%\\n\\n\\n
#
# ###Answer
# 845
#  500
#
# ###Answer:1.9:1.0
#
# ####
# 846
#
#
# ###Answer:52%\\n
#
# ###:\\n\\n
# 847
#  of 2014?
#
# ###Answer:9.1%\\n
# 848
#
#
# ###Answer:7.3% ( 7.3
# 849
#
#
# ###Answer:0.5%\\n\\n\\n
#
#
# 850
#
#
# ###Answer:6.5%\\n
#
# ####question:what
# 851
#
#
# ###Answer:59.4 billion
#
# ###Answer:59.4
# 852
# ?
#
# ###Answer:327.8 million
#
# ####question:what was
# 853
#
#
# ###Answer:12.5%\\n
#
# ###:\\n
# 854
#
#
# ###Answer:7.0
#
# ####question:what was the percentage
# 855
#  for sikorsky?
#
# ###Answer:7.1%\\
# 856
#
#
# ###Answer:0.5% ( 0.5
# 857
#
#
# ###Answer:1.1% ( 1.1
# 858
#
#
# ###Answer:-47.5 million dollars
#
# ###:what is the
# 859
#
#
# ###Answer:33.3%\\n
#
# ####question:what
# 860
#
#
# ###Answer:33.3%\\n\\n
#
# ###:
# 861
#
#
# ###Answer:138.5
#
# ####question:what is the percentage
# 862
#
#
# ###Answer:1.5:1.0:1.0
# 863
#
#
# ###Answer:127.1 million dollars
#
# ###:what was the
# 864
#
#
# ###Answer:10.6%\\n
#
# ###:\\n
# 865
#
#
# ###Answer:3.1%\\n
#
# ####question:what
# 866
#
#
# ###Answer:yes, by a factor of 2.5
# 867
#
#
# ###Answer:13.5%\\n
#
# ####question:what
# 868
#
#
# ###Answer:6800.5\\n\\n\\n\\
# 869
#
#
# ###Answer:5830.0 million
#
# ####question:what is
# 870
#
#
# ###Answer:5.5%\\n\\n\\n\\
# 871
#
#
# ###Answer:56.5%\\n
#
# ####question:what
# 872
#
#
# ###Answer:3.3, 3.3,
# 873
#
#
# ###Answer:5.5%\\n\\n\\n
#
#
# 874
#
#
# ###Answer:13.5%\\n
#
# ####question:what
# 875
#
#
# ###Answer:56%\\n\\n\\n\\n
#
#
# 876
#
#
# ###Answer:33.3%\\n
#
# ####question:what
# 877
# ?
#
# ###Answer:3199.5
#
# ####question:what was
# 878
#
#
# ###Answer:37.5%\\n
#
# ####question:what
# 879
# \\n
#
# ###Answer:14173.5
#
# ####question:what
# 880
#
#
# ###Answer:0.1% ( 0.1
# 881
#
#
# ###Answer:13.6% ( 13.6
# 882
#
#
# ###Answer:0.7:1
#
# ####question:what was
# 883
#
#
# ###Answer:13.5%\\n
#
# ###Answer:13
# 884
#
#
# ###Answer:13.6%\\n
#
# ####question:what
# 885
# ?
#
# ###Answer:2.4
#
# ####question:what was the
# 886
#
#
# ###Answer:56.7%\\n\\n
#
# ###Answer
# 887
#
#
# ###Answer:6.8
#
# ####question:what is the growth
# 888
#
#
# ###Answer:yes
#
# ####question:what was the percentage change in
# 889
#
#
# ###Answer:yes, by 76.32% (
# 890
#  allocation?
#
# ###Answer:10.0% ( 10.
# 891
#
#
# ###Answer:1.345 billion
#
# ###Answer:1.345
# 892
#
#
# ###Answer:1.2 billion in 2016 and 1
# 893
#
#
# ###Answer:108.5 million
#
# ####question:what was the
# 894
#
#
# ###Answer:1.7:1
#
# ####question:what was
# 895
#
#
# ###Answer:2.89 years
#
# ####question:what is the
# 896
#
#
# ###Answer:1.2 million
#
# ####question:what is the
# 897
#
#
# ###Answer:32.5%\\n\\n
#
# ###:
# 898
#
#
# ###Answer:28.5%\\n
#
# ####question:what
# 899
#
#
# ###Answer:3.5% ( 3.5
# 900
#
#
# ###Answer:yes, by 2.5% (
# 901
#
#
# ###Answer:82.9%\\n
#
# ####question:what
# 902
#
#
# ###Answer:2.1%\\n\\n
#
# ####question
# 903
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 904
#
#
# ###Answer:2.5
#
# ####question:what is the average
# 905
# ?
#
# ###Answer:2.6% ( 2.6
# 906
#
#
# ###Answer:1.4:1.0
#
# ####question:
# 907
#
#
# ###Answer:43.5%\\n
#
# ###:\\n
# 908
#
#
# ###Answer:10.7%\\n\\n
#
# ###:
# 909
#
#
# ###Answer:1.1%\\n
#
# ####question:what
# 910
#
#
# ###Answer:7.5%\\n
#
# ####question:what
# 911
#
#
# ###Answer:19.7 million dollars
#
# ####question:what is
# 912
#
#
# ###Answer:0.1% ( 0.1
# 913
#
#
# ###Answer:0.1%\\n\\n
#
# ###:
# 914
#
#
# ###Answer:46.6%\\n
#
# ###:\\n
# 915
#
#
# ###Answer:83.1% ( 83.1
# 916
#
#
# ###Answer:5.6% ( 5.6
# 917
#
#
# ###Answer:56%\\n\\n
#
# ####question:what
# 918
#
#
# ###Answer:0.1%\\n
#
# ####question:what
# 919
#
#
# ###Answer:9.5%\\n\\n\\n\\
# 920
#
#
# ###Answer:0.4 billion dollars
#
# ####question:what was
# 921
#
#
# ###Answer:0.07% ( 0.07
# 922
#
#
# ###Answer:7.5%\\n\\n\\n
#
#
# 923
#
#
# ###Answer:79.5% ( 79.5
# 924
#
#
# ###Answer:0.2% ( 0.2
# 925
#
#
# ###Answer:yes
#
# ####question:what was the percentage change in
# 926
# ?
#
# ###Answer:7.6%\\n\\n\\n
# 927
#
#
# ###Answer:59.6
#
# ####question:what is the total
# 928
#
#
# ###Answer:9.8%\\n
#
# ####question:what
# 929
#
#
# ###Answer:14.5%\\n
#
# ####question:what
# 930
# ?
#
# ###Answer:2.5:1.0
#
# ###:
# 931
#
#
# ###Answer:31.46%\\n
#
# ###question:what
# 932
#
#
# ###Answer:1.6:1.0
#
# ###:what
# 933
#  in millions?
#
# ###Answer:5.7% ( 5
# 934
#
#
# ###Answer:9.1% ( 9.1
# 935
#
#
# ###Answer:1.1% ( 1.1
# 936
# ?
#
# ###Answer:14.5% ( 14.5
# 937
# ?
#
# ###Answer:10543.5
#
# ####question:what was
# 938
#
#
# ###Answer:118.36%\\n
#
# ####question:what
# 939
#
#
# ###Answer:33% ( 33 % )
#
#
# 940
#
#
# ###Answer:184.07
#
# ###Answer:174.62
#
#
# 941
#
#
# ###Answer:1702.5 million dollars
#
# ####question:what
# 942
#
#
# ###Answer:1.1 and 1.2 respectively.
#
#
# 943
#
#
# ###Answer:7.5% ( 7.5
# 944
#
#
# ###Answer:0.5% ( 0.5
# 945
#
#
# ###Answer:5.5% ( 5.5
# 946
# ?
#
# ###Answer:93.6 million
#
# ###what was the percentage
# 947
#
#
# ###Answer:7.5%\\n
#
# ###:what was
# 948
#
#
# ###Answer:1.2% ( 1.2
# 949
#  from 2017 to 2018?
#
# ###Answer:7.
# 950
#
#
# ###Answer:2.1%\\n\\n
#
# ####question
# 951
#
#
# ###Answer:-11313.3 million
#
# ####question:what is
# 952
#  in 2017 and 2016, in millions?
#
# ###
# 953
#
#
# ###Answer:$ 1.79
#
# ####question:what is
# 954
#
#
# ###Answer:10.7%\\n
#
# ###:in
# 955
#
#
# ###Answer:27.3%\\n\\n\\n
#
#
# 956
#
#
# ###Answer:10.5%\\n\\n
#
# ###:
# 957
#
#
# ###Answer:18.5%\\n\\n
#
# ####question
# 958
#
#
# ###Answer:8800 shares of hologic common stock valued at
# 959
#
#
# ###Answer:0.5%, 0.6%
# 960
#
#
# ###Answer:79.5% ( 79.5
# 961
#
#
# ###Answer:56.5%\\n
#
# ####question:what
# 962
#
#
# ###Answer:1.2:1.0
#
# ####question:
# 963
#
#
# ###Answer:269.6
#
# ####question:what is the total
# 964
#
#
# ###Answer:57%\\n
#
# ####question:what percentage of
# 965
#
#
# ###Answer:14.5%\\n
#
# ####question:what
# 966
#
#
# ###Answer:127.1 million dollars
#
# ###:what was the
# 967
#
#
# ###Answer:203.4 million in 2006 and $
# 968
#
#
# ###Answer:yes, by $ 1.1 billion.
# 969
#
#
# ###Answer:165.6
#
# ####question:what is the percentage
# 970
#
#
# ###Answer:9.5%\\n\\n\\n\\
# 971
#
#
# ###Answer:42%\\n\\n
#
# ####question:what
# 972
#
#
# ###Answer:2100000.00$
#
# ####question:what
# 973
# ?
#
# ###Answer:3.0 million dollars
#
# ####question:what
# 974
#
#
# ###Answer:118.42%\\n\\n
#
# ###question
# 975
#
#
# ###Answer:27.5%\\n
#
# ####question:what
# 976
#
#
# ###Answer:52%\\n\\n\\n
#
# ####question
# 977
#
#
# ###Answer:17.5%\\n\\n
#
# ###:
# 978
#
#
# ###Answer:7.8% ( 7.8
# 979
#
#
# ###Answer:19.5%\\n\\n
#
# ###:
# 980
#
#
# ###Answer:-42.4 million dollars
#
# ###:what is the
# 981
# ?
#
# ###Answer:63.5%\\n\\n
#
# ###
# 982
#  from 2011 to 2012?
#
# ###Answer:61.
# 983
#
#
# ###Answer:27.5%\\n\\n
#
# ####question
# 984
#
#
# ###Answer:15.2%\\n
#
# ###:\\n
# 985
#
#
# ###Answer:16.7%\\n\\n
#
# ###:
# 986
#
#
# ###Answer:2.4% ( 2.4
# 987
#
#
# ###Answer:10.7%\\n\\n
#
# ####question
# 988
#
#
# ###Answer:24296
#
# ####question:what was the percentage change
# 989
#
#
# ###Answer:115.4% ( 115.4
# 990
#
#
# ###Answer:1.5
#
# ####question:what was the percentage
# 991
# ?
#
# ###Answer:($ 18205 )
#
# ###question:
# 992
#  to the total net of all collateral
#
# ###Answer:27.5%
# 993
#
#
# ###Answer:32.5%\\n
#
# ###:\\n
# 994
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 995
#
#
# ###Answer:24.5% ( 24.5
# 996
# ?
#
# ###Answer:6.7% ( 6.7
# 997
#
#
# ###Answer:0.5
#
# ###:what was the change in
# 998
#
#
# ###Answer:10.7%\\n\\n\\n
#
#
# 999
#
#
# ###Answer:2.5%\\n
#
# ####question:what
# 1000
#
#
# ###Answer:110.4% ( 110.4
# 1001
#
#
# ###Answer:33.3%\\n
#
# ###:based on
# 1002
#
#
# ###Answer:2.2%\\n\\n\\n\\
# 1003
#
#
# ###Answer:2.5% ( 2.5
# 1004
#
#
# ###Answer:1027.5 million
#
# ###:what was the
# 1005
#
#
# ###Answer:14.3%\\n\\n\\n\\
# 1006
#
#
# ###Answer:13.5%\\n\\n
#
# ###:
# 1007
# ?
#
# ###Answer:65.7%\\n\\n
#
# ####
# 1008
#
#
# ###Answer:10.6 million
#
# ####question:what is the
# 1009
# ?
#
# ###Answer:286.5
#
# ###what is the percentage change
# 1010
#
#
# ###Answer:-1.5% ( 1.5
# 1011
#
#
# ###Answer:118.4
#
# ####question:what was the change
# 1012
#
#
# ###Answer:2.5% ( 2.5
# 1013
# ?
#
# ###Answer:0.5% ( 0.5
# 1014
#
#
# ###Answer:1.5:1
#
# ####question:what was
# 1015
#
#
# ###Answer:13.00
#
# ####question:what was the percent
# 1016
#
#
# ###Answer:12.5%\\n\\n
#
# ####question
# 1017
#
#
# ###Answer:0.2 billion
#
# ####question:what was the
# 1018
#
#
# ###Answer:6.7%\\n\\n\\n\\
# 1019
#
#
# ###Answer:0.1% ( 0.1
# 1020
#
#
# ###Answer:10.7%\\n
#
# ####question:what
# 1021
#
#
# ###Answer:381415.5
#
# ####question:what is the
# 1022
#
#
# ###Answer:32.10%\\n
#
# ###Answer:32
# 1023
#
#
# ###Answer:10.5% ( 10.5
# 1024
#
#
# ###Answer:3.5% ( 3.5
# 1025
#
#
# ###Answer:376.5
#
# ####question:what was the percent
# 1026
#
#
# ###Answer:22.5%\\n\\n
#
# ###Answer
# 1027
#
#
# ###Answer:8.6%\\n
#
# ###:\\n
# 1028
#
#
# ###Answer:16.5%\\n\\n
#
# ####question
# 1029
#
#
# ###Answer:97.5%\\n
#
# ####question:what
# 1030
# ?
#
# ###Answer:6.25% ( 6.25
# 1031
#
#
# ###Answer:34.5%\\n
#
# ###:\\n
# 1032
#
#
# ###Answer:50%\\n50%\\n
#
# ###:
# 1033
#
#
# ###Answer:9.6%\\n\\n\\n\\
# 1034
#
#
# ###Answer:0.1% ( 0.1
# 1035
#
#
# ###Answer:0.1%\\n
#
# ####question:what
# 1036
# ?
#
# ###Answer:0.6% ( 0.6
# 1037
#
#
# ###Answer:2.5%\\n
#
# ###:what is
# 1038
#
#
# ###Answer:61677.5
#
# ####question:what was the
# 1039
#
#
# ###Answer:13.5%\\n
#
# ####question:what
# 1040
#
#
# ###Answer:88.8
#
# ####question:what was the change
# 1041
# ?
#
# ###Answer:2.5%\\n\\n\\n
# 1042
# ?
#
# ###Answer:327.4 million
#
# ####question:what was
# 1043
#
#
# ###Answer:230.29%\\n
#
# ####question:what
# 1044
# ?
#
# ###Answer:18.6%\\n\\n\\n
# 1045
#
#
# ###Answer:-5.8% ( 5.8
# 1046
#
#
# ###Answer:2.4 million
#
# ####question:what was the
# 1047
#
#
# ###Answer:1.1% ( 1.1
# 1048
#
#
# ###Answer:7.2
#
# ###Answer:7.2
#
#
# 1049
#
#
# ###Answer:7.5% ( 7.5
# 1050
#
#
# ###Answer:33%\\n
#
# ####question:what was the
# 1051
#  ( in thousands )
#
# ###Answer:1.2 million
#
#
# 1052
#
#
# ###Answer:7.5%\\n\\n\\n\\
# 1053
#
#
# ###Answer:8.9%\\n\\n\\n
#
#
# 1054
#
#
# ###Answer:27.7%\\n\\n
#
# ####question
# 1055
#
#
# ###Answer:1.1% ( 1.1
# 1056
#
#
# ###Answer:52%\\n
#
# ####question:what was the
# 1057
#
#
# ###Answer:13.3%\\n\\n\\n\\
# 1058
#
#
# ###Answer:8.5%\\n\\n
#
# ####question
# 1059
#
#
# ###Answer:1.9% ( 1.9
# 1060
#
#
# ###Answer:16.5%\\n\\n\\n\\
# 1061
#
#
# ###Answer:27.3%\\n
#
# ####question:what
# 1062
#
#
# ###Answer:1.5% ( 1.5
# 1063
#
#
# ###Answer:16.7%\\n\\n
#
# ###:
# 1064
#
#
# ###Answer:2.5% ( 2.5
# 1065
#
#
# ###Answer:13%\\n\\n\\n
#
# ###:
# 1066
#
#
# ###Answer:33.3%\\n\\n\\n
#
#
# 1067
#
#
# ###Answer:2.8%:2.8%
#
# ####
# 1068
#
#
# ###Answer:6.5% ( 6.5
# 1069
#
#
# ###Answer:188649-265436
#
# ###:what is the
# 1070
#
#
# ###Answer:13%\\n\\n\\n
#
# ###:
# 1071
#
#
# ###Answer:11.7%\\n\\n\\n\\
# 1072
#
#
# ###Answer:1.2
#
# ####question:what was the percentage
# 1073
#
#
# ###Answer:1499.9% ( 1499.
# 1074
#
#
# ###Answer:52.5%\\n
#
# ####question:what
# 1075
#
#
# ###Answer:13%\\n\\n
#
# ####question:what
# 1076
# ?
#
# ###Answer:1.1 billion
#
# ###:what was the
# 1077
#
#
# ###Answer:1.1% ( 1.1
# 1078
#
#
# ###Answer:0.36% ( 0.36
# 1079
#
#
# ###Answer:14.3-21.7
#
# ####question:
# 1080
#
#
# ###Answer:11.5%\\n\\n
#
# ###:
# 1081
#
#
# ###Answer:1.1 billion
#
# ####question:what is the
# 1082
#
#
# ###Answer:1.2 billion dollars
#
# ###:what was the
# 1083
#
#
# ###Answer:1.3%\\n\\n\\n
#
#
# 1084
#
#
# ###Answer:7.5%\\n\\n\\n\\
# 1085
#
#
# ###Answer:1.1 billion dollars
#
# ####question:what is
# 1086
#
#
# ###Answer:4.0%\\n\\n
#
# ####question
# 1087
#
#
# ###Answer:1.2% ( 1.2
# 1088
#
#
# ###Answer:23.5% ( 23.5
# 1089
#
#
# ###Answer:14.5% ( 14.5
# 1090
# ?
#
# ###Answer:3.8% ( 3.8
# 1091
#
#
# ###Answer:33.5%\\n
#
# ###:\\n
# 1092
#
#
# ###Answer:3.6
#
# ####question:what is the percentage
# 1093
#
#
# ###Answer:5822.5
#
# ####question:what was the
# 1094
# ?
#
# ###Answer:3.8%\\n
#
# ####question:
# 1095
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 1096
#
#
# ###Answer:13.7%\\n\\n
#
# ####question
# 1097
#
#
# ###Answer:25%.
#
# ####question:what was the
# 1098
#
#
# ###Answer:61.45%\\n\\n
#
# ####question
# 1099
#
#
# ###Answer:20%\\n\\n
#
# ###:\\n
# 1100
#
#
# ###Answer:0.1% ( 0.1
# 1101
#
#
# ###Answer:5.6%\\n\\n\\n
#
#
# 1102
# ?
#
# ###Answer:1.2 billion
#
# ####question:what was
# 1103
#
#
# ###Answer:23.5% ( 23.5
# 1104
#
#
# ###Answer:1.2%\\n
#
# ####question:what
# 1105
#
#
# ###Answer:0.5% ( 0.5
# 1106
#
#
# ###Answer:3.3%\\n
#
# ####question:what
# 1107
#
#
# ###Answer:127.8 million shares
#
# ####question:what was
# 1108
#
#
# ###Answer:1.5%\\n
#
# ####question:what
# 1109
#
#
# ###Answer:23.5%\\n
#
# ####question:what
# 1110
#
#
# ###Answer:5.6%\\n\\n
#
# ####question
# 1111
#
#
# ###Answer:14.3%\\n
#
# ####question:what
# 1112
#
#
# ###Answer:21.5%\\n\\n
#
# ####question
# 1113
#
#
# ###Answer:1.5% 1.5%
#
# ####
# 1114
#
#
# ###Answer:50.0
#
# ####question:what is the percentage
# 1115
#
#
# ###Answer:53.1%\\n
#
# ####question:what
# 1116
# ?
#
# ###Answer:268.9
#
# ####question:what was the
# 1117
#
#
# ###Answer:61.7%\\n
#
# ####question:what
# 1118
#
#
# ###Answer:8.5%\\n\\n
#
# ####question
# 1119
#
#
# ###Answer:54.6%\\n
#
# ####question:what
# 1120
#
#
# ###Answer:9.6%\\n\\n
#
# ####question
# 1121
#
#
# ###Answer:33%\\n
#
# ####question:what was the
# 1122
#
#
# ###Answer:1009.9
#
# ####question:what was the
# 1123
#
#
# ###Answer:0.5% ( 0.5
# 1124
#
#
# ###Answer:1.1%\\n
#
# ####question:what
# 1125
#
#
# ###Answer:13.5%\\n
#
# ###:\\n
# 1126
#
#
# ###Answer:5.6%\\n\\n\\n\\
# 1127
#
#
# ###Answer:3.5%\\n
#
# ###:\\n
# 1128
#
#
# ###Answer:22%\\n\\n\\n
#
# ###:
# 1129
#
#
# ###Answer:-1.2 billion
#
# ####question:what is the
# 1130
#  from 2013
#
# ###Answer:1.1% (
# 1131
#
#
# ###Answer:11.1%\\n
#
# ####question:what
# 1132
#
#
# ###Answer:1.1-1.3 billion?
#
# ###
# 1133
#
#
# ###Answer:20.5% ( 20.5
# 1134
#
#
# ###Answer:5.6%\\n\\n\\n\\
# 1135
#
#
# ###Answer:2.3
#
# ###: what is the total expected
# 1136
#
#
# ###Answer:23.5%\\n
#
# ####question:what
# 1137
#
#
# ###Answer:2.5%\\n
#
# ####question:what
# 1138
#
#
# ###Answer:1.2% more was spent on shares in nov
# 1139
#
#
# ###Answer:92.5% ( 92.5
# 1140
#
#
# ###Answer:1.5:1.0
#
# ####question:
# 1141
#
#
# ###Answer:1.6%\\n
#
# ####question:what
# 1142
#
#
# ###Answer:19.45%\\n\\n\\n
#
#
# 1143
#
#
# ###Answer:11.5%\\n\\n
#
# ###:
# 1144
#
#
# ###Answer:2.5
#
# ####question:what is the average
# 1145
# ?
#
# ###Answer:19.95
#
# ####question:what was the
# 1146
#  in millions?
#
# ###Answer:2.9 billion
#
# ####question:
# 1147
# --- 42155.3581302166 seconds ---

# %%
### add the output of the model to the test dataset for evaluation purpose
dataset_pd['prediction'] = output_list

# %% [markdown]
# ### Functions to perform the post-processing

# %%
def map_yes_no(x):
    x = str(x)
    if x.lower() in 'yes':
        return '1'
    elif x.lower() in 'no':
        return '0'
    else:
        return x


def remove_non_numeric(x):
    x = str(x)
    pattern = re.compile(r"[^\d.]")
    x = pattern.sub("", x)
    return x

def other_formatting(x):
  x =str(x)
  x=x.replace('...', '')
  x=x.replace('..', '')
  tofind = '.'
  if x.count(tofind) > 1:
    pos = x.index(tofind, x.index(tofind) + 1)
    x = x[:pos] + '' + x[pos + 1:]
    return x
  else:
    return x


def replace_blanks(x):
  x =str(x)
  if x.strip() == '':
    return '0'
  else:
    return x

# %% [markdown]
# ### Apply the post processing functions

# %%
dataset_pd['formatted_answer']  = dataset_pd['answer'].apply(map_yes_no)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(remove_non_numeric)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(other_formatting)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(replace_blanks)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].astype(float)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].round()

dataset_pd['formatted_prediction']  = dataset_pd['prediction'].apply(map_yes_no)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(remove_non_numeric)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(other_formatting)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(replace_blanks)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(other_formatting)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].astype(float)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].round()

# %% [markdown]
# ### Produce the Final Result

# %%
dataset_pd['match_ind'] = np.where( dataset_pd['formatted_answer'] == dataset_pd['formatted_prediction'], 1,0)
dataset_pd['match_ind'].mean()
# Out:
# 0.12031386224934612

# %% [markdown]
# ### The exact match accuracy for Falcon is 0.12
