# %% [markdown]
# #### This Notebook is the implementation of fine-tuning LLaMA 2 LLM on FinQA Dataset for Question-answering task. Evaluation was performed on test dataset and results have been reported. Please note that this cod is for experiment to select the rank parameter

# %% [markdown]
# ### Install Required Libraries and Packages

# %% [raw]
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# !pip install huggingface_hub
# !pip install -q datasets
#
# import re
# import os
# import torch
# from datasets import load_dataset
# from transformers import (
#     AutoModelForCausalLM,
#     AutoTokenizer,
#     BitsAndBytesConfig,
#     HfArgumentParser,
#     TrainingArguments,
#     pipeline,
#     logging,
# )
# from peft import LoraConfig, PeftModel
# from trl import SFTTrainer
# from datasets import load_dataset
# import pandas as pd
# import random
# from datasets import Dataset
# from datasets import load_dataset
# import pandas as pd
# import random

# %% [markdown]
# ### Login into Hugging Face Hub

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Load the data

# %% [markdown]
# - Train and Test data has been loaded
# - FINQA has separate Split for train and test data and hence same has been loaded from hugging face hub
# - Data has been converted into a format which can be used to fine tune the LLMs

# %%
pd.set_option('display.max_colwidth', -1)
dataset = load_dataset("dreamerdeo/finqa",split="train") ### Load train data from hugging face hub

dataset_pd = dataset.to_pandas() ### convert to pandas

def table_format(x_input): ### format the tabular data in the financial report in pipe delimited format
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x): ### Convert the list of sentences into a single paragraph of sentences 
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

##apply the functions
dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)


### Instructions to be overlaid to the train dataset
instructions = [
    "Financial data and expert analysis has been provided as context, use the provided context to answer the question.",
    "Please provide the required answer to this expert-authored finance question based on the context given.",
    "A deep financial question based on a financial report has been given along with required context, could you help answer the financial question.",
    "Analysis based on financial documents has been given as context, please answer the question using the context.",
    "Financial report data and analysis has been given as context , please respond to the question using the context given."
]

## Add the instructions
ins_list = []
for ins in range(6251):
  ins = random.choice(instructions)
  ins_list.append(ins)


dataset_pd['instructions'] = ins_list

### Finally combine all the formatted columns together to form the final prompt
ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = f'###Instruction:'  + dataset_pd['instructions'] + ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question'] +  f'\n\n###Answer:' +  dataset_pd['answer']

from datasets import Dataset
train_df = Dataset.from_pandas(dataset_pd)
dataset_dct = train_df.train_test_split(test_size=0.25)  ### Create validation dataset from train dataset

### Get the Train and Test Dataset from Hugging Face Dataset Dict object
df_train = dataset_dct["train"]
df_eval = dataset_dct["test"]
# Out:
# <ipython-input-4-222c4df8f7fc>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# Downloading builder script:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/515 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data: 0.00B [00:00, ?B/s]
# /root/.cache/huggingface/datasets/downloads/extracted/ca045c27488b49db24426c67e0b35e06b0188746c40ffaf8d01a7b51e52924dc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Fine-Tuning Framework Parameters

# %%
# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-hf"



# Fine-tuned model name
new_model = "llama-2-7b-finqa_rank_128-vj"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 128 ### RANK PARAMETER

# Alpha parameter for LoRA scaling
lora_alpha = 256

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = True

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = 2000

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)


# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform Fine-tuning

# %%
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard",
    evaluation_strategy="epoch"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=df_train,
    eval_dataset=df_eval,
    peft_config=peft_config,
    dataset_text_field="final_instruction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/4688 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1563 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='652' max='1172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 652/1172 27:57 < 22:22, 0.39 it/s, Epoch 0.56/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1172' max='1172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1172/1172 57:20, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.775300</td>
#       <td>0.842145</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-hf"

# Fine-tuned model name
new_model = "llama-2-7b-finqa_rank_128-vj"


# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Push the fine-tuned model to Hugging Face hub and save it

# %%
# !huggingface-cli login

model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/vijayshankar245/llama-2-7b-finqa_rank_128-vj/commit/2cb96b73830badfbe0ece21941aacf921b58f423', commit_message='Upload tokenizer', commit_description='', oid='2cb96b73830badfbe0ece21941aacf921b58f423', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# - Apply the necessary formatting on test data (Same steps which were followed for train dataset)

# %%
dataset = load_dataset("dreamerdeo/finqa",split="test")

dataset_pd = dataset.to_pandas()

def table_format(x_input):
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x):
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)




ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question']

from datasets import Dataset
test_df = Dataset.from_pandas(dataset_pd)
# Out:
# Downloading builder script:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/515 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data: 0.00B [00:00, ?B/s]
# /root/.cache/huggingface/datasets/downloads/extracted/ca045c27488b49db24426c67e0b35e06b0188746c40ffaf8d01a7b51e52924dc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Load the fine-tuned model for evaluation

# %%
# Ignore warnings
logging.set_verbosity(logging.CRITICAL)
model = "vijayshankar245/llama-2-7b-finqa_rank_128-vj"
tokenizer = AutoTokenizer.from_pretrained(model, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Run text generation pipeline with our next model

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer,return_full_text=False,temperature=0.1,top_p =0.9,max_new_tokens = 15)
# Out:
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform the evaluation and extract the results

# %%
import time
start_time = time.time()
from transformers.pipelines.pt_utils import KeyDataset
output_list = []
j=0
for i in pipe(KeyDataset(test_df, "final_instruction")):
  j=j+1
  print(i[0]['generated_text'])
  output_list.append(i[0]['generated_text'])
  print(j)
  df = pd.DataFrame({'output': output_list})
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ###Answer:24.4%\\n\\n
# 13
#
#
# ###Answer:yes\\n
#
# ###Yes|
# 14
# ?
#
# ###Answer:10.4%\\n\\
# 15
#
#
# ###Answer:2967.3333
# 16
#
#
# ###answer:100000000
# 17
#
#
# ###Answer:704.45\\n\\
# 18
#
#
# ###Answer:11.2%\\n\\n
# 19
#
#
# ###Answer:19.914257
# 20
# ?
#
# ###answer:15.9% increase in the
# 21
#
#
# ###Answer:11.81%\\n
#
# 22
#
#
# ###Answer:14.4%\\n\\n
# 23
#
#
# ###answer:18%\\n\\ncapital
# 24
#
#
# ###answer:1.67:1.00
# 25
#
#
# ###answer:1.25\\n\\n
#
# 26
#
#
# ###Answer:37.5%\\n"
#
# 27
#
#
# ###Answer:11.4% increase in the the
# 28
# ?
#
# ###Answer:10.85667
# 29
#
#
# ###Answer:10.5%\\n\\n
# 30
#
#
# ###Answer:17.2%\\n
#
#
# 31
#
#
# ###Answer:5.4%\\n\\nin
# 32
#
#
# ###Answer:1040.5656
# 33
#
#
# ###answer:6.1%\\n
#
# ##
# 34
#
#
# ###Answer:48609 million dollars
#
#
# 35
#
#
# ###answer:168.5\\n
#
#
# 36
#
#
# ###Answer:23.5%\\n\\n
# 37
#
#
# ###answer:10.5%\\n\\n
# 38
#
#
# ###answer:2.6698333
# 39
#
#
# ###Answer:4777553 shares.
# 40
#
#
# ###Answer:131.6 million dollars..
# 41
#
#
# ###Answer:148.36%\\n
# 42
#  in millions
#
# ###Answer:160.215
# 43
#
#
# ###answer:45.5%\\n\\n
# 44
#
#
# ###answer:882.8 million\\n\\
# 45
#
#
# ###answer:3495.5641
# 46
#
#
# ###Answer:15.4%\\n
#
#
# 47
#
#
# ###Answer:10.4%\\n\\n
# 48
#
#
# ###Answer:17%\\n\\n
#
#
# 49
#
#
# ###answer:33.3%\\n\\n
# 50
#
#
# ###Answer:23.8% decrease in cash
# 51
#  in connection with the federal reserve bank 2019s treas
# 52
#
#
# ###answer:274000000
# 53
#
#
# ###answer:3.00\\n
#
# ##
# 54
#
#
# ###Answer:10.4%\\n\\n
# 55
#
#
# ###Answer:38.5%\\n
#
#
# 56
#  from 2015 to 2016?
#
#
# 57
#
#
# ###Answer:9.4%\\n\\n\\
# 58
#
#
# ###Answer:2.9% increase in impact of the
# 59
# ?
#
# ###Answer:500000.3
# 60
#
#
# ###Answer:33.3%\\n\\n
# 61
#
#
# ###answer:1.25%\\n\\n
# 62
#
#
# ###answer:367438600
# 63
#
#
# ###Answer:126.5 million\\n\\
# 64
#
#
# ###Answer:10.6%\\n\\n
# 65
#
#
# ###Answer:yes, it grew by 28%
# 66
#
#
# ###Answer:116%\\n
#
# ##
# 67
#
#
# ###Answer:86%\\n
#
# ###
# 68
#
#
# ###Answer:150000000
# 69
#
#
# ###answer:28%\\n\\ncommer
# 70
#
#
# ###answer:5.2%\\n\\n
#
# 71
#
#
# ###answer:15.5%\\n"
#
# 72
#
#
# ###answer:99.2%\\n\\n
# 73
#
#
# ###answer:10% increase in the stock price performance
# 74
#
#
# ###Answer:105%\\n
#
# ##
# 75
#
#
# ###Answer:11.1%\\n\\n
# 76
#
#
# ###Answer:1056 miles
#
# ###
# 77
#
#
# ###answer:26% increase in fair value of financial
# 78
#
#
# ###answer:81808 and 78
# 79
#
#
# ###Answer:10.13% greater.\\
# 80
#
#
# ###Answer:10.76% greater.\\
# 81
#
#
# ###Answer:15.6%\\n\\n
# 82
#
#
# ###Answer:1.25\\n\\n
#
# 83
#
#
# ###Answer:42%\\n\\n\\n
# 84
# ?
#
# ###Answer:11.1%\\n"
# 85
#
#
# ###answer:45%\\n\\n\\n
# 86
#
#
# ###Answer:18.42%\\n
#
# 87
#
#
# ###Answer:2779.3333
# 88
#
#
# ###answer:100% more net gains from
# 89
#  from 2017 to 2018
#
# ##
# 90
#
#
# ###answer:90%\\n\\nwhat was
# 91
#
#
# ###Answer:6.7%\\n\\n
#
# 92
#
#
# ###Answer:857.6\\n\\n
# 93
#
#
# ###Answer:1646332.0
# 94
#
#
# ###Answer:37.9%\\n\\n
# 95
#
#
# ###answer:200000000
# 96
#
#
# ###Answer:20.9%\\n
#
#
# 97
#
#
# ###answer:0.0000000
# 98
#
#
# ###Answer:62.7%\\n\\n
# 99
#
#
# ###Answer:8.9%\\n\\n\\
# 100
#
#
# ###Answer:124.65%\\n
# 101
#
#
# ###Answer:1.5%\\n\\n
#
# 102
#
#
# ###Answer:19.1%\\n\\n
# 103
#
#
# ###Answer:27.5%\\n\\n
# 104
#
#
# ###Answer:12.3%\\n\\n
# 105
#
#
# ###Answer:444777.33
# 106
#
#
# ###answer:100%.945.
# 107
#
#
# ###answer:10.5%\\n\\n
# 108
#
#
# ###Answer:2250.5656
# 109
#
#
# ###Answer:12.5%\\n\\n
# 110
#
#
# ###Answer:1.6%\\n}
#
#
# 111
#
#
# ###Answer:114477777
# 112
#
#
# ###Answer:80%\\n\\n
#
#
# 113
#
#
# ###answer:38.6%\\n\\n
# 114
#
#
# ###Answer:166.75757
# 115
#
#
# ###Answer:1458.5656
# 116
#
#
# ###Answer:10166.750
# 117
#
#
# ###Answer:11.8%\\n"
#
# 118
#
#
# ###Answer:15.5%\\n"
#
# 119
#
#
# ###answer:133.33333
# 120
# ?
#
# ###Answer:177351\\n
# 121
#
#
# ###Answer:22.7%\\n\\n
# 122
#
#
# ###answer:62.5%\\n\\n
# 123
#
#
# ###Answer:11.7%\\n\\n
# 124
#
#
# ###Answer:17.1%\\n\\n
# 125
#  2012 that were purchased in november 2012
# 126
#
#
# ###answer:118.53%\\n
# 127
#  in millions?
#
# ###Answer:27.333
# 128
#
#
# ###Answer:57.4%\\n\\n
# 129
# ?
#
# ###Answer:188.6250
# 130
#
#
# ###Answer:188.2%\\n
#
# 131
#
#
# ###answer:112.5%\\n\\
# 132
#
#
# ###Answer:1.25\\n\\n
#
# 133
#
#
# ###answer:37.5%\\n\\n
# 134
#
#
# ###Answer:15.86%\\n
#
# 135
#
#
# ###Answer:22.5%\\n\\n
# 136
#
#
# ###Answer:28.5% decrease in general and
# 137
#
#
# ###Answer:18.5%\\n\\n
# 138
#
#
# ###answer:126 million dollars\\n'
#
# 139
#
#
# ###answer:2109.5625
# 140
#
#
# ###answer:43.9% increase in aggregate principal
# 141
#
#
# ###answer:0.16% ( 0.
# 142
#
#
# ###Answer:yes\\n\\nno\\n\\
# 143
#
#
# ###Answer:6337.5\\n6
# 144
#
#
# ###Answer:5735.5735
# 145
#
#
# ###Answer:18%\\n
#
# ###
# 146
#
#
# ###Answer:0.0011757
# 147
#
#
# ###Answer:19%\\n
#
# ###
# 148
#
#
# ###Answer:yes\\n
#
# ###Explan
# 149
#
#
# ###Answer:31.6%\\n
#
#
# 150
#
#
# ###Answer:13360000.
# 151
#
#
# ###Answer:109800.00
# 152
#
#
# ###answer:10%\\n\\n
#
#
# 153
#
#
# ###Answer:21%\\n\\n
#
#
# 154
#
#
# ###Answer:256.64444
# 155
#
#
# ###answer:112% increase in the fair value
# 156
#
#
# ###Answer:1226\\n
#
# ##
# 157
#
#
# ###answer:8.5%\\n\\n\\
# 158
#
#
# ###Answer:2.1%\\n\\n
#
# 159
#
#
# ###Answer:10%\\n\\n
#
#
# 160
#
#
# ###Answer:110000000
# 161
# ?
#
# ###Answer:9.8 million\\n'
#
# 162
#
#
# ###Answer:46.15%\\n\\
# 163
#
#
# ###Answer:13.35%\\n\\
# 164
#
#
# ###Answer:35.6%\\n
#
#
# 165
#
#
# ###answer:221323.33
# 166
# ?
#
# ###Answer:31.4%\\n\\
# 167
#
#
# ###Answer:37.2% increase in research and
# 168
#
#
# ###Answer:700000000
# 169
#
#
# ###answer:2.4%\\n\\n\\
# 170
# ?
#
# ###Answer:100% increase in minority
# 171
#
#
# ###Answer:24.5%\\n\\n
# 172
#
#
# ###Answer:15395.000
# 173
#
#
# ###Answer:60399.999
# 174
#
#
# ###Answer:189000000
# 175
#
#
# ###Answer:10.4%\\n\\n
# 176
#
#
# ###Answer:1.3%\\n\\n
#
# 177
#
#
# ###Answer:yes\\n\\n
#
# ###
# 178
#
#
# ###Answer:1056.5\\n\\
# 179
#
#
# ###Answer:yes\\n
#
# ###Explan
# 180
#
#
# ###answer:107.76%\\n
# 181
#
#
# ###Answer:18.5%\\n\\n
# 182
#
#
# ###answer:16493000.
# 183
# ?
#
# ###Answer:18.1%\\n
#
# 184
#
#
# ###answer:22.2%\\n\\n
# 185
#
#
# ###Answer:13.3%\\n\\n
# 186
#
#
# ###Answer:11.5%\\n}
#
# 187
#
#
# ###Answer:32.5%\\n\\n
# 188
#
#
# ###Answer:492500000
# 189
#
#
# ###Answer:1188.67\\n
# 190
# ?
#
# ###answer:5000.000
# 191
#
#
# ###Answer:10.5%\\n\\n
# 192
#
#
# ###Answer:380000000
# 193
#
#
# ###Answer:15.80%\\n\\
# 194
#
#
# ###Answer:23%\\n\\n\\n
# 195
#
#
# ###answer:167%\\n\\n\\
# 196
#
#
# ###answer:6.9%\\n\\nnotes
# 197
#
#
# ###Answer:5971.8400
# 198
#  for workers 2019 compensation, commercial general liability,
# 199
#  in the united states, canada, and latin america region and
# 200
#
#
# ###Answer:382.33333
# 201
#  sales
#
# ###answer:1.252525
# 202
#
#
# ###Answer:0.5 million of asset retirement li
# 203
#
#
# ###Answer:33.5%\\n\\n
# 204
#
#
# ###answer:10.7%\\n\\n
# 205
#
#
# ###Answer:12.5%\\n\\n
# 206
#
#
# ###answer:15.4%\\n\\n
# 207
#
#
# ###Answer:15.7%\\n\\n
# 208
#
#
# ###Answer:2.675\\n\\n
# 209
#
#
# ###Answer:160%\\n\\n
#
# 210
#  prepaid insurance?
#
# ###Answer:4.1
# 211
#
#
# ###Answer:39.459667
# 212
#
#
# ###answer:9.25\\n\\n
#
# 213
#
#
# ###Answer:50-200\\n\\
# 214
#
#
# ###Answer:54.5%\\n
#
#
# 215
#
#
# ###Answer:1.1%\\n\\n
#
# 216
#
#
# ###answer:10.3-4.8\\
# 217
#
#
# ###Answer:12.1%\\n
#
#
# 218
#
#
# ###Answer:11.8%\\n\\n
# 219
# ?
#
# ###answer:50% increase in number of shares
# 220
#
#
# ###Answer:920000.50
# 221
#
#
# ###Answer:10.7%\\n
#
#
# 222
# ?
#
# ###Answer:100% increase in the domestic
# 223
#
#
# ###Answer:2.13%\\n\\n
# 224
#
#
# ###Answer:80%\\n\\n\\n
# 225
#
#
# ###Answer:12.5% of the total li
# 226
#
#
# ###answer:18%\\n\\n
#
#
# 227
#
#
# ###answer:1.2457575
# 228
#
#
# ###answer:60%\\n\\n\\n
# 229
#
#
# ###answer:100%\\n\\n\\
# 230
#
#
# ###Answer:10.7%\\n\\n
# 231
#
#
# ###Answer:28.6% increase in the aggregate
# 232
#
#
# ###Answer:172.8 million shares.
#
# 233
#
#
# ###Answer:19%\\n"
#
# ##
# 234
#
#
# ###Answer:30694.56\\
# 235
# ?
#
# ###Answer:20.33333
# 236
#
#
# ###answer:18.5%\\n
#
#
# 237
#
#
# ###Answer:13.5%\\n\\n
# 238
#
#
# ###Answer:8600.5 million dollars.
# 239
#
#
# ###Answer:37.425 million and
# 240
# ?
#
# ###Answer:10212430
# 241
#
#
# ###Answer:1.7%\\n\\n
#
# 242
#
#
# ###answer:18.5%\\n\\n
# 243
#
#
# ###answer:6100.6675
# 244
#
#
# ###Answer:198.27%\\n
# 245
#
#
# ###Answer:134634400
# 246
#
#
# ###Answer:5.7%\\n\\n
#
# 247
#
#
# ###Answer:170000000
# 248
#
#
# ###Answer:21%\\n\\n
#
#
# 249
#
#
# ###answer:40%\\n\\n\\n
# 250
#
#
# ###answer:4.8% or $ 4.
# 251
#  options warrants and rights
#
# ###Answer:1.2
# 252
#
#
# ###answer:21.6%\\n\\n
# 253
#
#
# ###Answer:1.4%\\n\\n
#
# 254
#
#
# ###Answer:12.5%\\n\\n
# 255
#  in the us and other countries
#
# ###answer:65.
# 256
#
#
# ###Answer:38.2%\\n"
#
# 257
#
#
# ###Answer:47%\\n\\n
#
#
# 258
#
#
# ###answer:92.225625
# 259
#
#
# ###Answer:1.0250000
# 260
#
#
# ###answer:100% increase in net unreal
# 261
#
#
# ###Answer:25.4%\\n
#
#
# 262
#
#
# ###Answer:125.4 million dollars 2
# 263
#
#
# ###answer:10.4%\\n\\n
# 264
#
#
# ###answer:674.00000
# 265
#
#
# ###Answer:33.3%\\n\\n
# 266
#
#
# ###answer:223400.33
# 267
#
#
# ###Answer:340.3 million 20
# 268
#  8.00% ( 8.00 % )
#
# 269
#
#
# ###Answer:91%\\n\\n
#
#
# 270
#
#
# ###Answer:1.1667566
# 271
#
#
# ###Answer:10.4%\\n\\n
# 272
#
#
# ###Answer:10.5%\\n\\n
# 273
#
#
# ###Answer:107.62%\\n
# 274
#
#
# ###answer:1.5% and 1.5
# 275
#
#
# ###answer:10.5% increase in the recorded
# 276
#
#
# ###answer:101.00000
# 277
#
#
# ###answer:44%\\n\\n
#
#
# 278
#
#
# ###answer:15.5%\\n\\n
# 279
#
#
# ###answer:14.4%\\n\\n
# 280
#
#
# ###answer:yes\\n\\nno
#
# ##
# 281
#
#
# ###Answer:173352.50
# 282
#
#
# ###answer:10.4%\\n
#
#
# 283
#
#
# ###Answer:13.5 million shares.
#
#
# 284
#
#
# ###Answer:11.6%\\n\\n
# 285
#
#
# ###Answer:35.4%\\n"
#
# 286
#
#
# ###Answer:1.675\\n
#
#
# 287
#
#
# ###answer:252962 shares
#
#
# 288
#
#
# ###Answer:15.1%\\n"
#
# 289
#
#
# ###Answer:54.5%\\n\\n
# 290
#
#
# ###Answer:10.8%\\n\\n
# 291
#
#
# ###answer:14.1%\\n\\n
# 292
#
#
# ###Answer:13.3% ( 13
# 293
#
#
# ###answer:45%\\n\\n\\n
# 294
#
#
# ###Answer:11.5%\\n\\n
# 295
#
#
# ###Answer:28.5%\\n\\n
# 296
#
#
# ###Answer:100000000
# 297
#
#
# ###Answer:16.8%\\n\\n
# 298
#
#
# ###Answer:71.67\\n\\n
# 299
#
#
# ###Answer:9%\\n\\n
#
# ##
# 300
#
#
# ###Answer:182%\\n\\n
#
# 301
#
#
# ###Answer:4.0562500
# 302
#
#
# ###Answer:10.750000
# 303
#
#
# ###Answer:0.5% ( 0.5
# 304
#
#
# ###Answer:7.2%\\n\\n\\
# 305
#
#
# ###Answer:12.3%\\n
#
#
# 306
#
#
# ###answer:11.75\\n\\n
# 307
#
#
# ###Answer:12.7%\\n\\n
# 308
#
#
# ###answer:1.8%\\n\\n
#
# 309
#
#
# ###answer:2.44:1.00
# 310
# ?
#
# ###Answer:2.7%\\n'
#
# 311
#
#
# ###Answer:14%\\n\\n\\n
# 312
# \\n\\n\\n\\n\\n\\n\\n\\
# 313
#
#
# ###Answer:2.5 times bigger.\\n\\
# 314
#
#
# ###answer:10.3%\\n\\n
# 315
#
#
# ###answer:413.79999
# 316
#
#
# ###Answer:15.5%\\n\\n
# 317
#
#
# ###Answer:1.125\\n\\n
# 318
#
#
# ###Answer:1.1% ( 1.1
# 319
#
#
# ###Answer:81.4%\\n'
#
# 320
#
#
# ###Answer:17.6% decrease in millions of
# 321
#
#
# ###Answer:39.3%\\n\\n
# 322
#
#
# ###Answer:no\\n
#
# ###Context:
# 323
#
#
# ###Answer:18.6%\\n\\n
# 324
#
#
# ###answer:13.4%\\n\\n
# 325
#
#
# ###Answer:297256\\n
#
# 326
# ?
#
# ###answer:2.333333
# 327
#
#
# ###Answer:1.24\\n\\n
#
# 328
#
#
# ###answer:14.4%\\n\\n
# 329
#
#
# ###Answer:68%\\n\\n
#
#
# 330
#
#
# ###answer:123890000
# 331
#
#
# ###answer:15.6%\\n\\n
# 332
#
#
# ###Answer:1324.6675
# 333
#
#
# ###Answer:2200000\\n
# 334
#
#
# ###Answer:32.5%\\n\\n
# 335
#
#
# ###Answer:8.125%\\n
#
# 336
#
#
# ###Answer:148.36%\\n
# 337
#
#
# ###Answer:22.3%\\n\\n
# 338
#  to the total trade and other accounts receivable
#
# ###answer
# 339
#  from 2014 to 2015
#
# ##
# 340
#
#
# ###Answer:25%\\n
#
# ###
# 341
#
#
# ###Answer:1.33\\n\\n
#
# 342
#
#
# ###Answer:1.75%\\n
#
#
# 343
#
#
# ###Answer:10.7% and 11
# 344
#
#
# ###Answer:91.5%\\n\\n
# 345
#
#
# ###Answer:1.13\\n\\n
#
# 346
#
#
# ###answer:46.5\\n47.
# 347
#
#
# ###Answer:166312 shares of restricted
# 348
#
#
# ###Answer:120660.62
# 349
#
#
# ###answer:10.7%\\n\\n
# 350
#
#
# ###Answer:173.6 million\\n\\
# 351
#
#
# ###Answer:85.5%\\n\\n
# 352
#
#
# ###Answer:1.7%\\n\\n\\
# 353
#
#
# ###Answer:172.81575
# 354
#
#
# ###Answer:111.81%\\n
# 355
#
#
# ###answer:14%\\n\\n
#
#
# 356
#
#
# ###Answer:16.7%\\n\\n
# 357
#
#
# ###Answer:25.7%\\n"
#
# 358
#
#
# ###Answer:10.53%\\n\\
# 359
#
#
# ###answer:102477.5 million
# 360
#
#
# ###Answer:0.5%\\n\\nin
# 361
#
#
# ###Answer:5.2654246
# 362
#
#
# ###Answer:13.3%\\n\\n
# 363
#
#
# ###Answer:20.7%\\n"
#
# 364
#
#
# ###Answer:1.81:1.00
# 365
#
#
# ###Answer:4.3%\\n\\n\\
# 366
#
#
# ###answer:40.51 and 38
# 367
#
#
# ###Answer:50.00\\n\\n
# 368
#
#
# ###Answer:21000\\n\\n
# 369
#
#
# ###Answer:1000000.0
# 370
#
#
# ###answer:52%\\n\\nin millions
# 371
#
#
# ###Answer:16.7%\\n\\n
# 372
#
#
# ###Answer:357.8% increase in net
# 373
#
#
# ###Answer:10.7%\\n
#
#
# 374
#
#
# ###Answer:125.50000
# 375
#
#
# ###Answer:124.36%\\n
# 376
#
#
# ###Answer:5.9%\\n
#
# ##
# 377
#
#
# ###answer:1.9%\\n\\n\\
# 378
#
#
# ###Answer:25%\\n
#
# ###
# 379
#
#
# ###answer:30.86 billion dollars\\n
# 380
#
#
# ###Answer:89.3%\\n\\n
# 381
#
#
# ###Answer:10.7%\\n\\n
# 382
#
#
# ###Answer:19.1%\\n\\n
# 383
#
#
# ###Answer:55.5%\\n\\n
# 384
#  in 2008
#
# ###answer:1.0
# 385
#  in millions?
#
# ###Answer:19.3%\\
# 386
#
#
# ###Answer:1.3 million shares of common stock in
# 387
#
#
# ###Answer:20.3%\\n\\n
# 388
#
#
# ###Answer:22064.444
# 389
#
#
# ###Answer:12.4%\\n
#
#
# 390
#
#
# ###Answer:13.7%\\n
#
#
# 391
#
#
# ###Answer:0.6667143
# 392
#
#
# ###Answer:870.33333
# 393
#
#
# ###answer:350.52525
# 394
#
#
# ###Answer:2.4%\\n\\n
#
# 395
#
#
# ###Answer:18178.000
# 396
#
#
# ###Answer:82.7%\\n\\n
# 397
#
#
# ###Answer:36.7%\\n\\n
# 398
#
#
# ###answer:2.8954999
# 399
#
#
# ###Answer:1.3%\\n
#
# ##
# 400
#
#
# ###answer:12.0%\\n\\n
# 401
#
#
# ###answer:1.1%\\n\\n\\
# 402
#
#
# ###Answer:65%\\n
#
# ###
# 403
#
#
# ###Answer:2.7500000
# 404
#
#
# ###Answer:19.3%\\n\\n
# 405
#
#
# ###Answer:523.3 million dollars.\\
# 406
#
#
# ###Answer:150%\\n\\n
#
# 407
#
#
# ###Answer:1.2 million\\n\\n
#
# 408
#  to the percent of the outstanding shares of the company common stock repurch
# 409
#
#
# ###answer:35.2% and 35
# 410
#  and other non-current liabilities?
#
# ###Answer:3
# 411
#
#
# ###Answer:43.3%\\n\\n
# 412
#
#
# ###answer:16.600000
# 413
#
#
# ###Answer:1.4 million\\n
#
# ##
# 414
#
#
# ###Answer:2084.3333
# 415
#
#
# ###answer:166 million dollars\\n
#
#
# 416
#
#
# ###answer:35.5%\\n\\n
# 417
#
#
# ###Answer:41.7%\\n\\n
# 418
#
#
# ###Answer:15.4%\\n\\n
# 419
#
#
# ###answer:1436.3333
# 420
#
#
# ###Answer:11.4% increase in total exp
# 421
#
#
# ###Answer:82.86\\n\\n
# 422
#
#
# ###answer:15.6%\\n\\n
# 423
#
#
# ###Answer:12.25 million 20
# 424
#
#
# ###Answer:685000000
# 425
#
#
# ###Answer:10.4%\\n
#
#
# 426
#
#
# ###yes
#
# ###no
#
# ###n
# 427
#
#
# ###Answer:3.6%\\n\\n\\
# 428
#
#
# ###answer:183700000
# 429
#
#
# ###Answer:11.1%\\n\\n
# 430
#  from 2014 to 2015
#
# ##
# 431
#
#
# ###Answer:16.3%\\n\\n
# 432
#
#
# ###answer:10.5% increase in capital exp
# 433
#
#
# ###answer:37.5%\\n\\n
# 434
#
#
# ###answer:157.9%\\n\\
# 435
#
#
# ###Answer:16.4%\\n\\n
# 436
#
#
# ###answer:209480000
# 437
#
#
# ###Answer:15.2%\\n\\n
# 438
#
#
# ###Answer:14.2 million\\n
#
#
# 439
#
#
# ###answer:234000000
# 440
#
#
# ###Answer:20.3%\\n\\n
# 441
#
#
# ###answer:266% increase in net income from
# 442
#
#
# ###answer:15.365757
# 443
#
#
# ###answer:1600.55% of
# 444
#
#
# ###Answer:108.50000
# 445
#
#
# ###Answer:20.6%\\n
#
#
# 446
#
#
# ###Answer:0.0033333
# 447
#
#
# ###Answer:1.4% per year.\\n
# 448
#
#
# ###Answer:554000000
# 449
#
#
# ###Answer:182219.24
# 450
#
#
# ###Answer:2.25% ( 2.
# 451
#
#
# ###Answer:15.7%\\n\\n
# 452
#
#
# ###Answer:1.07%\\n\\n
# 453
#
#
# ###Answer:2.5%\\n\\n
#
# 454
#
#
# ###Answer:101.53333
# 455
#
#
# ###Answer:83% ( 83 % )
# 456
#
#
# ###Answer:5.715 and 5.
# 457
#
#
# ###Answer:12.5%\\n\\n
# 458
#
#
# ###Answer:17.6%\\n\\n
# 459
#
#
# ###answer:12.4%\\n
#
#
# 460
#
#
# ###Answer:69.9% ( 69
# 461
#
#
# ###Answer:192 towers were purchased under the
# 462
#
#
# ###answer:35.5% ( 35
# 463
# ?
#
# ###Answer:100% increase in citigr
# 464
#
#
# ###Answer:0.5%\\n
#
# ##
# 465
#
#
# ###Answer:100% increase in gain on land
# 466
#  and 2006?
#
# ###Answer:10
# 467
#
#
# ###answer:179519000
# 468
#
#
# ###Answer:2061 gwh in weather-
# 469
#
#
# ###Answer:114.36%\\n
# 470
#
#
# ###Answer:5190.0000
# 471
#
#
# ###answer:25.5% ( 25
# 472
#
#
# ###answer:77.1% ( 77
# 473
#
#
# ###Answer:19.4
#
# ###Ex
# 474
#
#
# ###Answer:9.5%\\n\\n
#
# 475
#
#
# ###answer:6.6367549
# 476
#
#
# ###answer:16.7%\\n\\n
# 477
#
#
# ###answer:45.5\\n\\n
#
# 478
#
#
# ###Answer:448450000
# 479
# ?
#
# ###answer:10.5%\\n\\
# 480
#
#
# ###Answer:13955.555
# 481
#
#
# ###answer:41%\\n\\n\\n
# 482
#
#
# ###Answer:98.27%\\n
#
# 483
#
#
# ###Answer:1.5% ( 1.5
# 484
#
#
# ###Answer:1.2616\\n\\
# 485
# ?
#
# ###Answer:100%\\n\\n
# 486
#
#
# ###Answer:8.5%\\n\\n\\
# 487
#
#
# ###Answer:139000\\n\\
# 488
#
#
# ###Answer:330.5 million dollars for fixed
# 489
#
#
# ###Answer:58%\\n\\n
#
#
# 490
#
#
# ###answer:5.3%\\n
#
# ##
# 491
#
#
# ###Answer:10.9%\\n"
#
# 492
#
#
# ###Answer:33.3%\\n\\n
# 493
#
#
# ###answer:78.333333
# 494
#
#
# ###Answer:14.4%\\n\\n
# 495
#
#
# ###answer:24%\\n
#
# ###
# 496
#
#
# ###Answer:1.3%\\n\\n
#
# 497
#
#
# ###Answer:71.6%\\n\\n
# 498
#
#
# ###Answer:35066.000
# 499
#
#
# ###Answer:36064.666
# 500
#
#
# ###answer:280.50000
# 501
#
#
# ###Answer:28.6%\\n\\n
# 502
#
#
# ###Answer:1.8%\\n\\n\\
# 503
#
#
# ###Answer:8.2%\\n\\n\\
# 504
#
#
# ###Answer:1.14\\n\\n
#
# 505
#
#
# ###answer:7.5%\\n\\n\\
# 506
#
#
# ###Answer:133.61%\\n
# 507
#
#
# ###Answer:927.1 million dollars 2
# 508
#
#
# ###answer:3.1%\\n\\n\\
# 509
#
#
# ###Answer:2.1%\\n\\n\\
# 510
#
#
# ###Answer:254412.50
# 511
#
#
# ###Answer:yes\\n\\n
#
# ###
# 512
#
#
# ###answer:8.25% 8.2
# 513
#
#
# ###Answer:29.9%\\n\\n
# 514
#
#
# ###Answer:3437.5 million dollars
#
# 515
#
#
# ###Answer:48.9%\\n\\n
# 516
#
#
# ###Answer:1.8456154
# 517
#
#
# ###Answer:10.5 years\\n\\n
# 518
#
#
# ###Answer:22.77%\\n
#
# 519
#  or sub-lease
#
# ###answer:33.3%
# 520
#
#
# ###answer:1.125\\n\\n
# 521
#
#
# ###Answer:7.4%\\n\\n
#
# 522
#
#
# ###answer:10.5%\\n
#
#
# 523
#
#
# ###Answer:12.4%\\n
#
#
# 524
#
#
# ###Answer:24.6%\\n
#
#
# 525
#
#
# ###Answer:24.9%\\n\\n
# 526
#
#
# ###Answer:13.6%\\n\\n
# 527
#
#
# ###Answer:40.23%\\n
#
# 528
# ?
#
# ###Answer:11589.57
# 529
#
#
# ###Answer:29%\\n
#
# ###
# 530
#
#
# ###Answer:18.7%\\n\\n
# 531
#
#
# ###answer:10% increase in 200
# 532
#
#
# ###answer:28.9% ( 28
# 533
#
#
# ###Answer:44936.66\\
# 534
#  in millions
#
# ###answer:19.5\\n
#
# 535
#
#
# ###Answer:102400000
# 536
#
#
# ###Answer:12.5%\\n
#
#
# 537
#
#
# ###Answer:45%\\n\\n
#
#
# 538
#
#
# ###Answer:148.36%\\n
# 539
#
#
# ###Answer:11.4%\\n\\n
# 540
#
#
# ###Answer:10.5%\\n
#
#
# 541
# , washington
#
# ###answer:1.75\\
# 542
#
#
# ###answer:15.7%\\n\\n
# 543
#
#
# ###answer:4.8%\\n\\n
#
# 544
#
#
# ###Answer:28.5%\\n\\n
# 545
#
#
# ###Answer:24000 units.
#
#
# 546
#
#
# ###Answer:1.2% ( 1.2
# 547
#
#
# ###Answer:14.5%\\n\\n
# 548
#
#
# ###answer:10.4% increase in fuel exp
# 549
#
#
# ###Answer:14.0%\\n\\n
# 550
#
#
# ###answer:36%\\n\\n
#
#
# 551
#
#
# ###Answer:13.6%\\n\\n
# 552
#
#
# ###answer:1.54\\n\\n
#
# 553
#
#
# ###Answer:4.2% ( 4.2
# 554
#
#
# ###Answer:3.17\\n
#
# ##
# 555
#
#
# ###Answer:6.96%\\n
#
#
# 556
#
#
# ###Answer:103.75\\n\\
# 557
#
#
# ###answer:0.0%\\n\\n\\
# 558
# ?
#
# ###answer:333333.3
# 559
#
#
# ###answer:8.6% ( 8.6
# 560
#
#
# ###Answer:10.3%\\n"
#
# 561
#
#
# ###Answer:10.8%\\n\\n
# 562
#
#
# ###Answer:3.2% ( 3.2
# 563
#
#
# ###Answer:44.5%\\n\\n
# 564
#
#
# ###Answer:10.1%\\n\\n
# 565
#
#
# ###Answer:33.3%\\n\\n
# 566
#
#
# ###Answer:10.7%\\n\\n
# 567
#
#
# ###Answer:11.5%\\n\\n
# 568
#
#
# ###answer:no\\n\\n
#
# ###
# 569
#  approved by security holders
#
# ###answer:99.9
# 570
#  obligations
#
# ###Answer:10.1%\\n
# 571
#
#
# ###Answer:2944.4444
# 572
# ?
#
# ###Answer:7.6675\\n
# 573
#
#
# ###Answer:16.1%\\n\\n
# 574
#
#
# ###Answer:6.65\\n
#
# ##
# 575
#
#
# ###Answer:3.5%\\n\\n
#
# 576
#
#
# ###answer:24478950.
# 577
#
#
# ###answer:2.14\\n\\n
#
# 578
#
#
# ###answer:35.7%\\n
#
#
# 579
# ?
#
# ###Answer:13.3% ( 1
# 580
#
#
# ###Answer:1.9%\\n
#
# ##
# 581
#
#
# ###Answer:12.7%\\n
#
#
# 582
#
#
# ###Answer:11.2%\\n\\n
# 583
#
#
# ###answer:697500000
# 584
#
#
# ###answer:26.6%\\n\\n
# 585
#
#
# ###Answer:17.5%\\n'
#
# 586
#
#
# ###answer:77559\\n\\n
# 587
#
#
# ###Answer:26.5%\\n\\n
# 588
#
#
# ###Answer:212.33333
# 589
#
#
# ###Answer:184.00000
# 590
#
#
# ###Answer:1.6% increase in operation and maintenance
# 591
#
#
# ###answer:1.25\\n\\n
#
# 592
#
#
# ###Answer:22.2%\\n\\n
# 593
#
#
# ###Answer:1.175:1.0
# 594
#  in millions
#
# ###Answer:367.000
# 595
#
#
# ###Answer:6.5\\n\\n
#
#
# 596
#
#
# ###Answer:382.33333
# 597
#
#
# ###Answer:1.5%\\n\\n
#
# 598
#
#
# ###Answer:16.4%\\n
#
#
# 599
#
#
# ###answer:88.8%\\n\\n
# 600
#
#
# ###Answer:3.5%\\n
#
# ##
# 601
#
#
# ###answer:1.5 million dollars in 20
# 602
#
#
# ###Answer:120760.50
# 603
#
#
# ###Answer:1.032000 to
# 604
#
#
# ###answer:100000000
# 605
#
#
# ###Answer:18%\\n\\n\\n
# 606
#
#
# ###answer:3.4%\\n\\n
#
# 607
#  remaining
#
# ###Answer:23.5%\\n\\
# 608
#
#
# ###Answer:38.1% increase in working capital
# 609
#
#
# ###answer:680000000
# 610
#
#
# ###answer:0.525%\\n
#
# 611
#
#
# ###Answer:15%\\n\\n
#
#
# 612
#
#
# ###Answer:6001.675\\
# 613
# ?
#
# ###Answer:20.8% increase in ear
# 614
#
#
# ###Answer:43.3%\\n\\n
# 615
#
#
# ###Answer:34.333333
# 616
#
#
# ###Answer:18.05%\\n\\
# 617
#
#
# ###Answer:14.6%\\n\\n
# 618
#
#
# ###Answer:174370000
# 619
#
#
# ###Answer:7850.3333
# 620
#
#
# ###answer:18.8%\\n\\n
# 621
#
#
# ###Answer:21.46%\\n
#
# 622
#
#
# ###Answer:18.75%\\n\\
# 623
#
#
# ###answer:1.66 million $ sales per employee
# 624
#
#
# ###Answer:11.6%\\n
#
#
# 625
#
#
# ###answer:yes\\n"
#
# ###question
# 626
#
#
# ###answer:yes\\n\\nno
#
# ##
# 627
# ?
#
# ###answer:39%\\n\\n\\
# 628
#
#
# ###answer:yes\\nno\\nyes\\n
# 629
#
#
# ###answer:1063.5000
# 630
#
#
# ###answer:17.7%\\n
#
#
# 631
#
#
# ###Answer:1.3% ( 1.3
# 632
#
#
# ###Answer:1.2%\\n\\n\\
# 633
#
#
# ###Answer:66.7%\\n\\n
# 634
#  in the retail electric price
#
# ###Answer:3.1
# 635
#
#
# ###answer:16.9%\\n
#
#
# 636
#
#
# ###Answer:1.4333333
# 637
#
#
# ###Answer:2374.6759
# 638
#
#
# ###Answer:11.6%\\n\\n
# 639
#
#
# ###answer:713542\\n\\
# 640
#
#
# ###answer:56.6%\\n\\n
# 641
#
#
# ###Answer:37.5%\\n"
#
# 642
# ?
#
# ###Answer:16.9%\\n\\
# 643
#
#
# ###Answer:16.7%\\n\\n
# 644
#
#
# ###Answer:16.1%\\n\\n
# 645
# ?
#
# ###Answer:150.7533
# 646
#
#
# ###Answer:258.60000
# 647
#
#
# ###Answer:65.3%\\n\\n
# 648
#
#
# ###Answer:yes, the change in asset impairment
# 649
#
#
# ###answer:69%\\n\\n
#
#
# 650
#
#
# ###answer:1.6%\\n\\n
#
# 651
#
#
# ###Answer:2.7%\\n\\n
#
# 652
#
#
# ###Answer:2831.5000
# 653
#
#
# ###answer:4.1%\\n\\n
#
# 654
#
#
# ###Answer:2.5%\\n\\n\\
# 655
#
#
# ###Answer:4.3%\\n\\n
#
# 656
#
#
# ###answer:46.5%\\n\\n
# 657
# ?
#
# ###Answer:4.5675\\n
# 658
#
#
# ###Answer:118.8%\\n
#
# 659
#
#
# ###Answer:7.5%\\n\\n
#
# 660
#
#
# ###Answer:5.8% ( 5.8
# 661
#
#
# ###answer:10.4%\\n\\n
# 662
#
#
# ###answer:5.2%\\n\\n\\
# 663
#
#
# ###Answer:4\\n\\n
#
# ###
# 664
#
#
# ###answer:33.3%\\n\\n
# 665
#
#
# ###Answer:10.3%\\n"
#
# 666
#
#
# ###Answer:18.5%\\n\\n
# 667
#
#
# ###Answer:1175.8%\\n
# 668
#
#
# ###answer:11%\\n\\n
#
#
# 669
#
#
# ###Answer:4.9%\\n\\n\\
# 670
#
#
# ###answer:10.4%\\n\\n
# 671
# ?
#
# ###Answer:16.2%\\n\\
# 672
#
#
# ###answer:223000000
# 673
#
#
# ###Answer:27.1%\\n"
#
# 674
#  in millions
#
# ###answer:21%\\ncommer
# 675
#
#
# ###answer:54.5%\\n\\n
# 676
#
#
# ###Answer:10.1%\\n\\n
# 677
#
#
# ###Answer:10.2% increase in reins
# 678
#
#
# ###Answer:28.5%\\n\\n
# 679
#
#
# ###Answer:26511\\n\\n
# 680
#
#
# ###Answer:16.4%\\n\\n
# 681
#
#
# ###answer:274.00000
# 682
#
#
# ###Answer:40.8%\\n
#
#
# 683
#  on the sale of approximately 4.9 million mastercard class b shares
# 684
#
#
# ###Answer:2166667.6
# 685
#
#
# ###Answer:15.9%\\n\\n
# 686
#
#
# ###Answer:575.2\\n\\n
# 687
#
#
# ###Answer:384000000
# 688
#
#
# ###Answer:23.5%\\n
#
#
# 689
#
#
# ###Answer:114353\\n\\
# 690
#
#
# ###Answer:37.9%\\n\\n
# 691
#
#
# ###Answer:25%\\n
#
# ###
# 692
# ?
#
# ###Answer:25.5%\\n\\
# 693
# 1
#
# ###answer:38.5%\\n\\
# 694
#
#
# ###answer:54%\\n\\n
#
#
# 695
#
#
# ###Answer:26%\\n
#
# ###
# 696
# ?
#
# ###Answer:10.5%\\n\\
# 697
#
#
# ###Answer:1.7%\\n
#
# ##
# 698
#
#
# ###Answer:169 million dollars.\\n
#
# 699
#
#
# ###Answer:1.8%\\n\\nin
# 700
#
#
# ###Answer:1.345:102
# 701
#
#
# ###answer:101.50000
# 702
#
#
# ###Answer:14%\\n\\n
#
#
# 703
#
#
# ###answer:1.425\\n\\n
# 704
#
#
# ###Answer:16.1%\\n\\n
# 705
#
#
# ###answer:15.3%\\n\\n
# 706
#
#
# ###Answer:14 million shares in the period 2
# 707
#
#
# ###Answer:2.6%\\n\\n
#
# 708
#
#
# ###Answer:20.333333
# 709
#
#
# ###answer:9.1%\\n\\n\\
# 710
#
#
# ###Answer:76.333333
# 711
#
#
# ###Answer:1.4152667
# 712
#
#
# ###Answer:50.075007
# 713
# ?
#
# ###Answer:177500.6
# 714
# ?
#
# ###Answer:932.4444
# 715
#
#
# ###Answer:105583.73
# 716
# ?
#
# ###Answer:100% increase in the weight
# 717
#
#
# ###Answer:85%\\n
#
# ###
# 718
#
#
# ###Answer:45.8%\\n\\n
# 719
#
#
# ###Answer:40%\\n\\n\\n
# 720
#
#
# ###Answer:53.9%\\n
#
#
# 721
#
#
# ###Answer:18.2%\\n\\n
# 722
#
#
# ###Answer:100% increase in otti between
# 723
#
#
# ###answer:1.246:1.2
# 724
#
#
# ###Answer:100000000
# 725
#  shares
#
# ###answer:30.56\\n\\
# 726
#
#
# ###answer:26.9%\\n\\n
# 727
#
#
# ###Answer:18.5%\\n
#
#
# 728
#
#
# ###answer:10.8%\\n\\n
# 729
#
#
# ###Answer:226.40000
# 730
#
#
# ###Answer:480 million dollars
#
# ###
# 731
#
#
# ###Answer:11.6%\\n\\n
# 732
#
#
# ###Answer:13.6%\\n\\n
# 733
#
#
# ###Answer:2061.0000
# 734
# , 2015 to 2016
#
# ##
# 735
#
#
# ###Answer:31890.675
# 736
#
#
# ###answer:588000000
# 737
#
#
# ###Answer:13.750000
# 738
#
#
# ###Answer:277.33333
# 739
#
#
# ###Answer:100% increase in maturity
# 740
#
#
# ###Answer:610.18888
# 741
# ?
#
# ###Answer:52.3%\\n\\
# 742
#
#
# ###Answer:46%\\n\\n\\n
# 743
#
#
# ###Answer:34.2%\\n
#
#
# 744
#
#
# ###answer:78.5%\\n\\n
# 745
#
#
# ###Answer:17.375% (
# 746
#
#
# ###Answer:10.0\\n\\n
#
# 747
#
#
# ###answer:1.25\\n\\n
#
# 748
#
#
# ###Answer:10.8%\\n\\n
# 749
#
#
# ###answer:8.4%\\n
#
# ##
# 750
#
#
# ###Answer:yes\\n\\nas of december
# 751
#
#
# ###answer:21%\\n\\n
#
#
# 752
#
#
# ###Answer:7.5%\\n\\n
#
# 753
#
#
# ###Answer:51.8%\\n\\n
# 754
#
#
# ###Answer:16.4%\\n\\n
# 755
#
#
# ###Answer:1.1% increase in securities
# 756
#
#
# ###Answer:33%\\n\\n\\n
# 757
#
#
# ###Answer:636.34243
# 758
#  in millions?
#
# ###Answer:3.8149
# 759
# ?
#
# ###Answer:35% ( 35 %
# 760
#
#
# ###answer:610000000
# 761
#
#
# ###Answer:248643.56
# 762
#
#
# ###Answer:10.8%\\n\\n
# 763
#
#
# ###Answer:8224.6676
# 764
#
#
# ###Answer:1175.8250
# 765
#
#
# ###Answer:18.5%\\n\\n
# 766
#
#
# ###Answer:15.4%\\n\\n
# 767
#
#
# ###answer:108000000
# 768
#
#
# ###Answer:17.5%\\n\\n
# 769
#
#
# ###Answer:16.7%\\n\\n
# 770
#
#
# ###answer:12% increase in 201
# 771
#
#
# ###Answer:18.5%\\n\\n
# 772
#
#
# ###answer:23.5 million dollars per locomotive
# 773
#
#
# ###Answer:65.7%\\n\\n
# 774
#
#
# ###Answer:3.5%\\n\\n
#
# 775
#
#
# ###Answer:11.6%\\n\\n
# 776
#
#
# ###answer:1.7% increase in the total carrying
# 777
#
#
# ###Answer:0.25% ( 0.
# 778
#
#
# ###answer:150000000
# 779
#
#
# ###Answer:8.1%\\n\\n\\
# 780
#
#
# ###Answer:259.5 million\\n\\
# 781
#
#
# ###Answer:11.7%\\n\\n
# 782
#
#
# ###Answer:47.4%\\n
#
#
# 783
#
#
# ###Answer:10.4%\\n\\n
# 784
#
#
# ###answer:123890000
# 785
#
#
# ###Answer:1221.5\\n
#
# 786
#
#
# ###Answer:25%\\n\\n
#
#
# 787
#
#
# ###Answer:378.52262
# 788
#
#
# ###Answer:9.1%\\n\\n
#
# 789
#
#
# ###Answer:27% ( 27 % )
# 790
#
#
# ###Answer:15.7%\\n
#
#
# 791
#
#
# ###Answer:208148.33
# 792
#
#
# ###answer:450.33333
# 793
#
#
# ###answer:100%\\n\\n
#
# 794
#
#
# ###Answer:2.1%\\n\\n\\
# 795
#
#
# ###answer:0.4%\\n
#
# ##
# 796
#
#
# ###Answer:24.2%\\n\\n
# 797
#
#
# ###Answer:134000000
# 798
#
#
# ###Answer:13.1%\\n\\n
# 799
#
#
# ###Answer:1.6%\\n\\n
#
# 800
#
#
# ###answer:33680.565
# 801
# ?
#
# ###Answer:10.62500
# 802
#
#
# ###Answer:1.7%\\n\\n
#
# 803
#
#
# ###Answer:134000000
# 804
#
#
# ###answer:2.15:1.00
# 805
# ?
#
# ###Answer:1.50% higher than the
# 806
#
#
# ###Answer:177332.50
# 807
#
#
# ###Answer:100% increase in the settlements
# 808
#
#
# ###Answer:31.3%\\n
#
#
# 809
#
#
# ###Answer:6.6%\\n\\n
#
# 810
# \\n\\n\\n\\n\\n\\n\\n\\
# 811
#
#
# ###Answer:12850.500
# 812
#
#
# ###Answer:143.81%\\n
# 813
#
#
# ###answer:21%\\n\\n
#
#
# 814
#
#
# ###answer:56%\\n\\n
#
#
# 815
#
#
# ###answer:100000000
# 816
#
#
# ###answer:75% ( 75 % )
# 817
#  to the unamortized unrealized pre-tax losses of $
# 818
#
#
# ###Answer:114%\\n
#
# ##
# 819
#
#
# ###Answer:1.3344545
# 820
#
#
# ###Answer:18.75% ( 1
# 821
#
#
# ###Answer:2.4\\n\\n
#
#
# 822
#
#
# ###Answer:20.39%\\n\\
# 823
#
#
# ###answer:51.3%\\n\\n
# 824
#
#
# ###Answer:20704\\n
#
#
# 825
#
#
# ###answer:3.3%\\n\\n\\
# 826
#
#
# ###Answer:102.49%\\n
# 827
#
#
# ###Answer:10.9%\\n\\n
# 828
#
#
# ###answer:20% ( 20 % )
# 829
#
#
# ###Answer:10.7%\\n
#
#
# 830
#
#
# ###answer:3.44:1.00
# 831
#
#
# ###Answer:45.7%\\n\\n
# 832
#
#
# ###Answer:12.5%\\n\\n
# 833
#
#
# ###Answer:111.81%\\n
# 834
#
#
# ###answer:3593.4525
# 835
#
#
# ###Answer:254141.5\\
# 836
# ?
#
# ###Answer:65.8%\\n
#
# 837
#
#
# ###answer:79.12 to 85
# 838
#
#
# ###Answer:26.5%\\n\\n
# 839
#
#
# ###Answer:100%\\n"
#
#
# 840
#
#
# ###Answer:19.5%\\n\\n
# 841
#
#
# ###answer:51%\\n\\n\\n
# 842
#
#
# ###answer:14%\\n\\n
#
#
# 843
#
#
# ###Answer:21.25\\n\\n
# 844
#
#
# ###Answer:6.0%\\n
#
# ##
# 845
#  500
#
# ###Answer:1.942
# 846
#
#
# ###answer:21%\\n\\n
#
#
# 847
#  of 2014?
#
# ###Answer:8.
# 848
#
#
# ###Answer:100% increase in the aggregate net
# 849
#
#
# ###Answer:10.7% increase in the excess
# 850
# ?
#
# ###Answer:10.2%\\n"
# 851
#
#
# ###Answer:45775.250
# 852
#  and 2007
#
# ###Answer:513
# 853
#
#
# ###Answer:89.5%\\n\\n
# 854
#
#
# ###Answer:150.56675
# 855
#  for sikorsky
#
# ###Answer:7.4%\\
# 856
#
#
# ###Answer:1.3% more money was expensed
# 857
#
#
# ###Answer:37.2% increase in the amount
# 858
#
#
# ###Answer:50.5 million dollars\\n\\
# 859
#
#
# ###Answer:21.4%\\n"
#
# 860
#
#
# ###Answer:25%\\n
#
# ###
# 861
#
#
# ###Answer:39.95
#
# ###
# 862
#
#
# ###Answer:1.67:1.00
# 863
#
#
# ###Answer:138.4 million dollars
#
#
# 864
#
#
# ###answer:10.1%\\n\\n
# 865
#
#
# ###Answer:3.1%\\n\\n\\
# 866
#
#
# ###Answer:no\\n
#
# ###Explan
# 867
#
#
# ###Answer:4.3%\\n\\n\\
# 868
#
#
# ###Answer:6800.3333
# 869
#
#
# ###Answer:5796.2 million dollars.
# 870
#
#
# ###Answer:10.6%\\n
#
#
# 871
#
#
# ###Answer:12.5%\\n\\n
# 872
#
#
# ###Answer:34.75\\n
#
#
# 873
#
#
# ###answer:15.6%\\n\\n
# 874
#
#
# ###Answer:13.6%\\n\\n
# 875
#
#
# ###answer:17.5%\\n\\n
# 876
#
#
# ###Answer:10.3%\\n\\n
# 877
#
#
# ###Answer:3303.94\\n
# 878
#
#
# ###answer:10.7%\\n
#
#
# 879
#
#
# ###answer:39601\\n\\n
# 880
#
#
# ###Answer:13.5%\\n"
#
# 881
#
#
# ###answer:26.7%\\n\\n
# 882
#
#
# ###Answer:1.675\\n
#
#
# 883
#
#
# ###answer:40%\\n\\n\\n
# 884
#
#
# ###Answer:49.5%\\n\\n
# 885
#
#
# ###answer:1950.5000
# 886
#
#
# ###Answer:12.5%\\n
#
#
# 887
#
#
# ###Answer:36.35% of the total
# 888
#
#
# ###Answer:yes\\n
#
# ###Explan
# 889
#
#
# ###yes
#
# ###no
#
# ###n
# 890
#  asset allocation
#
# ###Answer:14%\\n\\n
# 891
#
#
# ###Answer:137500000
# 892
#
#
# ###Answer:162.00000
# 893
#
#
# ###Answer:101.50\\n\\
# 894
#
#
# ###Answer:1.675:1.0
# 895
#
#
# ###Answer:3.00 years\\n\\n
# 896
#
#
# ###answer:250.625 million
# 897
#
#
# ###answer:32.5%\\n\\n
# 898
#
#
# ###Answer:30.5%\\n\\n
# 899
#
#
# ###Answer:106.7%\\n\\
# 900
#
#
# ###answer:yes, 18.4% higher
# 901
#
#
# ###Answer:73.0% ( 73
# 902
#
#
# ###Answer:22.5%\\n\\n
# 903
#
#
# ###Answer:2.75\\n\\n
#
# 904
#
#
# ###Answer:2.8978627
# 905
# ?
#
# ###Answer:2.7%\\n\\n
# 906
#
#
# ###answer:1.48 : 1.0
# 907
#
#
# ###Answer:49.7%\\n\\n
# 908
#
#
# ###answer:20%\\n\\n
#
#
# 909
#
#
# ###Answer:0.5%\\n
#
# ##
# 910
#
#
# ###Answer:10.3%\\n\\n
# 911
#
#
# ###Answer:14.7 million dollars\\n\\
# 912
#
#
# ###Answer:46332.333
# 913
#
#
# ###Answer:1.1%\\n\\n\\
# 914
#
#
# ###Answer:46.4 million dollars.\\n
# 915
#
#
# ###Answer:494.2%\\n
#
# 916
#
#
# ###Answer:0.0001%\\n
# 917
#
#
# ###answer:51%\\n\\n
#
#
# 918
#
#
# ###answer:100% increase in operating leases
# 919
#
#
# ###answer:10.2%\\n\\n
# 920
#
#
# ###Answer:16.156757
# 921
#
#
# ###answer:0.17% ( 0.
# 922
#
#
# ###answer:10.4%\\n\\n
# 923
#
#
# ###Answer:358.25k shares\\
# 924
#
#
# ###answer:0.26% ( 0.
# 925
#
#
# ###answer:yes\\nno\\nyes
#
#
# 926
#
#
# ###Answer:7.5%\\n\\n
#
# 927
#
#
# ###answer:77.649844
# 928
#
#
# ###Answer:10.5%\\n\\n
# 929
#
#
# ###Answer:131.5%\\n\\
# 930
#
#
# ###answer:72% to 28% deb
# 931
#
#
# ###Answer:19.46%\\n
#
# 932
#
#
# ###answer:1.25\\n\\n
#
# 933
#  in millions
#
# ###Answer:3.75%\\n
# 934
#
#
# ###Answer:9.1 million dollars.\\n\\
# 935
#
#
# ###Answer:0.1% ( 0.1
# 936
# ?
#
# ###Answer:27.4% ( 2
# 937
# ?
#
# ###answer:15752.00
# 938
#
#
# ###Answer:136.20%\\n
# 939
#
#
# ###answer:40% ( 40 % )
# 940
#
#
# ###Answer:179.14526
# 941
#
#
# ###Answer:1438 million dollars
#
# ##
# 942
#
#
# ###answer:1150.5000
# 943
#
#
# ###Answer:129%\\n\\n
#
# 944
#
#
# ###answer:98.6%\\n\\n
# 945
#
#
# ###Answer:15.1%\\n\\n
# 946
# ?
#
# ###Answer:80.33333
# 947
#
#
# ###answer:10.5%\\n\\n
# 948
#
#
# ###answer:12.3%\\n\\n
# 949
#  from 2017 to 2018
#
# ##
# 950
#
#
# ###Answer:1.4%\\n\\n\\
# 951
#
#
# ###Answer:113500000
# 952
#  in 2017?
#
# ###Answer:22
# 953
#
#
# ###Answer:15.46%\\n
#
# 954
#
#
# ###Answer:7.6%\\n\\n
#
# 955
#
#
# ###Answer:33.3%\\n\\n
# 956
#
#
# ###answer:6.2%\\n\\n\\
# 957
#
#
# ###Answer:39.5%\\n\\n
# 958
#
#
# ###Answer:205500000
# 959
#
#
# ###Answer:3.3333333
# 960
#
#
# ###answer:89%\\n\\n\\n
# 961
#
#
# ###Answer:14.9%\\n\\n
# 962
#
#
# ###answer:1.045\\n\\n
# 963
#
#
# ###Answer:28.858443
# 964
#
#
# ###Answer:58%\\n\\n
#
#
# 965
#
#
# ###Answer:45%\\n\\n\\n
# 966
#
#
# ###Answer:198.5 million dollars
#
#
# 967
#
#
# ###Answer:216.75 million\\n
# 968
#
#
# ###Answer:yes\\n\\nin 20
# 969
#
#
# ###answer:541.7\\n\\n
# 970
#
#
# ###answer:10.3%\\n\\n
# 971
#
#
# ###answer:45.4%\\ninterest
# 972
#
#
# ###Answer:198180.00
# 973
# ?
#
# ###answer:11257340
# 974
#
#
# ###Answer:188.46%\\n
# 975
#
#
# ###answer:89.5%\\n\\n
# 976
#
#
# ###Answer:47%\\n\\n\\n
# 977
#
#
# ###answer:16%\\n\\n\\n
# 978
#
#
# ###Answer:1.1%\\n\\n
#
# 979
#
#
# ###Answer:23.5%\\n\\n
# 980
#
#
# ###Answer:41.4 million dollars.\\n
# 981
# ?
#
# ###Answer:75.8%\\n
#
# 982
#  from 2011 to 2012
#
# ##
# 983
#  in 2010
#
# ###answer:69.
# 984
#
#
# ###Answer:16.7% ( 16
# 985
#
#
# ###Answer:18%\\n\\n
#
#
# 986
#
#
# ###Answer:20.5%\\n\\n
# 987
#
#
# ###Answer:15%\\n
#
# ###
# 988
#
#
# ###answer:35066\\n24
# 989
#
#
# ###Answer:11.4%\\n\\n
# 990
#
#
# ###Answer:1.3345121
# 991
# ?
#
# ###Answer:18205000
# 992
#
#
# ###Answer:2.5%\\n
#
# ##
# 993
#
#
# ###Answer:15.2%\\n
#
#
# 994
#
#
# ###Answer:1.3333333
# 995
#
#
# ###answer:15.5%\\n\\n
# 996
# ?
#
# ###Answer:1.5% ( 1.
# 997
#
#
# ###Answer:0.3%\\n\\n
#
# 998
#
#
# ###answer:190%\\n\\n\\
# 999
#
#
# ###Answer:10.2%\\n\\n
# 1000
#
#
# ###Answer:10.7%\\n\\n
# 1001
#
#
# ###answer:16.4%\\n"
#
# 1002
#
#
# ###Answer:18.5%\\n\\n
# 1003
#
#
# ###Answer:1.33%\\n
#
#
# 1004
#
#
# ###Answer:1535.9 million dollars
#
# 1005
#
#
# ###answer:18.5%\\n\\n
# 1006
#
#
# ###Answer:10.5%\\n
#
#
# 1007
# ?
#
# ###Answer:60.62%\\n
# 1008
#
#
# ###Answer:106.6 million dollars 2
# 1009
# ?
#
# ###Answer:275.6333
# 1010
#
#
# ###answer:262400000
# 1011
#
#
# ###Answer:77.711333
# 1012
#
#
# ###Answer:1.8% increase in net interest exp
# 1013
#
#
# ###answer:12.5%\\n\\n
# 1014
#
#
# ###answer:1.25:1.00
# 1015
#
#
# ###Answer:84.48\\n\\n
# 1016
#
#
# ###Answer:9.2%\\n\\n
#
# 1017
#
#
# ###Answer:16.3% increase in billions
# 1018
#
#
# ###answer:16.3%\\n\\n
# 1019
#
#
# ###answer:113700000
# 1020
#
#
# ###Answer:13.3%\\n\\n
# 1021
#
#
# ###Answer:372307\\n
#
# 1022
#
#
# ###Answer:120%\\n\\njk
# 1023
#
#
# ###answer:1.8%\\n\\n
#
# 1024
#
#
# ###Answer:11.8%\\n\\n
# 1025
#
#
# ###Answer:362.50000
# 1026
#
#
# ###Answer:21.4%\\n"
#
# 1027
#
#
# ###Answer:31.5%\\n\\n
# 1028
#  revenues
#
# ###Answer:17.5%\\n
# 1029
#
#
# ###answer:70%\\n\\n
#
#
# 1030
# ?
#
# ###answer:6.25% ( 6
# 1031
#
#
# ###Answer:35%\\n
#
# ###
# 1032
#
#
# ###Answer:10% increase in the percentage of the
# 1033
#
#
# ###Answer:24.5%\\n\\n
# 1034
#
#
# ###Answer:1.3%\\n\\n
#
# 1035
#
#
# ###Answer:1133.5 million dollars
#
# 1036
#
#
# ###answer:13.5%\\n\\n
# 1037
#
#
# ###Answer:1.5%\\n\\n
#
# 1038
#
#
# ###answer:58654.757
# 1039
#
#
# ###Answer:16.5%\\n\\n
# 1040
#
#
# ###Answer:108.8%\\n\\
# 1041
#
#
# ###Answer:128%\\n\\nwhat
# 1042
#
#
# ###Answer:324.95\\n\\
# 1043
#
#
# ###Answer:140.29%\\n
# 1044
# ?
#
# ###Answer:16.2%\\n"
# 1045
#
#
# ###Answer:10.4%\\n
#
#
# 1046
#
#
# ###Answer:1.4 million\\n
#
# ##
# 1047
#
#
# ###Answer:10.5%\\n
#
#
# 1048
#
#
# ###Answer:5.525\\n\\n
# 1049
#
#
# ###Answer:18.5%\\n
#
#
# 1050
#
#
# ###answer:31%\\n"
#
# ##
# 1051
#
#
# ###Answer:11160000.
# 1052
#
#
# ###Answer:100%\\n\\n
#
# 1053
# ?
#
# ###Answer:29%\\n\\n
#
# 1054
#
#
# ###answer:33.69%\\n\\
# 1055
#
#
# ###Answer:13.1%\\n
#
#
# 1056
#
#
# ###answer:51%\\n"
#
# ##
# 1057
#
#
# ###answer:13.5%\\n\\n
# 1058
#
#
# ###Answer:83%\\n
#
# ###
# 1059
#
#
# ###answer:1.4%\\n\\nbased
# 1060
#
#
# ###Answer:21%\\n
#
# ###
# 1061
#
#
# ###answer:13.6%\\n\\n
# 1062
#
#
# ###Answer:10.7%\\n\\n
# 1063
#
#
# ###answer:15.6%\\n15
# 1064
#
#
# ###answer:10.6%\\n\\n
# 1065
#
#
# ###Answer:20%\\n
#
# ###
# 1066
#
#
# ###answer:100% increase in the reserve for
# 1067
#
#
# ###Answer:30.4%\\n30
# 1068
#
#
# ###answer:10.6%\\n\\n
# 1069
#
#
# ###answer:132493.5\\
# 1070
#
#
# ###Answer:23%\\n\\n\\n
# 1071
#
#
# ###answer:36.9%\\n\\n
# 1072
#
#
# ###answer:1.1554897
# 1073
#
#
# ###Answer:1891 million dollars.\\n
# 1074
#
#
# ###Answer:55%\\n
#
# ###
# 1075
#
#
# ###Answer:25%\\n\\n\\n
# 1076
# ?
#
# ###Answer:245.5888
# 1077
#
#
# ###Answer:14.1%\\n
#
#
# 1078
#
#
# ###Answer:16.7%\\n"
#
# 1079
#
#
# ###Answer:13.4 to -13.
# 1080
#
#
# ###answer:11.1%\\n\\n
# 1081
#
#
# ###Answer:1455 million dollars\\n
#
# 1082
#
#
# ###answer:250000000
# 1083
#
#
# ###Answer:17.3%\\n"
#
# 1084
#
#
# ###Answer:10.5%\\n
#
#
# 1085
#
#
# ###answer:527000000
# 1086
#
#
# ###answer:600000000
# 1087
#
#
# ###answer:11.4%\\n\\n
# 1088
#
#
# ###Answer:163.4%\\n\\
# 1089
#
#
# ###Answer:7.5%\\n\\n
#
# 1090
# ?
#
# ###Answer:7.7%\\n\\n
# 1091
#
#
# ###answer:34.6%\\n\\n
# 1092
#
#
# ###Answer:3.6525000
# 1093
#
#
# ###Answer:5748.5% higher than
# 1094
# ?
#
# ###Answer:7.4%\\n\\n
# 1095
#
#
# ###answer:1.67%\\n\\n
# 1096
#
#
# ###answer:33.69%\\n\\
# 1097
#
#
# ###Answer:24.2%\\n"
#
# 1098
#
#
# ###Answer:106.37%\\n
# 1099
#
#
# ###Answer:20%\\n
#
# ###
# 1100
#
#
# ###Answer:10.6%\\n\\n
# 1101
#
#
# ###Answer:10.3%\\n\\n
# 1102
# ?
#
# ###Answer:651.6666
# 1103
#
#
# ###answer:13.4%\\n\\n
# 1104
#
#
# ###answer:18 million dollars\\n
#
# ##
# 1105
#
#
# ###answer:10.8% increase in interest with
# 1106
#
#
# ###answer:21 million dollars 2100
# 1107
#
#
# ###Answer:14513720 shares
# 1108
#
#
# ###answer:100%\\n\\ncons
# 1109
#
#
# ###Answer:162.4%\\n\\
# 1110
#
#
# ###answer:23%\\n\\n
#
#
# 1111
#
#
# ###answer:17.6%\\n\\n
# 1112
#  under existing debt and lease commitments and purchase obligations at december
# 1113
#
#
# ###answer:1.125\\n\\n
# 1114
#
#
# ###answer:100.00000
# 1115
#
#
# ###Answer:51.6%\\n"
#
# 1116
# ?
#
# ###Answer:528.3554
# 1117
#
#
# ###Answer:118%\\n\\n
#
# 1118
#
#
# ###Answer:27%\\n\\n
#
#
# 1119
#
#
# ###Answer:52%\\n"
#
# ##
# 1120
#
#
# ###answer:56%\\n\\n\\n
# 1121
#
#
# ###answer:18.2%\\n\\n
# 1122
#
#
# ###Answer:1892 million dollars.
#
#
# 1123
#
#
# ###Answer:10.7%\\n\\n
# 1124
#
#
# ###answer:122 million dollars\\n
#
#
# 1125
#
#
# ###Answer:11.5%\\n
#
#
# 1126
#
#
# ###answer:48.3%\\n\\n
# 1127
#
#
# ###Answer:4.1%\\n\\n\\
# 1128
#
#
# ###Answer:40%\\n\\n
#
#
# 1129
#
#
# ###Answer:1071 million dollars\\n
#
# 1130
#  in the balance of unrecognized tax benefits
#
# ###answer:
# 1131
#
#
# ###answer:16.7%\\n\\n
# 1132
#
#
# ###Answer:10612.500
# 1133
#
#
# ###answer:12.3%\\n\\n
# 1134
#
#
# ###Answer:10.4%\\n\\n
# 1135
#
#
# ###answer:11.833333
# 1136
#
#
# ###Answer:52.9%\\n\\n
# 1137
#
#
# ###Answer:10.4%\\n
#
#
# 1138
#
#
# ###Answer:113310600
# 1139
#
#
# ###answer:56.5%\\n\\n
# 1140
#
#
# ###Answer:1.3333333
# 1141
#
#
# ###Answer:111%\\n\\n
#
# 1142
#
#
# ###Answer:14.86%\\n
#
# 1143
#
#
# ###Answer:11.5%\\n\\n
# 1144
#
#
# ###Answer:243.33333
# 1145
# ?
#
# ###Answer:21.75\\n\\
# 1146
#
#
# ###Answer:4.5 billion dollars
#
# ###
# 1147
# --- 44877.314284563065 seconds ---

# %%
dataset_pd['prediction'] = output_list ### Add the output to test dataset for evaluation

# %% [markdown]
# ### Perform Post Processing

# %%
def map_yes_no(x):
    x = str(x)
    if x.lower() in 'yes':
        return '1'
    elif x.lower() in 'no':
        return '0'
    else:
        return x
    
def remove_non_numeric(x):
    x = str(x)
    pattern = re.compile(r"[^\d.]")
    x = pattern.sub("", x)
    return x


def other_formatting(x):
  x =str(x)
  x=x.replace('...', '')
  x=x.replace('..', '')
  tofind = '.'
  if x.count(tofind) > 1:
    pos = x.index(tofind, x.index(tofind) + 1)
    x = x[:pos] + '' + x[pos + 1:]
    return x
  else:
    return x


def replace_blanks(x):
  x =str(x)
  if x.strip() == '':
    return '0'
  else:
    return x

# %% [markdown]
# ### Appply Post processing functions

# %%
dataset_pd['formatted_answer']  = dataset_pd['answer'].apply(map_yes_no)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(remove_non_numeric)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(other_formatting)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(replace_blanks)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].astype(float)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].round()

# %%
dataset_pd['formatted_prediction']  = dataset_pd['prediction'].apply(map_yes_no)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(remove_non_numeric)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(other_formatting)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(replace_blanks)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].astype(float)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].round()

# %% [markdown]
# ## Extract the final result

# %%
import numpy as np
dataset_pd['match_ind'] = np.where( dataset_pd['formatted_answer'] == dataset_pd['formatted_prediction'], 1,0)
dataset_pd['match_ind'].mean()
# Out:
# 0.16041848299912817

# %% [markdown]
# ### The exact match accuracy score for LLaMA 2 model with Rank 128 is 0.16
