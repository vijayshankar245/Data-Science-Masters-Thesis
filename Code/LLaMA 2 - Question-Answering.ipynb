# %% [markdown]
# This Notebook is the implementation of fine-tuning LLaMA 2 LLM on FinQA Dataset for Question-answering task. Evaluation was performed on test dataset and results have been reported.

# %% [markdown]
# ### Install Required Libraries and Packages¶

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# !pip install huggingface_hub
# !pip install -q datasets

import re
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
from datasets import load_dataset
import pandas as pd
import random
from datasets import Dataset
from datasets import load_dataset
import pandas as pd
import random
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 80.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.11.17)

# %% [markdown]
# ### Login into Hugging Face hub

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# #### Load the data

# %% [markdown]
# - Train and Test data has been loaded
# - FINQA has separate Split for train and test data and hence same has been loaded from hugging face hub
# - Data has been converted into a format which can be used to fine tune the LLMs

# %%
pd.set_option('display.max_colwidth', -1)
dataset = load_dataset("dreamerdeo/finqa",split="train") ### Load train data from hugging face hub
 
dataset_pd = dataset.to_pandas() ### convert to pandas

def table_format(x_input): ### format the tabular data in the financial report in pipe delimited format
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x): ### Convert the list of sentences into a single paragraph of sentences 
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)


### Instructions to be overlaid to the train dataset
instructions = [
    "Financial data and expert analysis has been provided as context, use the provided context to answer the question.",
    "Please provide the required answer to this expert-authored finance question based on the context given.",
    "A deep financial question based on a financial report has been given along with required context, could you help answer the financial question.",
    "Analysis based on financial documents has been given as context, please answer the question using the context.",
    "Financial report data and analysis has been given as context , please respond to the question using the context given."
]

## Add the instructions
ins_list = []
for ins in range(6251):
  ins = random.choice(instructions)
  ins_list.append(ins)


dataset_pd['instructions'] = ins_list

### Finally combine all the formatted columns together to form the final prompt
ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = f'###Instruction:'  + dataset_pd['instructions'] + ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question'] +  f'\n\n###Answer:' +  dataset_pd['answer']

from datasets import Dataset
train_df = Dataset.from_pandas(dataset_pd)
dataset_dct = train_df.train_test_split(test_size=0.25) ### Create validation dataset from train dataset

### Get the Train and Test Dataset from Hugging Face Dataset Dict object
df_train = dataset_dct["train"]
df_eval = dataset_dct["test"]
# Out:
# <ipython-input-4-222c4df8f7fc>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
# Downloading builder script:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/515 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data: 0.00B [00:00, ?B/s]
# /root/.cache/huggingface/datasets/downloads/extracted/ca045c27488b49db24426c67e0b35e06b0188746c40ffaf8d01a7b51e52924dc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Fine-Tuning Framework Parameters

# %%
# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-hf"



# Fine-tuned model name
new_model = "llama-2-7b-finqa-rank-64-vj"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64 ### RANK PARAMETER

# Alpha parameter for LoRA scaling
lora_alpha = 128

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = True

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = 2000

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

device_map = {"": 0}

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)


# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform Fine-Tuning

# %%
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard",
    evaluation_strategy="epoch"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=df_train,
    eval_dataset=df_eval,
    peft_config=peft_config,
    dataset_text_field="final_instruction",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# Map:   0%|          | 0/4688 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1563 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='1172' max='1172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1172/1172 57:27, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.828400</td>
#       <td>0.906243</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-hf"

# Fine-tuned model name
new_model = "llama-2-7b-finqa-rank-64-vj"


# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, new_model)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ### Push the fine-tuned model to hugging Face Hub

# %%
# !huggingface-cli login

model.push_to_hub(new_model, use_temp_dir=False)
tokenizer.push_to_hub(new_model, use_temp_dir=False)
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/vijayshankar245/llama-2-7b-finqa-rank-64-vj/commit/1e87ebe101e44c89307750284e1d615e26be5335', commit_message='Upload tokenizer', commit_description='', oid='1e87ebe101e44c89307750284e1d615e26be5335', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### Evaluation

# %% [markdown]
# - Apply the necessary formatting on test data (Same steps which were followed for train dataset)

# %%
dataset = load_dataset("dreamerdeo/finqa",split="test")

dataset_pd = dataset.to_pandas()

def table_format(x_input):
  fin_list = []
  x = x_input.tolist()
  for i in range(len(x)):
    j = x[i]
    x_str="|".join(str(element) for element in j)
    fin_list.append(x_str)
  final_str = f"\n".join(str(element) for element in fin_list)
  return final_str


def conv_list_string(x):
  x_list = x.tolist()
  x_string="".join(str(element) for element in x)
  return x_string

dataset_pd['pre_text'] = dataset_pd['pre_text'].map(conv_list_string)
dataset_pd['table'] = dataset_pd['table'].apply(table_format)
dataset_pd['post_text'] = dataset_pd['post_text'].map(conv_list_string)
dataset_pd['gold_evidence'] = dataset_pd['gold_evidence'].map(conv_list_string)




ins_str = 'context has financial text followed by pipe delimited table and some more financial text is given below the pipe delimited table. Use multi-step numerical reasoning and logical reasoning wherever required to answer the given question'
dataset_pd['final_instruction'] = ins_str + f'\n\n' + f'####context:' + f'\n' + dataset_pd['pre_text'] + f'\n'+ dataset_pd['table'] + f'\n' + dataset_pd['post_text'] + f'\n\n' +f'####question:' + dataset_pd['question']

from datasets import Dataset
test_df = Dataset.from_pandas(dataset_pd)
# Out:
# Downloading builder script:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/515 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
#   warnings.warn("Repo card metadata block was not found. Setting CardData to empty.")
# Downloading data: 0.00B [00:00, ?B/s]
# /root/.cache/huggingface/datasets/downloads/extracted/ca045c27488b49db24426c67e0b35e06b0188746c40ffaf8d01a7b51e52924dc
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# ### Load the fine-tuned model for evaluation

# %%
# Ignore warnings
logging.set_verbosity(logging.CRITICAL)
model = "vijayshankar245/llama-2-7b-finqa-rank-64-vj"
tokenizer = AutoTokenizer.from_pretrained(model, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Run text generation pipeline with our next model

pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer,return_full_text=False,temperature=0.1,top_p =0.9,max_new_tokens = 15)
# Out:
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/437 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]

# %% [markdown]
# ### Perform the evaluation and extract the results

# %%
import time
start_time = time.time()
from transformers.pipelines.pt_utils import KeyDataset
output_list = []
j=0
for i in pipe(KeyDataset(test_df, "final_instruction")):
  j=j+1
  print(i[0]['generated_text'])
  output_list.append(i[0]['generated_text'])
  print(j)
  df = pd.DataFrame({'output': output_list})
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ###Answer:94.4 million\\n\\n
# 1
#
#
# ###Answer:14.5%\\n\\n
# 2
#
#
# ###Answer:10.6% ( 10
# 3
#
#
# ###Answer:5.5%\\n\\n\\
# 4
#
#
# ### Answer:18.46%..
#
# 5
#
#
# ###Answer:15.4%\\n\\n
# 6
#
#
# ###Answer:9.5% ( 9.5
# 7
#
#
# ###Answer:12%\\n\\n\\n
# 8
#
#
# ###Answer:yes, by 86.63
# 9
#
#
# ###Answer:165 million\\n\\nwhat
# 10
#
#
# ###Answer:1.9% ( 1.9
# 11
#
#
# ### Answer:22.1%\\n\\n
# 12
#
#
# ###Answer:23.4%\\n\\n
# 13
#
#
# ###Answer:yes\\n\\n\\n\\n
# 14
# ?
#
# ###Answer:3.4%\\n\\n
# 15
#
#
# ###Answer:3913.3333
# 16
#
#
# ###Answer:100000000
# 17
# ?
#
# ### Answer:704.5555
# 18
#
#
# ###Answer:11.3%\\n\\n
# 19
#
#
# ###Answer:24.700000
# 20
# ?
#
# ###Answer:15.5%\\n\\
# 21
#
#
# ###Answer:11.81%.
#
#
# 22
#
#
# ###Answer:11.8%\\n\\n
# 23
#
#
# ###Answer:1.9%\\n\\n\\
# 24
#
#
# ###Answer:1.4414414
# 25
#
#
# ###Answer:1.7517517
# 26
#
#
# ###Answer:35.5%\\n\\n
# 27
#
#
# ###Answer:10.5% ( 10
# 28
# ?
#
# ###Answer:10.35250
# 29
#
#
# ###Answer:5.4%\\n\\n\\
# 30
#
#
# ###Answer:16.5%\\n\\n
# 31
#
#
# ###Answer:21% ( 21 % )
# 32
#
#
# ###Answer:1040.0000
# 33
#
#
# ###Answer:6.1% ( 6.1
# 34
#
#
# ###Answer:59147 million dollars.
#
# 35
#
#
# ###Answer:1.68\\n\\n
#
# 36
#
#
# ###Answer:23.5%\\n\\n
# 37
#
#
# ###Answer:7.6%\\n\\n\\
# 38
#
#
# ###Answer:11.212500
# 39
#
#
# ###Answer:1939734 shares and
# 40
#
#
# ###Answer:95.6 million\\n\\n
# 41
#
#
# ###Answer:148.36%.
#
# 42
#  in millions
#
# ###Answer:35.4375
# 43
#
#
# ###Answer:45%\\n\\nwhat percent
# 44
#
#
# ###Answer:900.8 million\\n\\
# 45
#
#
# ###Answer:3620.4681
# 46
#
#
# ###Answer:13.5% ( 13
# 47
#
#
# ###Answer:11.5%\\n\\n
# 48
#
#
# ###Answer:17.5%\\n\\n
# 49
#
#
# ###Answer:32.5%\\n\\n
# 50
#
#
# ###Answer:23.7%\\n\\n
# 51
#  in connection with the federal reserve bank 2019s treas
# 52
#
#
# ###Answer:114000000
# 53
#
#
# ###Answer:3.00\\n\\n
#
# 54
#
#
# ### Answer:10.8%\\n\\n
# 55
#
#
# ###Answer:37.5% ( 37
# 56
#  from 2015 to 2016?
#
#
# 57
#
#
# ###Answer:9.5%\\n\\n\\
# 58
#
#
# ###Answer:1.8%\\n\\n\\
# 59
# ?
#
# ###Answer:487000.3
# 60
#
#
# ###Answer:28.5%\\n\\n
# 61
#
#
# ###answer:1.3533333
# 62
#
#
# ###Answer:357986000
# 63
#
#
# ###Answer:101.5 million\\n\\
# 64
#
#
# ###Answer:103.7%..
#
# 65
#
#
# ###Answer:100% ( 100
# 66
#
#
# ###Answer:23.5%\\n\\n
# 67
#
#
# ###Answer:85.5%\\n\\n
# 68
#
#
# ###Answer:15.2 million dollars.
#
#
# 69
#
#
# ###Answer:28%\\n\\ncommer
# 70
#
#
# ###Answer:26.7%\\n\\n
# 71
#
#
# ###Answer:16.5%\\n\\n
# 72
#
#
# ###Answer:99.3%\\n\\n
# 73
# ?
#
# ###Answer:20%..
#
# ####
# 74
#
#
# ###Answer:108%\\n\\nwhat
# 75
#
#
# ###Answer:10.8%\\n\\n
# 76
#
#
# ###Answer:1055 miles of private crude
# 77
#
#
# ###Answer:163%\\n\\n
#
# 78
#
#
# ###Answer:81808 and 81
# 79
#
#
# ###Answer:36.41%..
#
# 80
#
#
# ###Answer:17.44%..
#
# 81
#
#
# ###Answer:1.1252534
# 82
#
#
# ###Answer:1.5714285
# 83
#
#
# ###Answer:41.3%\\n\\n
# 84
# ?
#
# ###Answer:1.1%\\n\\n
# 85
#
#
# ###Answer:45%\\n\\n\\n
# 86
#
#
# ###Answer:18.2%\\n\\n
# 87
#
#
# ###Answer:2779.3333
# 88
#
#
# ###Answer:111%\\n\\n\\
# 89
#  from 2017 to 2018
#
# ##
# 90
#
#
# ###Answer:93.5%\\n\\n
# 91
#
#
# ###Answer:6.6%\\n\\n\\
# 92
#
#
# ###Answer:859.8\\n\\n
# 93
#
#
# ###Answer:100000000
# 94
#
#
# ###Answer:37.9%..
#
#
# 95
#
#
# ###Answer:120000000
# 96
#
#
# ###Answer:1.98%..
#
#
# 97
#
#
# ###Answer:100.44444
# 98
#
#
# ###Answer:60.6%\\n\\n
# 99
#
#
# ###Answer:93.5%\\n\\n
# 100
#
#
# ###Answer:124.65%..
# 101
#
#
# ###Answer:28% ( 28 % )
# 102
#
#
# ###Answer:19%\\n\\n
#
#
# 103
#
#
# ###Answer:18.8%\\n\\n
# 104
#
#
# ###Answer:31.7%\\n\\n
# 105
#
#
# ###Answer:442784.67
# 106
#
#
# ###Answer:9.1%\\n\\n\\
# 107
#
#
# ###Answer:10.3%\\n\\n
# 108
# ?
#
# ###Answer:2261.500
# 109
#
#
# ###Answer:12.5%\\n\\n
# 110
#
#
# ###Answer:1.6% ( 1.6
# 111
#
#
# ###Answer:-1.1 million\\n\\n\\
# 112
#
#
# ###Answer:78.9%\\n\\n
# 113
#
#
# ###Answer:38.5%\\n\\n
# 114
#
#
# ###Answer:178.75333
# 115
#
#
# ###Answer:581.67571
# 116
#
#
# ###Answer:10527.000
# 117
#
#
# ###Answer:10.5%\\n\\n
# 118
#
#
# ###Answer:13.5%\\n\\n
# 119
#
#
# ###Answer:133.33333
# 120
# ?
#
# ###Answer:176171\\n
# 121
#
#
# ###Answer:22.6%\\n\\n
# 122
#
#
# ###Answer:60% ( 60 % )
# 123
#
#
# ###Answer:10.9%\\n\\n
# 124
#
#
# ###Answer:12.3%\\n\\n
# 125
#  2012 that were purchased in november 2012
# 126
#
#
# ###Answer:100.93333
# 127
#  in millions?
#
# ###Answer:27.252
# 128
#
#
# ###Answer:57%\\n\\n\\n
# 129
# ?
#
# ###Answer:19163.93
# 130
#
#
# ### Answer:120.4%..
#
# 131
#
#
# ###Answer:10.6%\\n\\n
# 132
#
#
# ###Answer:1.25\\n\\n
#
# 133
#
#
# ###Answer:43.5%\\n\\n
# 134
#
#
# ###Answer:109.16677
# 135
#
#
# ###Answer:25%..
#
# ####question
# 136
#
#
# ###Answer:25.7%\\n\\n
# 137
#
#
# ###Answer:11% ( 11 % )
# 138
#
#
# ###Answer:-384.00000
# 139
#
#
# ###Answer:2109.0675
# 140
#
#
# ###Answer:10.7%\\n\\n
# 141
#
#
# ###answer:0.16% ( 0.
# 142
#
#
# ###Answer:yes\\n\\n2014
# 143
#
#
# ### Answer:6754.5000
# 144
#
#
# ###Answer:5652.3333
# 145
#
#
# ###Answer:19.7%\\n\\n
# 146
#
#
# ###Answer:0.0000000
# 147
#
#
# ###Answer:19%\\n\\n\\n
# 148
#
#
# ###Answer:10.9% ( 10
# 149
#
#
# ### Answer:33.6% ( 33
# 150
#
#
# ###Answer:1.0% ( 1.0
# 151
#
#
# ###Answer:109800.00
# 152
#
#
# ###Answer:1.4%\\n\\n\\
# 153
#
#
# ###Answer:21.4%\\n\\n
# 154
#
#
# ###Answer:654.84200
# 155
#
#
# ###Answer:104%\\n\\n
#
# 156
#
#
# ###Answer:122600000
# 157
#
#
# ###Answer:25% ( 25 % )
# 158
#
#
# ###Answer:3.5%\\n\\n\\
# 159
#
#
# ###Answer:10%\\n\\n\\n
# 160
#
#
# ###Answer:193973400
# 161
# ?
#
# ###Answer:8.8\\n\\n
#
# 162
#
#
# ###Answer:44.4%\\n\\n
# 163
#
#
# ###Answer:13.35%\\n\\
# 164
#
#
# ### Answer:35.6% ( 35
# 165
#
#
# ###Answer:223454.33
# 166
# ?
#
# ### Answer:10.27%..
# 167
#
#
# ###Answer:37.2% ( 37
# 168
#
#
# ###Answer:6.0000000
# 169
#
#
# ###Answer:24.5%\\n\\n
# 170
# ?
#
# ###Answer:10.7% ( 1
# 171
#
#
# ###Answer:27.5%\\n\\n
# 172
#
#
# ###Answer:15395.000
# 173
#
#
# ###Answer:159390000
# 174
#
#
# ###Answer:110000000
# 175
#
#
# ###Answer:3.6%.
#
# ####context
# 176
#
#
# ###Answer:1.5555555
# 177
#
#
# ###Answer:yes\\n\\n$ 57
# 178
#
#
# ###Answer:1056.5333
# 179
#
#
# ###Answer:yes, by 2.5%.
# 180
#
#
# ###Answer:17.76%\\n\\
# 181
#
#
# ###Answer:39.047575
# 182
#
#
# ###Answer:16500000.
# 183
# ?
#
# ###Answer:12.5%..
#
# 184
#
#
# ###Answer:21%..
#
# ####question
# 185
#
#
# ###Answer:19.2%\\n\\n
# 186
#
#
# ###Answer:15.5%\\n\\n
# 187
#
#
# ###Answer:28.6%..
#
#
# 188
#
#
# ###Answer:492500000
# 189
#
#
# ###Answer:1175.3333
# 190
# ?
#
# ###Answer:50000000
# 191
#
#
# ### Answer:11.54%\\n\\
# 192
#
#
# ###Answer:414095400
# 193
#
#
# ###Answer:44.81%\\n\\
# 194
#
#
# ###Answer:57% ( 57 % )
# 195
#
#
# ###Answer:160%\\n\\n\\
# 196
#
#
# ###Answer:6.7%\\n\\n\\
# 197
#
#
# ###Answer:593000000
# 198
#  for workers 2019 compensation, commercial general liability,
# 199
#  in the united states, canada, and latin america region and
# 200
#  in millions?
#
# ###Answer:381.33
# 201
#  sales
#
# ###Answer:1.75\\n\\n
# 202
#
#
# ###Answer:0.5 million\\n\\n
#
# 203
#
#
# ###Answer:88.6% ( 88
# 204
#
#
# ###Answer:10.4%\\n\\n
# 205
#
#
# ###Answer:12.4%\\n\\n
# 206
# ?
#
# ###Answer:15.5%\\n\\
# 207
#
#
# ###Answer:15.9%\\n\\n
# 208
# ?
#
# ###Answer:2.333333
# 209
#
#
# ###Answer:152%\\n\\n\\
# 210
#  refundable income tax?
#
# ###Answer:4.1
# 211
#
#
# ###Answer:39.936727
# 212
#
#
# ###Answer:8.75\\n\\n
#
# 213
#
#
# ###Answer:50-200\\n\\
# 214
#
#
# ###Answer:57.5%\\n\\n
# 215
#
#
# ###Answer:1.3% ( 1.3
# 216
#
#
# ###Answer:11.75\\n12
# 217
# ?
#
# ###Answer:12.3%\\n\\
# 218
#
#
# ###Answer:11.8% ( 11
# 219
# ?
#
# ###Answer:30.5%\\n\\
# 220
#
#
# ###Answer:923355.52
# 221
#
#
# ###Answer:10.3%\\n\\n
# 222
# ?
#
# ###Answer:100%\\n\\n
# 223
#
#
# ###Answer:2.13% ( 2.
# 224
#
#
# ###Answer:78.8%\\n\\n
# 225
#
#
# ###Answer:12.25% ( 1
# 226
#
#
# ###Answer:18.4%\\n\\n
# 227
#
#
# ###Answer:1.1947575
# 228
#
#
# ###Answer:75.5%\\n\\n
# 229
#
#
# ###Answer:54.2% ( 54
# 230
#
#
# ###Answer:10.3%\\n\\n
# 231
#
#
# ###Answer:28.6%.
#
# ####
# 232
#
#
# ###Answer:172.0 million\\n\\
# 233
#
#
# ###Answer:19%\\n\\n\\n
# 234
#
#
# ###Answer:295000000
# 235
# ?
#
# ###Answer:20.33333
# 236
#
#
# ###Answer:1.7%\\n\\n
#
# 237
#
#
# ###Answer:11.6%\\n\\n
# 238
#
#
# ###Answer:6050.5 million\\n
# 239
#
#
# ###Answer:37.344 million and
# 240
# ?
#
# ###Answer:10208361
# 241
#
#
# ###Answer:1.4% ( 1.4
# 242
#
#
# ###Answer:18.6%\\n\\n
# 243
# ?
#
# ###Answer:5900.333
# 244
#
#
# ###Answer:1.2104\\n\\
# 245
#
#
# ###Answer:174570000
# 246
#
#
# ###Answer:4.7%..
#
# ####
# 247
#
#
# ###Answer:170.98750
# 248
#
#
# ###Answer:22.5%\\n\\n
# 249
#
#
# ###Answer:45.8%\\n\\n
# 250
#
#
# ###Answer:4.8444444
# 251
#  options warrants and rights
#
# ###Answer:0.6
# 252
#  to the total cash obligations
#
# ###Answer:21
# 253
#
#
# ### Answer:1.3% ( 1.3
# 254
#
#
# ###Answer:5.6%\\n\\n
#
# 255
#  in the us and other countries
#
# ###Answer:55.
# 256
#
#
# ###Answer:36.2%\\n\\n
# 257
#
#
# ###Answer:85.5%\\n\\n
# 258
#
#
# ###Answer:92.222222
# 259
#
#
# ###Answer:0.3252525
# 260
#
#
# ###Answer:100% ( 100
# 261
#
#
# ### Answer:36.4%..
#
#
# 262
#
#
# ###Answer:154.6 million\\nwhat
# 263
#
#
# ###Answer:10.6%\\n\\n
# 264
#
#
# ###Answer:674.00000
# 265
#
#
# ###Answer:55.2%\\n\\n
# 266
#
#
# ###Answer:223313.33
# 267
#
#
# ###Answer:340.3 million\\n\\
# 268
#
#
# ###Answer:4.50% ( 4.
# 269
#
#
# ###Answer:91.3%\\n\\n
# 270
#
#
# ###Answer:1.15\\n\\n\\
# 271
#
#
# ###Answer:11.4%\\n\\n
# 272
# ?
#
# ###Answer:13.5%\\n\\
# 273
#
#
# ###Answer:107.62%\\n
# 274
#
#
# ###Answer:1.4% ( 1.4
# 275
#
#
# ###Answer:10.5% ( 10
# 276
#
#
# ###Answer:101.00000
# 277
#
#
# ###Answer:48%\\n\\n
#
#
# 278
#
#
# ###Answer:20.3%\\n\\n
# 279
#
#
# ###Answer:14.5%\\n\\n
# 280
#
#
# ###Answer:yes\\n\\nthe firm cancelled
# 281
#
#
# ###Answer:173355.57
# 282
# ?
#
# ###Answer:10.3%\\n\\
# 283
#
#
# ###Answer:36.675233
# 284
#
#
# ###Answer:11.6%\\n\\n
# 285
#
#
# ###Answer:33.4%\\n\\n
# 286
#
#
# ### Answer:60% ( 60 % )
# 287
#
#
# ###Answer:2525993 shares.
# 288
#
#
# ###Answer:12.8%..
#
#
# 289
#
#
# ###Answer:70.1%\\n\\n
# 290
#
#
# ###Answer:10.4%\\n\\n
# 291
#
#
# ###Answer:14.5%\\n\\n
# 292
#
#
# ###Answer:10.5% ( 10
# 293
#
#
# ###Answer:45.5%\\n\\n
# 294
#
#
# ###Answer:10.5% ( 10
# 295
#
#
# ###Answer:27%..
#
# ####context
# 296
#
#
# ###Answer:100000000
# 297
#
#
# ###Answer:17.7%\\n\\n
# 298
#  in millions?
#
# ###Answer:83.333
# 299
#
#
# ###Answer:8.4%\\n\\n
#
# 300
#
#
# ###Answer:138%\\n\\n\\
# 301
#
#
# ###Answer:4.0525000
# 302
#
#
# ###Answer:10.7 and 10.
# 303
#
#
# ###Answer:1.3% ( 1.3
# 304
#
#
# ###Answer:14.5%..
#
#
# 305
#
#
# ###Answer:27.3% ( 27
# 306
#
#
# ###answer:10.7\\n\\n
#
# 307
#
#
# ###Answer:11.2%\\n\\n
# 308
#
#
# ###Answer:1.8% ( 1.8
# 309
#
#
# ###Answer:2.44\\n\\n\\
# 310
# ?
#
# ###Answer:2.7%\\n\\n
# 311
#
#
# ###Answer:13.5%\\n\\n
# 312
#
#
# ###Answer:36.0%\\n\\n
# 313
#
#
# ###Answer:1.54% ( 1.
# 314
#
#
# ###Answer:10.3% ( 10
# 315
#
#
# ###Answer:721.79999
# 316
#
#
# ###Answer:15.1%\\n\\n
# 317
#
#
# ###Answer:1.09\\n\\n
#
# 318
#
#
# ###Answer:1.7% ( 1.7
# 319
#
#
# ###Answer:81.4%\\n\\n
# 320
#
#
# ###Answer:12.4%\\n\\n
# 321
#
#
# ### Answer:38.9%\\n\\n
# 322
#
#
# ###Answer:yes\\n\\nno\\n\\
# 323
#
#
# ###Answer:30.5%\\n\\n
# 324
#
#
# ###Answer:15.4%\\n\\n
# 325
#
#
# ###Answer:298207.57
# 326
# ?
#
# ###Answer:8.333333
# 327
# ?
#
# ###Answer:1.167789
# 328
#
#
# ###Answer:13.2% ( 13
# 329
#
#
# ###Answer:15.4%\\n\\n
# 330
#
#
# ###Answer:12389.000
# 331
# ?
#
# ###Answer:1.5% ( 1.
# 332
#
#
# ###1328.75
#
# ###
# 333
#
#
# ###Answer:2200000\\n
# 334
#
#
# ###Answer:-18\\n\\n
#
# ##
# 335
#
#
# ###Answer:8.05% ( 8.
# 336
#
#
# ###Answer:248.36%\\n
# 337
#
#
# ###Answer:23.5%\\n\\n
# 338
#  to the total trade and other accounts receivable
#
# ###Answer
# 339
#  from 2014 to 2015
#
# ##
# 340
#
#
# ###Answer:28%\\n\\n\\n
# 341
#
#
# ###Answer:1.67\\n
#
# ##
# 342
#
#
# ###Answer:1.7575757
# 343
#
#
# ###Answer:10.9% and 17
# 344
#
#
# ###Answer:99.2%\\n\\n
# 345
# .
#
# ###Answer:1.144222
# 346
#
#
# ###Answer:13.500000
# 347
#
#
# ###Answer:166312 shares of restricted
# 348
#
#
# ###Answer:60675.000
# 349
#
#
# ###Answer:10.7%\\n\\n
# 350
#
#
# ###Answer:173.4 million\\n\\
# 351
#
#
# ###Answer:88.5%\\n\\n
# 352
#
#
# ###Answer:1.7%\\n\\n\\
# 353
#
#
# ###Answer:172.85172
# 354
#
#
# ###Answer:111.81%\\n
# 355
#
#
# ###Answer:15.4%\\n\\n
# 356
#
#
# ###Answer:15.8%\\n\\n
# 357
#
#
# ###Answer:24.5%\\n\\n
# 358
#
#
# ###Answer:1.2512512
# 359
#
#
# ###Answer:146780000
# 360
#
#
# ###Answer:1.8% ( 1.8
# 361
#
#
# ###Answer:2.6175777
# 362
#
#
# ###Answer:13.5%\\n\\n
# 363
#
#
# ###Answer:20.9%\\n\\n
# 364
# ?
#
# ###Answer:1.157142
# 365
#
#
# ###Answer:4.2% ( 4.2
# 366
#
#
# ###Answer:41.51\\n42
# 367
#
#
# ###Answer:50.00\\n\\n
# 368
#
#
# ###Answer:110000000
# 369
#
#
# ###Answer:118210.00
# 370
#  contractual obligations by year
#
# ###Answer:53.
# 371
#
#
# ###Answer:10.8%\\n\\n
# 372
#
#
# ###Answer:357.8%\\n\\
# 373
#
#
# ###Answer:10.8%.
#
# ####
# 374
#
#
# ###Answer:125.50000
# 375
#
#
# ###Answer:16.34%..
#
# 376
# ?
#
# ###Answer:6.3% ( 6.
# 377
#
#
# ###Answer:1.6% ( 1.6
# 378
#
#
# ###Answer:25%\\n\\n
#
#
# 379
#
#
# ###Answer:317000000
# 380
#
#
# ###Answer:27.6%\\n\\n
# 381
#
#
# ###Answer:11.5%\\n\\n
# 382
#
#
# ###Answer:18.9%\\n\\n
# 383
#
#
# ###Answer:65.7%\\n\\n
# 384
#
#
# ###Answer:1.045625\\
# 385
#  in millions?
#
# ###Answer:19.3%\\
# 386
#
#
# ### Answer:1.3 million shares of common stock in
# 387
#
#
# ###Answer:21.2%\\n\\n
# 388
#
#
# ###Answer:232600000
# 389
#
#
# ###Answer:10.6%\\n\\n
# 390
#
#
# ###Answer:10.6% ( 10
# 391
#
#
# ###Answer:0.75\\n\\n
#
# 392
#
#
# ###Answer:88.333333
# 393
#
#
# ###Answer:200.25757
# 394
#
#
# ###Answer:3.4%\\n\\n\\
# 395
#
#
# ###Answer:18178.000
# 396
#
#
# ###Answer:37.5%\\n\\n
# 397
#
#
# ###Answer:37.5%\\n\\n
# 398
#
#
# ###Answer:2.8843333
# 399
#
#
# ###Answer:100%\\n\\n
#
# 400
#
#
# ###Answer:18.2% ( 18
# 401
#
#
# ###Answer:4.3\\n\\n\\n
# 402
#
#
# ###Answer:69.3% ( 69
# 403
#
#
# ###Answer:1.9200000
# 404
#
#
# ###Answer:19.4%\\n\\n
# 405
#
#
# ###Answer:518.3 million\\n\\
# 406
#
#
# ###Answer:115.2%\\n\\
# 407
#
#
# ###Answer:1.2 million\\n\\n
#
# 408
#  to the s&p 500 index
#
# ###Answer
# 409
#
#
# ###Answer:37.3% and 36
# 410
#  and the non-current assets?
#
# ###Answer:12
# 411
#
#
# ###Answer:100%\\n\\n\\
# 412
#
#
# ###Answer:16.6\\n\\n\\
# 413
#
#
# ###Answer:1.8%\\n\\n\\
# 414
#
#
# ###Answer:358.33333
# 415
#
#
# ###Answer:166.0%\\n\\
# 416
#
#
# ###Answer:34.9%\\n\\n
# 417
#
#
# ###Answer:41.5%\\n\\n
# 418
#
#
# ###Answer:16.3% ( 16
# 419
#
#
# ###Answer:1414.0000
# 420
#
#
# ###Answer:10.7%.\\n\\
# 421
#
#
# ### Answer:89.233333
# 422
#
#
# ###Answer:16.3%\\n\\n
# 423
#
#
# ###Answer:13.625000
# 424
#
#
# ###Answer:6829.5000
# 425
#
#
# ###Answer:10.4% ( 10
# 426
#
#
# ###Answer:yes...
#
# ####context:
# 427
#
#
# ###Answer:17.5%\\n\\n
# 428
#
#
# ###Answer:183700000
# 429
#
#
# ###Answer:14.2% ( 14
# 430
#  from 2014 to 2015
#
# ##
# 431
#
#
# ###Answer:16.2%\\n\\n
# 432
#
#
# ###Answer:10.4%\\n\\n
# 433
#
#
# ###Answer:33.5%\\n\\n
# 434
#
#
# ###Answer:157.9\\n\\n
# 435
# ?
#
# ###Answer:16.4%..
#
# 436
#
#
# ###Answer:367150000
# 437
#
#
# ###Answer:15.2%..
#
#
# 438
#
#
# ###Answer:14.5 million\\n\\n
# 439
#
#
# ###Answer:450000000
# 440
#
#
# ###Answer:19.1%\\n\\n
# 441
#
#
# ###Answer:267%\\n\\n\\
# 442
#
#
# ###Answer:29.944777
# 443
#
#
# ###Answer:100000000
# 444
#
#
# ###Answer:87.500000
# 445
#
#
# ###Answer:19.2%\\n\\n
# 446
#
#
# ###Answer:0.0000000
# 447
#
#
# ###Answer:1.4% ( 1.4
# 448
#
#
# ###Answer:1.7% ( 1.7
# 449
#
#
# ###Answer:196247.24
# 450
#
#
# ###Answer:0.25% ( 0.
# 451
#
#
# ###Answer:16.2%\\n\\n
# 452
#
#
# ###Answer:5.6%\\n\\n\\
# 453
#
#
# ###Answer:2.5%\\n\\n\\
# 454
#
#
# ###Answer:102.33333
# 455
#
#
# ###Answer:73.0% ( 73
# 456
#
#
# ###Answer:5.7147571
# 457
#
#
# ###Answer:12.9%\\n\\n
# 458
#
#
# ###Answer:17.5% ( 17
# 459
#
#
# ###Answer:12.2% ( 12
# 460
#
#
# ### Answer:71.1% ( 71
# 461
#
#
# ###Answer:192.7% ( 1
# 462
#
#
# ###Answer:35.500000
# 463
# ?
#
# ###Answer:114%..
#
#
# 464
#
#
# ###Answer:0.5%\\n\\n\\
# 465
#
#
# ###Answer:10.6%\\n\\n
# 466
#  compared to 2006?
#
# ###Answer:4
# 467
#
#
# ###Answer:655346000
# 468
#
#
# ###Answer:190.4 million\\n\\
# 469
#
#
# ###Answer:114.36%\\n
# 470
#
#
# ###Answer:5190.5190
# 471
#
#
# ###Answer:76.5% ( 76
# 472
#
#
# ###Answer:77.7% ( 77
# 473
#
#
# ### Answer:19.433333
# 474
#
#
# ###Answer:9.3%\\n\\nwhat
# 475
#
#
# ###Answer:5.8257437
# 476
#
#
# ###Answer:39%..
#
# ####question
# 477
#
#
# ###Answer:46.5\\n\\n\\
# 478
#
#
# ###Answer:447195037
# 479
# ?
#
# ###Answer:12.5%\\n\\
# 480
#
#
# ###Answer:12765.555
# 481
#
#
# ###Answer:45.5%\\n\\n
# 482
#
#
# ###Answer:98.27%\\n\\
# 483
#
#
# ###Answer:12.5% ( 12
# 484
#
#
# ###Answer:1.1880000
# 485
# ?
#
# ###Answer:100%\\n\\n
# 486
#
#
# ###Answer:32%\\n\\n\\n
# 487
#
#
# ###Answer:163000\\n\\
# 488
#
#
# ###Answer:200.00000
# 489
#
#
# ###Answer:62%\\n\\n\\n
# 490
#
#
# ###Answer:5.7%\\n\\n\\
# 491
#
#
# ###Answer:10.9% ( 10
# 492
#
#
# ###Answer:33.3% ( 33
# 493
#  in millions?
#
# ###Answer:80.333
# 494
#
#
# ###Answer:14.2% ( 14
# 495
#
#
# ###Answer:23.5%\\n\\n
# 496
#  from 2017 to 2018
#
# ##
# 497
#
#
# ###Answer:73.4%\\n\\n
# 498
#
#
# ###Answer:35066 278
# 499
#
#
# ###Answer:300000000
# 500
#
#
# ###Answer:292.50000
# 501
#
#
# ###Answer:28.6%\\n\\n
# 502
#
#
# ###Answer:1.9114233
# 503
#
#
# ###Answer:8.2%\\n\\n\\
# 504
#
#
# ###Answer:1.14\\n\\nthe
# 505
#
#
# ###Answer:32%\\n\\n\\n
# 506
#
#
# ###Answer:138.79%.
#
# 507
#
#
# ###Answer:829000000
# 508
#
#
# ###Answer:2.8% ( 2.8
# 509
#
#
# ###Answer:2.1% ( 2.1
# 510
#
#
# ###Answer:270500000
# 511
#
#
# ###Answer:yes..
#
# ####context:the
# 512
#
#
# ###Answer:8.25:1.75
# 513
#
#
# ###Answer:29.4%..
#
#
# 514
#
#
# ###Answer:3471.5000
# 515
#
#
# ###Answer:45.3%\\n\\n
# 516
#
#
# ###Answer:1.6757142
# 517
#
#
# ###Answer:10.6 years\\n\\n
# 518
#
#
# ### Answer:22.77%..
#
# 519
#  or sub-lease
#
# ###Answer:31.45
# 520
#
#
# ###Answer:1.09\\n\\n
#
# 521
#
#
# ###Answer:7.3%\\n\\n\\
# 522
#
#
# ###Answer:10.2%\\n\\n
# 523
#
#
# ###Answer:10.6% ( 10
# 524
#
#
# ###Answer:24%\\n\\nin
# 525
#
#
# ###Answer:25.8% ( 25
# 526
#
#
# ###Answer:15.2%..
#
#
# 527
#
#
# ###Answer:38.85\\n\\n
# 528
# ?
#
# ###Answer:11589000
# 529
#
#
# ###Answer:29%\\n\\n\\n
# 530
#
#
# ###Answer:10.7%\\n\\n
# 531
#
#
# ###Answer:10% ( 10 % )
# 532
#
#
# ###Answer:34.3%\\n\\n
# 533
#
#
# ###Answer:358500000
# 534
#  in millions
#
# ###Answer:14.7\\n
#
# 535
#
#
# ###Answer:102400000
# 536
#
#
# ###Answer:28.5%\\n\\n
# 537
#
#
# ###Answer:45%\\n\\n\\n
# 538
#
#
# ###Answer:148.36%\\n
# 539
#
#
# ###Answer:100%\\n\\n\\
# 540
#
#
# ###Answer:10.5%\\n\\n
# 541
#  washington
#
# ###Answer:1.8333
# 542
#
#
# ###Answer:26.4%..
#
#
# 543
#
#
# ###Answer:18.4%\\n\\n
# 544
#
#
# ###Answer:30%\\n\\n\\n
# 545
#
#
# ###Answer:240000000
# 546
#
#
# ###Answer:1.1% ( 1.1
# 547
#
#
# ###Answer:14.2%\\n\\n
# 548
# ?
#
# ###Answer:104%.104
# 549
#
#
# ###Answer:14.0%\\n\\n
# 550
#
#
# ###Answer:28%\\n\\n\\n
# 551
# , satisfy excess tax withholding obligations for stock option exercises
# 552
#
#
# ###Answer:1.125\\\\\\\\
# 553
#
#
# ###Answer:4.1% ( 4.1
# 554
#
#
# ###Answer:3.25\\n
#
# ####
# 555
#
#
# ###Answer:6.94%\\n\\n
# 556
#
#
# ###Answer:17.533333
# 557
#
#
# ###Answer:0.2% ( 0.2
# 558
# ?
#
# ###Answer:833333.3
# 559
#
#
# ###Answer:88.5%..
#
#
# 560
#
#
# ###Answer:18.3%..
#
#
# 561
#
#
# ###Answer:100000000
# 562
#
#
# ###Answer:3.3% ( 3.3
# 563
#
#
# ###Answer:40.5%\\n\\n
# 564
#
#
# ###Answer:10.1%\\n\\n
# 565
#
#
# ###Answer:26.6%\\n\\n
# 566
#
#
# ###Answer:17.7%\\n\\n
# 567
#
#
# ###Answer:11.2%\\n\\n
# 568
#
#
# ###Answer:no\\n\\nthe weighted average
# 569
#  that was approved by security holders
#
# ###Answer:10
# 570
#  obligations that is due in 2013
#
# ###
# 571
#
#
# ###Answer:646444444
# 572
# ?
#
# ###Answer:10.575\\n
# 573
#
#
# ###Answer:15.4%\\n\\n
# 574
#
#
# ###Answer:6.675\\n\\n
# 575
#
#
# ###Answer:4.5%\\n\\n
#
# 576
#
#
# ###Answer:274431400
# 577
#
#
# ###Answer:2.37\\n\\n
#
# 578
# ?
#
# ###Answer:19%..
#
# ####
# 579
#  in 2017?
#
# ###Answer:38
# 580
#
#
# ###Answer:1.8%\\n\\nwhat
# 581
#
#
# ###Answer:10.6% ( 10
# 582
#
#
# ###Answer:11.5%\\n\\n
# 583
#
#
# ###Answer:587500000
# 584
#
#
# ###Answer:27.5%\\n\\n
# 585
#
#
# ### -17 ( 17 )
#
# ##
# 586
#
#
# ###Answer:71438\\n\\n
# 587
#
#
# ###Answer:39.8%\\n\\n
# 588
#
#
# ###Answer:1804.3333
# 589
#
#
# ###Answer:184.00000
# 590
#
#
# ### Answer:2.1%\\n\\n\\
# 591
# ?
#
# ###Answer:1.833333
# 592
#
#
# ###Answer:19.5%\\n\\n
# 593
#
#
# ###Answer:1.1675\\n
#
# 594
#  in millions
#
# ###Answer:367.000
# 595
#
#
# ###Answer:6.5\\n\\n\\n
# 596
#
#
# ###Answer:382.33333
# 597
#
#
# ###Answer:10.5% ( 10
# 598
#
#
# ###Answer:12.8%\\n\\n
# 599
#
#
# ###Answer:98.0%\\n\\n
# 600
#
#
# ###Answer:3.6% ( 3.6
# 601
#
#
# ###Answer:1.5 million dollars..
#
#
# 602
#
#
# ###Answer:118314.00
# 603
#
#
# ###Answer:1.0333333
# 604
#
#
# ###Answer:475000000
# 605
#
#
# ###Answer:17.6%.
#
# ####
# 606
#
#
# ###Answer:2.2%\\n\\nin
# 607
#  that was used
#
# ###Answer:10.5%\\
# 608
#
#
# ###Answer:33.5%..
#
#
# 609
#
#
# ###Answer:68.075252
# 610
#
#
# ###Answer:0.5677777
# 611
#
#
# ###Answer:16.5%\\n\\n
# 612
#
#
# ###Answer:5838.3333
# 613
# ?
#
# ###Answer:6.5%\\n\\n
# 614
#
#
# ###Answer:85.5%\\n\\n
# 615
#
#
# ###Answer:32.133333
# 616
#
#
# ###Answer:18.1%\\n\\n
# 617
#
#
# ###Answer:14.4%\\n\\n
# 618
#
#
# ###Answer:377340000
# 619
#
#
# ###Answer:7930.3333
# 620
#
#
# ###Answer:17.7%\\n\\n
# 621
#
#
# ### Answer:21.46%..
#
# 622
#
#
# ###Answer:18.7%\\n\\n
# 623
#
#
# ###Answer:1.9752531
# 624
#
#
# ###Answer:12.5%\\n\\n
# 625
#
#
# ###Answer:yes, 76% ( 7
# 626
#
#
# ###Answer:yes\\n\\nno\\n\\
# 627
# ?
#
# ###Answer:43% ( 43 %
# 628
#
#
# ###Answer:yes\\n\\nno\\n\\
# 629
#
#
# ###Answer:1073.5 million\\n
# 630
#
#
# ###Answer:18.8%\\n\\n
# 631
#
#
# ###Answer:1.1% ( 1.1
# 632
#
#
# ###Answer:1.5% ( 1.5
# 633
#
#
# ###Answer:66.7%.\\n\\
# 634
#  in the net revenue
#
# ###Answer:1.3%
# 635
#
#
# ###Answer:25.6%\\n\\n
# 636
#
#
# ###Answer:1.0751111
# 637
#
#
# ###Answer:1775.6\\n\\
# 638
#
#
# ###Answer:10.4%\\n\\n
# 639
#
#
# ###Answer:69853\\n\\n
# 640
#
#
# ###Answer:63%\\n\\n\\n
# 641
# ?
#
# ### Answer:18.3% ( 1
# 642
# ?
#
# ###Answer:10.8%..
#
# 643
#
#
# ###Answer:16.8% ( 16
# 644
#
#
# ###Answer:1.1%..
#
# ####
# 645
#  in 2017?
#
# ###Answer:79
# 646
#
#
# ###Answer:263.6 million dollars..
# 647
#
#
# ###Answer:65.3%\\n\\n
# 648
#
#
# ###Answer:16.1% ( 16
# 649
#
#
# ###Answer:10.3%\\n\\n
# 650
#
#
# ###Answer:1.8% ( 1.8
# 651
#
#
# ###Answer:3.1% ( 3.1
# 652
#
#
# ###Answer:3832.5000
# 653
#
#
# ###Answer:4.5%\\n\\n\\
# 654
#
#
# ###Answer:2.5% ( 2.5
# 655
#
#
# ###Answer:4.2%\\n\\n\\
# 656
#
#
# ###Answer:24.1%\\n\\n
# 657
# ?
#
# ###Answer:3.25\\n\\n
# 658
#
#
# ### Answer:103.7%..
#
# 659
#
#
# ###Answer:7.7% ( 7.7
# 660
#
#
# ###Answer:600000000
# 661
#
#
# ###Answer:1.9% ( 1.9
# 662
#
#
# ###Answer:5.2%\\n\\nwhat
# 663
#
#
# ###Answer:-633333333
# 664
#
#
# ###Answer:35% ( 35 % )
# 665
#
#
# ###Answer:10.9% ( 10
# 666
#
#
# ###Answer:1.47%\\n\\n
# 667
#
#
# ###Answer:1200.5852
# 668
#
#
# ###Answer:88%\\n\\n
#
#
# 669
#
#
# ###Answer:4.5%\\n\\n\\
# 670
#
#
# ###Answer:100%\\n\\n\\
# 671
# ?
#
# ###Answer:18.5%\\n\\
# 672
#
#
# ###Answer:223000000
# 673
#
#
# ###Answer:19.9%..
#
#
# 674
#  in millions?
#
# ###Answer:21%\\n\\
# 675
#
#
# ###Answer:53.8%\\n\\n
# 676
#
#
# ###Answer:8.6%\\n\\n\\
# 677
# ?
#
# ###Answer:10.8% ( 1
# 678
#
#
# ###Answer:35.9%\\n\\n
# 679
#
#
# ###Answer:3.71% ( 3.
# 680
#
#
# ###Answer:17%\\n\\n\\n
# 681
#
#
# ###Answer:30.294\\n\\
# 682
#
#
# ###Answer:39.5%\\n\\n
# 683
#  on the sale of approximately 4.9 million mastercard class b shares
# 684
#
#
# ###Answer:216667.67
# 685
#
#
# ###Answer:52.5%\\n\\n
# 686
#
#
# ###Answer:545.6\\n\\n
# 687
#
#
# ###Answer:238000000
# 688
#
#
# ###Answer:20.4%\\n\\n
# 689
#
#
# ###Answer:101653.43
# 690
#
#
# ###Answer:37.9%..
#
#
# 691
#
#
# ###Answer:17.5%\\n\\n
# 692
# ?
#
# ###Answer:27.5%.\\n
# 693
# 1
#
# ###Answer:68.6%\\n\\
# 694
#
#
# ###Answer:54%.
#
# ####context:
# 695
#
#
# ###Answer:25%\\n\\n
#
#
# 696
# ?
#
# ###Answer:10.4%\\n\\
# 697
#
#
# ###Answer:10.2% ( 10
# 698
#
#
# ###Answer:165 million\\n\\nwhat
# 699
#
#
# ###Answer:3.5%\\n\\n\\
# 700
#
#
# ###Answer:0.6677777
# 701
#
#
# ###Answer:102.33333
# 702
#
#
# ###Answer:10.5%....
# 703
#
#
# ###Answer:1.3333333
# 704
#
#
# ###Answer:16.1%\\n\\n
# 705
#
#
# ###Answer:12.5% ( 12
# 706
#
#
# ###Answer:14.0 million shares.\\n
# 707
#
#
# ###Answer:4.5%\\n\\n
#
# 708
#
#
# ###Answer:20.333333
# 709
#
#
# ###Answer:9.1%\\n\\n\\
# 710
#
#
# ### Answer:76.67\\n\\n
# 711
#
#
# ###Answer:1.4714285
# 712
#
#
# ###Answer:50.25\\n\\n
# 713
# ?
#
# ###Answer:20752.33
# 714
# ?
#
# ###Answer:932.4444
# 715
#
#
# ###Answer:100.54784
# 716
# ?
#
# ###Answer:100%\\n\\n
# 717
#
#
# ###Answer:85%\\n\\nwhat was
# 718
# , to the total cash obligations
#
# ###Answer:4
# 719
#
#
# ###Answer:40.7%\\n\\n
# 720
#
#
# ###Answer:55.5%\\n\\n
# 721
#
#
# ###Answer:18.7%.
#
# ####
# 722
#
#
# ###Answer:150%\\n\\n
#
# 723
#
#
# ###Answer:1.2461246
# 724
#
#
# ###Answer:100000000
# 725
#  shares?
#
# ###Answer:30.56\\n
# 726
#
#
# ###Answer:26.9%\\n\\n
# 727
#
#
# ###Answer:19.4%\\n\\n
# 728
#
#
# ###Answer:10.8%\\n\\n
# 729
#
#
# ###Answer:226.44444
# 730
#
#
# ###Answer:480000000
# 731
#
#
# ###Answer:10.3%\\n\\n
# 732
#
#
# ###Answer:11.4%\\n\\n
# 733
#
#
# ###Answer:100000000
# 734
# , 2015 to 2016
#
# ##
# 735
#
#
# ###Answer:31890.647
# 736
#
#
# ###Answer:1497680.0
# 737
#
#
# ###Answer:1.9555555
# 738
#
#
# ###Answer:240.33333
# 739
#
#
# ###Answer:10% ( 10 % )
# 740
#
#
# ###Answer:618.12333
# 741
#  in 2006?
#
# ###Answer:54
# 742
#
#
# ###Answer:45.4%\\n\\n
# 743
#
#
# ###Answer:33.5%\\n\\n
# 744
#  and 2011
#
# ###Answer:75%
# 745
#
#
# ###Answer:8.75% ( 8.
# 746
#
#
# ###Answer:50.000000
# 747
#
#
# ###Answer:0.71\\n\\n
#
# 748
#
#
# ###Answer:10%\\n\\n\\n
# 749
#
#
# ###Answer:33%\\n\\nother oblig
# 750
#
#
# ###Answer:no\\n\\npurchase commitments
# 751
#
#
# ###Answer:41%\\n\\nwhat was
# 752
#
#
# ###Answer:8.5% ( 8.5
# 753
#
#
# ###Answer:44.8%\\n\\n
# 754
#
#
# ###Answer:15.5% ( 15
# 755
#
#
# ###Answer:1.2%\\n\\nwhat
# 756
#
#
# ###Answer:33.4%\\n\\n
# 757
#
#
# ###Answer:6150.5633
# 758
# ?
#
# ###Answer:-3.8% ( 3.
# 759
# ?
#
# ###Answer:35% ( 35 %
# 760
#
#
# ###Answer:61.2% ( 61
# 761
#
#
# ###Answer:251533000
# 762
#
#
# ###Answer:10.8% ( 10
# 763
#
#
# ###Answer:7804.9\\n\\
# 764
#
#
# ###Answer:1279.5250
# 765
#
#
# ###Answer:19.5%..
#
#
# 766
#
#
# ###Answer:1.6%\\n\\n\\
# 767
#
#
# ###Answer:108.7 billion tons-m
# 768
#
#
# ###Answer:1.6%\\n\\n\\
# 769
#
#
# ###Answer:11.4%\\n\\n
# 770
#
#
# ###Answer:12.5%\\n\\n
# 771
#
#
# ###Answer:1.4%\\n\\n\\
# 772
#
#
# ###Answer:2350000.0
# 773
#
#
# ###Answer:64.5%\\n\\n
# 774
#
#
# ###Answer:3.6%.
#
# ####context
# 775
#
#
# ###Answer:11.2%\\n\\n
# 776
#
#
# ###Answer:1.8% ( 1.8
# 777
#
#
# ###Answer:0.25% ( 0.
# 778
#
#
# ###Answer:100000000
# 779
#
#
# ###Answer:1.1%\\n\\n\\
# 780
#
#
# ###Answer:460000000
# 781
#
#
# ###Answer:10.3%\\n\\n
# 782
#
#
# ###Answer:49.3%\\n\\n
# 783
#
#
# ###Answer:1.9%\\n\\n\\
# 784
#
#
# ###Answer:14732.333
# 785
#
#
# ### Answer:1221.3333
# 786
#
#
# ###Answer:8.7%\\n\\n\\
# 787
#
#
# ###Answer:600000000
# 788
#
#
# ###Answer:9.2%\\n\\n\\
# 789
#
#
# ###Answer:27% ( 27 % )
# 790
#
#
# ###Answer:11.4% ( 11
# 791
#
#
# ###Answer:165000000
# 792
#
#
# ###Answer:600.33333
# 793
#
#
# ###Answer:100%\\n\\n
#
# 794
#
#
# ###Answer:2.8%\\n\\n\\
# 795
#
#
# ###Answer:0.4%\\n\\n\\
# 796
#
#
# ###Answer:23.1%\\n\\n
# 797
#
#
# ###Answer:627000000
# 798
#
#
# ###Answer:13.3% ( 13
# 799
#
#
# ###Answer:1.7%\\n\\n\\
# 800
#  for american eagle and american's third-party regional carri
# 801
# ?
#
# ###Answer:10.25252
# 802
#
#
# ###Answer:10.7%\\n\\n
# 803
#
#
# ###Answer:249000000
# 804
# ?
#
# ###Answer:1.675714
# 805
#
#
# ###Answer:100000000
# 806
#
#
# ###Answer:277334.00
# 807
#
#
# ###Answer:100%\\n\\n\\
# 808
#
#
# ### Answer:27.5%..
#
#
# 809
#
#
# ###Answer:10.4%\\n\\n
# 810
#
#
# ###Answer:518000000
# 811
#
#
# ###Answer:127500000
# 812
#
#
# ### Answer:168.91%..
# 813
#
#
# ###Answer:46.3%\\n\\n
# 814
#
#
# ###Answer:77.5%\\n\\n
# 815
#
#
# ###Answer:2014% ( 20
# 816
#
#
# ###Answer:70.7% ( 70
# 817
#  to the unamortized unrealized pre-tax losses of $
# 818
#
#
# ###Answer:114%\\n\\ncom
# 819
#
#
# ###Answer:1.0913333
# 820
#
#
# ###Answer:70000000.
# 821
#
#
# ###Answer:2.4125\\n\\
# 822
#
#
# ###Answer:203.39%\\n
# 823
#
#
# ###Answer:53.3%\\n\\n
# 824
#
#
# ###Answer:20704\\n\\n
# 825
#
#
# ###Answer:0% ( 0 % )\\n
# 826
#
#
# ###Answer:104.5%\\n\\
# 827
#
#
# ###Answer:10.4% ( 10
# 828
#
#
# ###Answer:2.4% ( 2.4
# 829
#
#
# ###Answer:10.4% ( 10
# 830
#
#
# ###Answer:3.48\\n\\ninter
# 831
#
#
# ###Answer:45.7%\\n\\n
# 832
#
#
# ###Answer:12.5%\\n\\n
# 833
#
#
# ###Answer:111814.81
# 834
#
#
# ###Answer:4085.5555
# 835
#
#
# ###Answer:265000000
# 836
# ?
#
# ###Answer:60.5%\\n\\
# 837
#
#
# ###Answer:81.99 201
# 838
# ?
#
# ###Answer:26.3%\\n\\
# 839
#
#
# ###Answer:94.1%\\n\\n
# 840
#
#
# ###Answer:20.1%\\n\\n
# 841
#
#
# ###Answer:50%\\n\\n1.
# 842
#
#
# ###Answer:14%..
#
# ####context
# 843
#
#
# ###Answer:15.25\\n\\n
# 844
#
#
# ###Answer:6.0%\\n\\n\\
# 845
#  500
#
# ###Answer:2.095
# 846
#
#
# ###Answer:46.5%\\n\\n
# 847
#  of 2014?
#
# ###Answer:7.
# 848
#
#
# ###Answer:10% ( 10 % )
# 849
#
#
# ###Answer:10.8%\\n\\n
# 850
# ?
#
# ###Answer:10.6% ( 1
# 851
#
#
# ###Answer:46674 million dollars.
#
# 852
# ?
#
# ###Answer:25390700
# 853
#
#
# ###Answer:93.9%\\n\\n
# 854
#
#
# ###Answer:118.00000
# 855
#  for sikorsky?
#
# ###Answer:7.0%
# 856
#
#
# ###Answer:1.5%\\n\\nhow
# 857
#
#
# ###Answer:37.2% ( 37
# 858
#
#
# ###Answer:39.7% ( 39
# 859
#
#
# ###Answer:22.8%.\\n\\
# 860
#
#
# ###Answer:28%\\n\\n\\n
# 861
#
#
# ###Answer:435.6\\n\\n
# 862
#
#
# ###Answer:1.25\\n
#
# ##
# 863
#
#
# ###Answer:130.5 million\\n\\
# 864
#
#
# ###Answer:10.2%\\n\\n
# 865
#
#
# ###Answer:3.1%\\n\\n\\
# 866
#
#
# ###Answer:no\\n\\nthe company had more
# 867
#
#
# ###Answer:4.3%\\n\\n\\
# 868
#
#
# ###Answer:6800.3333
# 869
#
#
# ###Answer:5756.2444
# 870
#
#
# ###Answer:1.5% ( 1.5
# 871
#
#
# ###Answer:12.3%\\n\\n
# 872
#
#
# ###Answer:34.133333
# 873
#
#
# ###Answer:11.7%\\n\\n
# 874
#
#
# ###Answer:13.3%\\n\\n
# 875
#
#
# ###Answer:18%\\n\\n\\n
# 876
#
#
# ###Answer:10.4%\\n\\n
# 877
# ?
#
# ###Answer:3383.945
# 878
#
#
# ###Answer:12.6% ( 12
# 879
#
#
# ###Answer:38625\\n38
# 880
#
#
# ###Answer:10.9%.
#
# ##
# 881
# ?
#
# ###Answer:35.4%.\\n
# 882
#
#
# ###Answer:1.7717717
# 883
#
#
# ###Answer:39.8%\\n\\n
# 884
#
#
# ###Answer:46.7%\\n\\n
# 885
# ?
#
# ###Answer:2006 : 18
# 886
#
#
# ###Answer:12%\\n\\nfor national
# 887
#
#
# ###Answer:67.25% ( 6
# 888
#
#
# ###Answer:yes\\n\\nno..
#
# 889
#
#
# ###Answer:10.9% ( 10
# 890
#  asset allocation?
#
# ###Answer:10% ( 1
# 891
#
#
# ###Answer:137450000
# 892
#
#
# ###Answer:162.00000
# 893
#
#
# ###Answer:88.500000
# 894
#
#
# ###Answer:0.5757143
# 895
#
#
# ###Answer:3.00 years\\n\\n
# 896
#
#
# ###Answer:2.9% ( 2.9
# 897
#
#
# ###Answer:26.5%\\n\\n
# 898
#
#
# ###Answer:31.3%\\n\\n
# 899
#
#
# ###Answer:101.6%\\n\\
# 900
#
#
# ###Answer:yes, by 11.3%
# 901
#
#
# ###Answer:73.0% ( 73
# 902
#
#
# ###Answer:13.8%\\n\\n
# 903
#
#
# ###Answer:2.8333333
# 904
#
#
# ###Answer:1.5585714
# 905
# ?
#
# ###Answer:2.7% ( 2.
# 906
#
#
# ###Answer:1.4814814
# 907
#
#
# ###Answer:51.9%\\n\\n
# 908
#
#
# ###Answer:20.7%\\n\\n
# 909
#
#
# ###Answer:1.3% ( 1.3
# 910
#
#
# ###Answer:11.1%\\n\\n
# 911
#
#
# ###Answer:35.7 million dollars.\\n
# 912
#
#
# ###Answer:547333333
# 913
#
#
# ###Answer:0.8%\\n\\n\\
# 914
#
#
# ### Answer:46.4 million\\n\\n
# 915
#
#
# ###Answer:5.1% ( 5.1
# 916
#
#
# ###Answer:1.0%\\n\\n\\
# 917
#
#
# ###Answer:54%\\n\\n\\n
# 918
#
#
# ###Answer:100%\\n\\n
#
# 919
#
#
# ###Answer:10.7%..
#
#
# 920
#
#
# ###Answer:1.5475757
# 921
#
#
# ###Answer:1.1% ( 1.1
# 922
#
#
# ###Answer:10.4%\\n\\n
# 923
#
#
# ###Answer:3770000.0
# 924
#
#
# ###Answer:0.16% ( 0.
# 925
#
#
# ###Answer:yes\\n\\nno\\n\\
# 926
# ?
#
# ###Answer:7.5%\\n\\n
# 927
#
#
# ###Answer:8.1777777
# 928
#
#
# ###Answer:8.2% ( 8.2
# 929
#
#
# ###Answer:183%\\n\\n\\
# 930
#
#
# ###Answer:3.575\\n\\n
# 931
#
#
# ### Answer:19.47%..
#
# 932
#
#
# ###Answer:1.3333333
# 933
#  in millions?
#
# ###Answer:2.75% (
# 934
#
#
# ###Answer:9.1 million\\n\\n\\
# 935
#
#
# ###Answer:0.1% ( 0.1
# 936
# ?
#
# ###Answer:26.8% ( 2
# 937
# ?
#
# ###Answer:15752.00
# 938
#
#
# ###Answer:136.20%\\n
# 939
#
#
# ###Answer:40% ( 40 % )
# 940
#
#
# ###Answer:179.54675
# 941
#
#
# ###Answer:442000000
# 942
#
#
# ###Answer:172.50000
# 943
#
#
# ###Answer:161%\\n\\n\\
# 944
#
#
# ###Answer:98.4%\\n\\n
# 945
#
#
# ###Answer:10.5% ( 10
# 946
# ?
#
# ###Answer:84.33333
# 947
#
#
# ###Answer:10.7%\\n\\n
# 948
#
#
# ###Answer:13.95% ( 1
# 949
#  from 2017 to 2018
#
# ##
# 950
#
#
# ###Answer:1.3%\\n\\n\\
# 951
#
#
# ###Answer:126499.50
# 952
#  in 2017?
#
# ###Answer:21
# 953
#
#
# ###Answer:150.00000
# 954
#
#
# ###Answer:7.5%\\n\\n\\
# 955
#
#
# ###Answer:32.3%\\n\\n
# 956
#
#
# ###Answer:62%..
#
# ####context
# 957
#
#
# ###Answer:10.5%\\n\\n
# 958
#
#
# ###Answer:205500000
# 959
#
#
# ###Answer:5.5% ( 5.5
# 960
#
#
# ###Answer:89.2% ( 89
# 961
#
#
# ###Answer:15.5%\\n\\n
# 962
#
#
# ###Answer:1.04\\n\\nin
# 963
#
#
# ###Answer:29.425000
# 964
#
#
# ###Answer:62%\\n\\n\\n
# 965
#
#
# ###Answer:18.8%\\n\\n
# 966
#
#
# ###Answer:130.5 million\\n\\
# 967
#
#
# ###Answer:215.7 million\\n\\
# 968
#
#
# ###Answer:yes\\n\\nin 20
# 969
#
#
# ###Answer:12067.3\\n
# 970
#
#
# ###Answer:10.7%..
#
#
# 971
#
#
# ###Answer:44.3%\\n\\n
# 972
#
#
# ###Answer:100000.00
# 973
# ?
#
# ###Answer:11257340
# 974
#
#
# ### Answer:218.46%\\n
# 975
#
#
# ###Answer:94.3%\\n\\n
# 976
#
#
# ###Answer:45.6%\\n\\n
# 977
#
#
# ###Answer:16.1%\\n\\n
# 978
#
#
# ###Answer:7.9% ( 7.9
# 979
#
#
# ###Answer:3.8%..
#
# ####
# 980
#
#
# ###Answer:4.2%\\n\\n\\
# 981
# ?
#
# ###Answer:68.6%\\n\\
# 982
#  from 2011 to 2012
#
# ##
# 983
#  in 2010
#
# ###Answer:69.
# 984
#
#
# ###Answer:28.5% ( 28
# 985
#
#
# ###Answer:18%\\n\\nwhat percentage
# 986
#
#
# ###Answer:20.5% ( 20
# 987
#
#
# ###Answer:7.4%\\n\\nin
# 988
#
#
# ###Answer:300000000
# 989
#
#
# ###Answer:11.4%.\\n\\
# 990
#
#
# ### Answer:1.3134591
# 991
#  and 2013?
#
# ###Answer:17
# 992
#  to the total net of all collateral
#
# ###Answer:
# 993
#
#
# ###Answer:30.7%\\n\\n
# 994
#
#
# ###Answer:1.5857142
# 995
#
#
# ###Answer:27.5%\\n\\n
# 996
# ?
#
# ###Answer:10.5%.\\n
# 997
#
#
# ###Answer:0.4575757
# 998
#
#
# ###Answer:1.90% per year..
# 999
#
#
# ###Answer:10.3% ( 10
# 1000
#
#
# ###Answer:12.71%\\n\\
# 1001
#
#
# ###Answer:10.5%\\n\\n
# 1002
#
#
# ###Answer:15.5%..
#
#
# 1003
#
#
# ###Answer:1.3333333
# 1004
#
#
# ###Answer:1221.75 million dollars
# 1005
#
#
# ###Answer:14.5% ( 14
# 1006
#
#
# ###Answer:45%\\n\\nwhat percentage
# 1007
# ?
#
# ###Answer:60.62%..
# 1008
#
#
# ###Answer:104.6 million\\n\\
# 1009
# ?
#
# ###Answer:307.3333
# 1010
#
#
# ###Answer:2034.5000
# 1011
#
#
# ###Answer:77.711111
# 1012
#
#
# ###Answer:1.6% ( 1.6
# 1013
# ?
#
# ###Answer:1.2% ( 1.
# 1014
#  to the u.s.pension plans, discretionary contributions
# 1015
#
#
# ### Answer:102.83333
# 1016
#
#
# ###Answer:8.6%\\n\\n\\
# 1017
#
#
# ###Answer:117.00000
# 1018
#
#
# ###Answer:10.6%\\n\\n
# 1019
#
#
# ###Answer:371475320
# 1020
#
#
# ###Answer:10.5%\\n\\n
# 1021
#
#
# ###Answer:294941\\n\\
# 1022
#
#
# ### Answer:120.6%\\n\\
# 1023
#
#
# ###Answer:10% ( 10 % )
# 1024
#
#
# ###Answer:10.3%.
#
# ####
# 1025
#
#
# ### Answer:360.50000
# 1026
#
#
# ###Answer:20.8%\\n\\n
# 1027
#
#
# ###Answer:31.8% ( 31
# 1028
#  revenues
#
# ###Answer:17.4%\\n
# 1029
#
#
# ###Answer:63.5%\\n\\n
# 1030
# ?
#
# ###Answer:6.25% ( 6
# 1031
#
#
# ###Answer:36%\\n\\n\\n
# 1032
#
#
# ###Answer:10% ( 10 % )
# 1033
#
#
# ###Answer:23.5%\\n\\n
# 1034
#
#
# ###Answer:1.2% ( 1.2
# 1035
#
#
# ###Answer:1233.5 million dollars\\
# 1036
#
#
# ###Answer:1.4% ( 1.4
# 1037
#
#
# ###Answer:1.4% ( 1.4
# 1038
#
#
# ###Answer:50704.7\\n
# 1039
#
#
# ###Answer:10.7% ( 10
# 1040
#
#
# ###Answer:100.8%\\n\\
# 1041
# ?
#
# ###Answer:123% ( 12
# 1042
# ?
#
# ###Answer:324.7500
# 1043
#
#
# ###Answer:140.29%\\n
# 1044
# ?
#
# ###Answer:13.7%\\n\\
# 1045
#
#
# ###Answer:10.5%.
#
# ####
# 1046
#
#
# ###Answer:1.8\\n\\n
#
#
# 1047
#
#
# ###Answer:10.4%\\n\\n
# 1048
#
#
# ###Answer:5.75\\n\\n\\
# 1049
#
#
# ###Answer:16.5%\\n\\n
# 1050
#
#
# ###Answer:31%\\n\\n\\n
# 1051
#
#
# ###Answer:3700000.0
# 1052
#
#
# ###Answer:100%\\n\\n\\
# 1053
# ?
#
# ###Answer:49%..
#
# ####
# 1054
#
#
# ###Answer:33.69%..
#
# 1055
#
#
# ###Answer:12.4%\\n\\n
# 1056
#
#
# ###Answer:51%\\n\\n\\n
# 1057
#
#
# ###Answer:14.5%\\n\\n
# 1058
#
#
# ###Answer:36%\\n\\nwhat percentage
# 1059
#
#
# ###Answer:1.1% ( 1.1
# 1060
#
#
# ###Answer:22% ( 22 % )
# 1061
#
#
# ###Answer:13.6%\\n\\n
# 1062
#
#
# ###Answer:10.4%\\n\\n
# 1063
#
#
# ###Answer:25.6%..
#
#
# 1064
#
#
# ###Answer:1.9% ( 1.9
# 1065
#
#
# ###Answer:44.5%\\n\\n
# 1066
#
#
# ###Answer:100%\\n\\nwhat
# 1067
#
#
# ###Answer:27.5%\\n\\n
# 1068
#
#
# ###Answer:1.9% ( 1.9
# 1069
#
#
# ###Answer:215924\\n2
# 1070
#
#
# ###Answer:17.5%\\n\\n
# 1071
#
#
# ###Answer:36.9%\\n\\n
# 1072
# ?
#
# ###Answer:1.754333
# 1073
#
#
# ###Answer:19.7% ( 19
# 1074
#
#
# ###Answer:54.5%\\n\\n
# 1075
#
#
# ###Answer:20%\\n\\nwhat percent
# 1076
# ?
#
# ###Answer:263.4444
# 1077
#
#
# ###Answer:13.5% ( 13
# 1078
#
#
# ###Answer:16.5%.
#
# ####
# 1079
#
#
# ###Answer:14.000000
# 1080
#
#
# ###Answer:25% ( 25 % )
# 1081
#
#
# ###Answer:1349.0 million\\n
# 1082
#
#
# ###Answer:148291400
# 1083
#
#
# ###Answer:49.2%\\n\\n
# 1084
#
#
# ###Answer:100%\\n\\n\\
# 1085
#
#
# ###answer:410000000
# 1086
#
#
# ###Answer:6.0000000
# 1087
#
#
# ###Answer:12.5% ( 12
# 1088
#
#
# ###Answer:163.4%\\n\\
# 1089
#
#
# ###Answer:10.3% ( 10
# 1090
# ?
#
# ###Answer:8.1%\\n\\n
# 1091
#
#
# ###Answer:34.2%\\n\\n
# 1092
#
#
# ###Answer:3.9333333
# 1093
#
#
# ###Answer:7237.3333
# 1094
# ?
#
# ###Answer:7.4% ( 7.
# 1095
#
#
# ###Answer:0.4041428
# 1096
#
#
# ###Answer:33.3%..
#
#
# 1097
#
#
# ###Answer:25%..
#
# ####context
# 1098
#
#
# ###Answer:1.55%\\n\\n
# 1099
#
#
# ###Answer:45%\\n\\n\\n
# 1100
#
#
# ###Answer:12.5% ( 12
# 1101
#
#
# ###Answer:10.4%\\n\\n
# 1102
# ?
#
# ###Answer:648.5\\n\\
# 1103
#
#
# ### Answer:13.4% ( 13
# 1104
#
#
# ###Answer:178 million\\n\\nwhat
# 1105
#
#
# ###Answer:10.2% ( 10
# 1106
#
#
# ###Answer:19% ( 19 % )
# 1107
#
#
# ###Answer:2953816.0
# 1108
#
#
# ###Answer:100%\\n\\ncons
# 1109
#
#
# ###Answer:171.4%\\n\\
# 1110
#
#
# ###Answer:7.5%\\n\\n\\
# 1111
#
#
# ###Answer:15.4%\\n\\n
# 1112
#  under existing debt and lease commitments and purchase obligations at december
# 1113
#
#
# ###Answer:1.14\\n\\n\\
# 1114
#
#
# ###Answer:100.00000
# 1115
#
#
# ###Answer:52.5%\\n\\n
# 1116
# ?
#
# ###Answer:52883.5\\
# 1117
#
#
# ###Answer:13.5%\\n\\n
# 1118
#
#
# ###Answer:28%\\n\\nwhat percentage
# 1119
#
#
# ###Answer:53.2%\\n\\n
# 1120
#
#
# ###Answer:55.7%\\n\\n
# 1121
#
#
# ###Answer:11% ( 11 % )
# 1122
#
#
# ###Answer:10.7% ( 10
# 1123
#
#
# ###Answer:10.5% ( 10
# 1124
#
#
# ###Answer:158 million\\n\\nwhat
# 1125
#  to the total future minimum lease commitments
#
# ###Answer:
# 1126
#
#
# ###Answer:42.5%\\n\\n
# 1127
#
#
# ###Answer:4.1% ( 4.1
# 1128
#
#
# ###Answer:40.6%\\n\\n
# 1129
#
#
# ###Answer:1014.9 million\\n
# 1130
#  in the balance of unrecognized tax benefits?
#
# ###Answer
# 1131
#
#
# ###Answer:16.8%\\n\\n
# 1132
#
#
# ###Answer:10111.500
# 1133
#
#
# ### Answer:27.3% ( 27
# 1134
#
#
# ###Answer:10.6%\\n\\n
# 1135
#
#
# ###Answer:11.833333
# 1136
#
#
# ###Answer:55.8%\\n\\n
# 1137
#
#
# ###Answer:11.4%\\n\\n
# 1138
#
#
# ###Answer:133310600
# 1139
#
#
# ###Answer:56.5%\\n\\n
# 1140
#
#
# ###Answer:1.25\\nol carry forward
# 1141
#
#
# ###Answer:264%\\n\\n\\
# 1142
#
#
# ###Answer:1.04%\\n\\n
# 1143
#
#
# ###Answer:11.6%\\n\\n
# 1144
#
#
# ###Answer:154.33333
# 1145
# ?
#
# ###Answer:1.666712
# 1146
#
#
# ###Answer:4.9000000
# 1147
# --- 44623.39685058594 seconds ---

# %%
dataset_pd['prediction'] = output_list ## Add prediction output to test dataset

# %% [markdown]
# ### Perform Post Processing

# %%
def map_yes_no(x):
    x = str(x)
    if x.lower() in 'yes':
        return '1'
    elif x.lower() in 'no':
        return '0'
    else:
        return x


def remove_non_numeric(x):
    x = str(x)
    pattern = re.compile(r"[^\d.]")
    x = pattern.sub("", x)
    return x

def other_formatting(x):
  x =str(x)
  x=x.replace('...', '')
  x=x.replace('..', '')
  tofind = '.'
  if x.count(tofind) > 1:
    pos = x.index(tofind, x.index(tofind) + 1)
    x = x[:pos] + '' + x[pos + 1:]
    return x
  else:
    return x


def replace_blanks(x):
  x =str(x)
  if x.strip() == '':
    return '0'
  else:
    return x

# %%
import re
dataset_pd['formatted_answer']  = dataset_pd['answer'].apply(map_yes_no)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(remove_non_numeric)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(other_formatting)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].apply(replace_blanks)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].astype(float)
dataset_pd['formatted_answer'] = dataset_pd['formatted_answer'].round()

dataset_pd['formatted_prediction']  = dataset_pd['prediction'].apply(map_yes_no)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(remove_non_numeric)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(other_formatting)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].apply(replace_blanks)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].astype(float)
dataset_pd['formatted_prediction'] = dataset_pd['formatted_prediction'].round()

# %% [markdown]
# ### Final Score

# %%
import numpy as np
dataset_pd['match_ind'] = np.where( dataset_pd['formatted_answer'] == dataset_pd['formatted_prediction'], 1,0)
dataset_pd['match_ind'].mean()
# Out:
# 0.14908456843940715

# %% [markdown]
# ### The final exact match accuracy of LLaMA 2 is 0.15
